# %%
import pandas as pd
import requests
import urllib.parse
import geopandas as gpd

# %%
inactivity_df = pd.read_csv('ni_inac.csv')
inactivity_df.rename(columns={'Census 2021 Super Data Zone Code': 'SDZ'}, inplace=True)

# %%
inactivity_df['Economic Activity - 9 Categories Label'].value_counts()
# Out:
# Economically active: Employee (including full-time students)         850
# Economically active: Self-employed (including full-time students)    850
# Economically active: Unemployed (including full-time students)       850
# Economically inactive: Retired                                       850
# Economically inactive: Student                                       850
# Economically inactive: Looking after home or family                  850
# Economically inactive: Long-term sick or disabled                    850
# Economically inactive: Other                                         850
# No code required                                                     850
# Name: Economic Activity - 9 Categories Label, dtype: int64

# %%
pop_df = pd.read_excel('ni_pop.xlsx', sheet_name='SDZ', skiprows=5)
pop_df.rename(columns={'All usual residents':'Population', 'Geography Code': "SDZ"}, inplace=True)
pop_df = pop_df[['SDZ', 'Population']]

# %%
df = pd.merge(inactivity_df, pop_df, on='SDZ', how='left')
df.rename(columns={'Economic Activity - 9 Categories Label':'Series', 'Census 2021 Super Data Zone Label': 'Area'}, inplace=True)
df['Value'] = df['Count']/df['Population']
df = df[["SDZ", "Area", "Series", "Count", "Population", "Value"]]

file_names = {
 'Economically active: Employee (including full-time students)':'employee.csv',
 'Economically active: Self-employed (including full-time students)': 'self_employed.csv',
 'Economically active: Unemployed (including full-time students)': 'unemployed.csv',
 'Economically inactive: Retired': 'retired.csv',
 'Economically inactive: Student': 'student.csv',
 'Economically inactive: Looking after home or family': 'home.csv',
 'Economically inactive: Long-term sick or disabled': 'sick.csv',
 'Economically inactive: Other': 'other.csv',
 'No code required': 'no_code.csv'
}

for series in df.Series.unique():
    df[df.Series == series].to_csv("/Users/finn/Documents/GitHub/RADataHub/Economic Inactivity/NI_Activity/"+file_names[series], index=False)

# %%
df[df.Series.str.contains('Economically inactive')].groupby(['SDZ', 'Area']).sum().to_csv('/Users/finn/Documents/GitHub/RADataHub/Economic Inactivity/NI_Activity/inactive.csv')

df[df.Series.str.contains('Economically inactive')].groupby(['SDZ', 'Area']).sum().to_csv('/Users/finn/Documents/GitHub/RADataHub/Economic Inactivity/NI_Activity/inactive.csv')

# %%
df[df.Area.str.contains('park')]
# Out:
#             SDZ       Area                                             Series  \
# 1440  N21000161  Oldpark_A  Economically active: Employee (including full-...
# 1441  N21000161  Oldpark_A  Economically active: Self-employed (including ...
# 1442  N21000161  Oldpark_A  Economically active: Unemployed (including ful...
# 1443  N21000161  Oldpark_A                     Economically inactive: Retired
# 1444  N21000161  Oldpark_A                     Economically inactive: Student
# ...         ...        ...                                                ...
# 1597  N21000178  Oldpark_U                     Economically inactive: Student
# 1598  N21000178  Oldpark_U  Economically inactive: Looking after home or f...
# 1599  N21000178  Oldpark_U  Economically inactive: Long-term sick or disabled
# 1600  N21000178  Oldpark_U                       Economically inactive: Other
# 1601  N21000178  Oldpark_U                                   No code required
#
#       Count  Population     Value
# 1440   1022        2707  0.377540
# 1441    116        2707  0.042852
# 1442     69        2707  0.025489
# 1443    192        2707  0.070927
# 1444    138        2707  0.050979
# ...     ...         ...       ...
# 1597     92        1775  0.051831
# 1598    114        1775  0.064225
# 1599    269        1775  0.151549
# 1600    120        1775  0.067606
# 1601    361        1775  0.203380
#
# [162 rows x 6 columns]

# %%
places_df = pd.read_excel('/Users/finn/Documents/Data_Dump/NI_Places.xlsx')

# %%
def get_coords(place):
    """Get the coordinates of a place using the Google Maps API"""
    place = place+" Northern Ireland, UK"
    url = 'https://nominatim.openstreetmap.org/search?q=' + urllib.parse.quote(place) + '&format=json'

    print(url)

    response = requests.get(url).json()
    print(response)
    return [response[0]["lat"], response[0]["lon"]]

if input("Do you want to get the coordinates of the places? (y/n)") == "y":
    places_df['coords'] = places_df['City'].apply(get_coords)
# Out:
# https://nominatim.openstreetmap.org/search?q=Belfast%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 13725155, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1418701024, 'lat': '54.596391', 'lon': '-5.9301829', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.6500238353643837, 'addresstype': 'city', 'name': 'Belfast', 'display_name': 'Belfast, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT1 5GS, United Kingdom', 'boundingbox': ['54.4363910', '54.7563910', '-6.0901829', '-5.7701829']}]
# https://nominatim.openstreetmap.org/search?q=Londonderry%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 730705, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762522, 'lat': '54.9978678', 'lon': '-7.3213056', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5541638863419593, 'addresstype': 'city', 'name': 'Derry/Londonderry', 'display_name': 'Derry/Londonderry, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, BT48 6BU, United Kingdom', 'boundingbox': ['54.8378678', '55.1578678', '-7.4813056', '-7.1613056']}]
# https://nominatim.openstreetmap.org/search?q=Lisburn%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 14338315, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1460517034, 'lat': '54.5112913', 'lon': '-6.0466736', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5059426015954562, 'addresstype': 'city', 'name': 'Lisburn', 'display_name': 'Lisburn, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT28 1BJ, United Kingdom', 'boundingbox': ['54.3512913', '54.6712913', '-6.2066736', '-5.8866736']}]
# https://nominatim.openstreetmap.org/search?q=Newtownabbey%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 739696, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763099, 'lat': '54.6778816', 'lon': '-5.9249199', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.42604892627190893, 'addresstype': 'town', 'name': 'Newtownabbey', 'display_name': 'Newtownabbey, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT36 6UN, United Kingdom', 'boundingbox': ['54.6378816', '54.7178816', '-5.9649199', '-5.8849199']}]
# https://nominatim.openstreetmap.org/search?q=Bangor%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732630, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762683, 'lat': '54.662595', 'lon': '-5.6679127', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.46907511874282654, 'addresstype': 'city', 'name': 'Bangor', 'display_name': 'Bangor, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT20 5AG, United Kingdom', 'boundingbox': ['54.5025950', '54.8225950', '-5.8279127', '-5.5079127']}]
# https://nominatim.openstreetmap.org/search?q=Craigavon%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732047, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763084, 'lat': '54.4507201', 'lon': '-6.3921622', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4122960537999171, 'addresstype': 'town', 'name': 'Craigavon', 'display_name': 'Craigavon, County Armagh, Ulster, Northern Ireland / Tuaisceart Éireann, BT64 3AE, United Kingdom', 'boundingbox': ['54.4107201', '54.4907201', '-6.4321622', '-6.3521622']}]
# https://nominatim.openstreetmap.org/search?q=Castlereagh%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 15842510, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1724172118, 'lat': '54.5763441', 'lon': '-5.8812117', 'class': 'place', 'type': 'suburb', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'suburb', 'name': 'Castlereagh', 'display_name': 'Castlereagh, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT6 9HL, United Kingdom', 'boundingbox': ['54.5563441', '54.5963441', '-5.9012117', '-5.8612117']}, {'place_id': 298491606, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4777415, 'lat': '54.5697368', 'lon': '-5.873949954841993', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Castlereagh', 'display_name': 'Castlereagh, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.5614939', '54.5779477', '-5.8864355', '-5.8626881']}, {'place_id': 729971, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762744, 'lat': '54.566667', 'lon': '-5.866667', 'class': 'place', 'type': 'locality', 'place_rank': 25, 'importance': 0.12500009999999995, 'addresstype': 'locality', 'name': 'Castlereagh', 'display_name': 'Castlereagh, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT6 9RD, United Kingdom', 'boundingbox': ['54.5566670', '54.5766670', '-5.8766670', '-5.8566670']}]
# https://nominatim.openstreetmap.org/search?q=Newtownards%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728275, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762996, 'lat': '54.5933779', 'lon': '-5.6960935', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4411963935969196, 'addresstype': 'town', 'name': 'Newtownards', 'display_name': 'Newtownards, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT23 4FA, United Kingdom', 'boundingbox': ['54.5533779', '54.6333779', '-5.7360935', '-5.6560935']}]
# https://nominatim.openstreetmap.org/search?q=Carrickfergus%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733132, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762843, 'lat': '54.7136165', 'lon': '-5.8073112', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4591662794031617, 'addresstype': 'town', 'name': 'Carrickfergus', 'display_name': 'Carrickfergus, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT38 7AN, United Kingdom', 'boundingbox': ['54.6736165', '54.7536165', '-5.8473112', '-5.7673112']}, {'place_id': 298460405, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6413805, 'lat': '54.7317202', 'lon': '-5.847020465458015', 'class': 'boundary', 'type': 'barony', 'place_rank': 25, 'importance': 0.36529067188377956, 'addresstype': 'barony', 'name': 'Carrickfergus or St Nicholas', 'display_name': 'Carrickfergus or St Nicholas, Greenisland, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.6854147', '54.7780431', '-5.9638510', '-5.7708711']}, {'place_id': 298257418, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4480739, 'lat': '54.7152785', 'lon': '-5.806752632791332', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Carrickfergus', 'display_name': 'Carrickfergus, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.7095004', '54.7210651', '-5.8163120', '-5.7950830']}]
# https://nominatim.openstreetmap.org/search?q=Ballymena%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732847, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763055, 'lat': '54.8662966', 'lon': '-6.2760159', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.36529067188377956, 'addresstype': 'town', 'name': 'Ballymena', 'display_name': 'Ballymena, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT43 6AH, United Kingdom', 'boundingbox': ['54.8262966', '54.9062966', '-6.3160159', '-6.2360159']}, {'place_id': 298702058, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4261251, 'lat': '54.92742345', 'lon': '-6.166898830654912', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Ballymena', 'display_name': 'Ballymena, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.9067333', '54.9480181', '-6.1938072', '-6.1465826']}]
# https://nominatim.openstreetmap.org/search?q=Newry%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 298560816, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4676275, 'lat': '54.1775283', 'lon': '-6.337506', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5117649239554671, 'addresstype': 'city', 'name': 'Newry', 'display_name': 'Newry, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.1449485', '54.1959650', '-6.3601138', '-6.3050701']}, {'place_id': 298591565, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5489469, 'lat': '54.3997065', 'lon': '-7.254764385810086', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Newry', 'display_name': 'Newry, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3944843', '54.4049418', '-7.2637195', '-7.2450539']}]
# https://nominatim.openstreetmap.org/search?q=Coleraine%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733274, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763060, 'lat': '55.1315912', 'lon': '-6.671861', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.46799787085516703, 'addresstype': 'town', 'name': 'Coleraine', 'display_name': 'Coleraine, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, BT52 1EP, United Kingdom', 'boundingbox': ['55.0915912', '55.1715912', '-6.7118610', '-6.6318610']}, {'place_id': 298868149, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1959598, 'lat': '54.91429105', 'lon': '-6.88060985974311', 'class': 'place', 'type': 'county', 'place_rank': 12, 'importance': 0.5130338711197162, 'addresstype': 'county', 'name': 'County Londonderry', 'display_name': 'County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.6282688', '55.2002556', '-7.4074365', '-6.4570363']}]
# https://nominatim.openstreetmap.org/search?q=Omagh%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728460, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763090, 'lat': '54.5992486', 'lon': '-7.3029907', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4625475868267511, 'addresstype': 'town', 'name': 'Omagh', 'display_name': 'Omagh, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT78 1BJ, United Kingdom', 'boundingbox': ['54.5592486', '54.6392486', '-7.3429907', '-7.2629907']}, {'place_id': 298494837, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5323188, 'lat': '54.60027665', 'lon': '-7.302272424803647', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Omagh', 'display_name': 'Omagh, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.5986003', '54.6019885', '-7.3079107', '-7.2967342']}]
# https://nominatim.openstreetmap.org/search?q=Antrim%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733393, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762485, 'lat': '54.715139', 'lon': '-6.2192038', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4435490608922571, 'addresstype': 'town', 'name': 'Antrim', 'display_name': 'Antrim, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT41 4AR, United Kingdom', 'boundingbox': ['54.6751390', '54.7551390', '-6.2592038', '-6.1792038']}, {'place_id': 297746914, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1119534, 'lat': '54.864725500000006', 'lon': '-6.143637910742768', 'class': 'place', 'type': 'county', 'place_rank': 12, 'importance': 0.5448215497330099, 'addresstype': 'county', 'name': 'County Antrim', 'display_name': 'County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4772774', '55.3130865', '-6.6689889', '-5.6879630']}]
# https://nominatim.openstreetmap.org/search?q=Larne%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 731472, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762846, 'lat': '54.8508458', 'lon': '-5.8183116', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.46805993772785703, 'addresstype': 'town', 'name': 'Larne', 'display_name': 'Larne, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT40 1JS, United Kingdom', 'boundingbox': ['54.8108458', '54.8908458', '-5.8583116', '-5.7783116']}]
# https://nominatim.openstreetmap.org/search?q=Banbridge%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 735428, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762560, 'lat': '54.3514168', 'lon': '-6.2714623', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4327262509148135, 'addresstype': 'town', 'name': 'Banbridge', 'display_name': 'Banbridge, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT32 3AD, United Kingdom', 'boundingbox': ['54.3114168', '54.3914168', '-6.3114623', '-6.2314623']}]
# https://nominatim.openstreetmap.org/search?q=Armagh%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 731306, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763062, 'lat': '54.3481977', 'lon': '-6.6540432', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5109196839369105, 'addresstype': 'city', 'name': 'Armagh', 'display_name': 'Armagh, County Armagh, Ulster, Northern Ireland / Tuaisceart Éireann, BT61 7DJ, United Kingdom', 'boundingbox': ['54.1881977', '54.5081977', '-6.8140432', '-6.4940432']}, {'place_id': 297749802, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1119535, 'lat': '54.30201135', 'lon': '-6.612426774999999', 'class': 'place', 'type': 'county', 'place_rank': 12, 'importance': 0.5121908158728945, 'addresstype': 'county', 'name': 'County Armagh', 'display_name': 'County Armagh, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.0364597', '54.5675362', '-6.8780378', '-6.2908641']}]
# https://nominatim.openstreetmap.org/search?q=Enniskillen%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728520, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763152, 'lat': '54.3448538', 'lon': '-7.6389365', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4636235753005195, 'addresstype': 'town', 'name': 'Enniskillen', 'display_name': 'Enniskillen, County Fermanagh, Ulster, Northern Ireland / Tuaisceart Éireann, BT74 7DH, United Kingdom', 'boundingbox': ['54.3048538', '54.3848538', '-7.6789365', '-7.5989365']}, {'place_id': 298402397, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5394729, 'lat': '54.6257327', 'lon': '-6.643404610342717', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Enniskillen', 'display_name': 'Enniskillen, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.6193396', '54.6320567', '-6.6554167', '-6.6362696']}, {'place_id': 298825021, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9448068, 'lat': '54.3444541', 'lon': '-7.638987146851637', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Enniskillen', 'display_name': 'Enniskillen, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3416612', '54.3472165', '-7.6449788', '-7.6346013']}, {'place_id': 298138738, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3570146, 'lat': '54.3467067', 'lon': '-7.642089030843312', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'suburb', 'name': 'Enniskillen', 'display_name': 'Enniskillen, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3433960', '54.3499791', '-7.6473400', '-7.6380633']}]
# https://nominatim.openstreetmap.org/search?q=Strabane%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732845, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762533, 'lat': '54.826115', 'lon': '-7.4627993', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4313349412833712, 'addresstype': 'town', 'name': 'Strabane', 'display_name': 'Strabane, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT82 8AH, United Kingdom', 'boundingbox': ['54.7861150', '54.8661150', '-7.5027993', '-7.4227993']}, {'place_id': 298561983, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4631848, 'lat': '54.47372245', 'lon': '-7.392011690620496', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Strabane', 'display_name': 'Strabane, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4682670', '54.4793182', '-7.3990075', '-7.3826133']}]
# https://nominatim.openstreetmap.org/search?q=Holywood%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 737197, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762830, 'lat': '54.6404494', 'lon': '-5.8361723', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000009999999994, 'addresstype': 'town', 'name': 'Holywood', 'display_name': 'Holywood, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT18 9AE, United Kingdom', 'boundingbox': ['54.6004494', '54.6804494', '-5.8761723', '-5.7961723']}, {'place_id': 298744743, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4648272, 'lat': '54.63165585', 'lon': '-5.830126242183564', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Holywood', 'display_name': 'Holywood, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.6187922', '54.6444429', '-5.8548445', '-5.8155834']}]
# https://nominatim.openstreetmap.org/search?q=Limavady%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733576, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762733, 'lat': '55.0504857', 'lon': '-6.9505134', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.41869761780661746, 'addresstype': 'town', 'name': 'Limavady', 'display_name': 'Limavady, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, BT49 0EP, United Kingdom', 'boundingbox': ['55.0104857', '55.0904857', '-6.9905134', '-6.9105134']}]
# https://nominatim.openstreetmap.org/search?q=Dungannon%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 735283, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762878, 'lat': '54.5039088', 'lon': '-6.7703622', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.44782895083352503, 'addresstype': 'town', 'name': 'Dungannon', 'display_name': 'Dungannon, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT71 7AA, United Kingdom', 'boundingbox': ['54.4639088', '54.5439088', '-6.8103622', '-6.7303622']}]
# https://nominatim.openstreetmap.org/search?q=Cookstown%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 731773, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762588, 'lat': '54.6436734', 'lon': '-6.7416008', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4153614865228886, 'addresstype': 'town', 'name': 'Cookstown', 'display_name': 'Cookstown, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT80 8PF, United Kingdom', 'boundingbox': ['54.6036734', '54.6836734', '-6.7816008', '-6.7016008']}, {'place_id': 298394272, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4570657, 'lat': '54.45057945', 'lon': '-5.519015761626256', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Cookstown', 'display_name': 'Cookstown, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4411821', '54.4600269', '-5.5323970', '-5.5101008']}, {'place_id': 298554405, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5443361, 'lat': '54.650288599999996', 'lon': '-6.742806896628762', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Cookstown', 'display_name': 'Cookstown, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.6459329', '54.6546095', '-6.7589758', '-6.7305826']}]
# https://nominatim.openstreetmap.org/search?q=Downpatrick%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733044, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762719, 'lat': '54.3279335', 'lon': '-5.71649', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4463469122541483, 'addresstype': 'town', 'name': 'Downpatrick', 'display_name': 'Downpatrick, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, BT30 6BB, United Kingdom', 'boundingbox': ['54.2879335', '54.3679335', '-5.7564900', '-5.6764900']}]
# https://nominatim.openstreetmap.org/search?q=Ballymoney%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 14974734, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1604307220, 'lat': '55.0702727', 'lon': '-6.5172758', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4336004840035907, 'addresstype': 'town', 'name': 'Ballymoney', 'display_name': 'Ballymoney, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT53 6AY, United Kingdom', 'boundingbox': ['55.0302727', '55.1102727', '-6.5572758', '-6.4772758']}, {'place_id': 298258415, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4519571, 'lat': '54.57559395', 'lon': '-6.005923274481331', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, Lenadoon, Andersonstown, Lisburn, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.5651886', '54.5859709', '-6.0175714', '-5.9805313']}, {'place_id': 298458515, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4772478, 'lat': '54.3628162', 'lon': '-6.258076819348124', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, Banbridge, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3560390', '54.3694974', '-6.2723653', '-6.2341745']}, {'place_id': 298420066, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4595033, 'lat': '54.827974100000006', 'lon': '-5.716236836476792', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.8207560', '54.8349859', '-5.7293315', '-5.7040026']}, {'place_id': 298737698, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4595882, 'lat': '54.2387765', 'lon': '-6.026058157177813', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, Kilcoo, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, BT34 5HU, United Kingdom', 'boundingbox': ['54.2313200', '54.2463413', '-6.0503924', '-6.0098736']}, {'place_id': 298428009, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4680868, 'lat': '54.11082065', 'lon': '-6.205146713248212', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, Rostrevor, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.1037159', '54.1180206', '-6.2174674', '-6.1946918']}, {'place_id': 298295495, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5140858, 'lat': '54.9318314', 'lon': '-7.0281466', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Ballymoney', 'display_name': 'Ballymoney, Ulster, Northern Ireland / Tuaisceart Éireann, BT47 4PJ, United Kingdom', 'boundingbox': ['54.9144063', '54.9497366', '-7.0615441', '-7.0106575']}, {'place_id': 298262175, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4583320, 'lat': '54.5714950499 ...
# https://nominatim.openstreetmap.org/search?q=Ballyclare%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 735872, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763025, 'lat': '54.7525296', 'lon': '-6.0010911', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4163742482679513, 'addresstype': 'town', 'name': 'Ballyclare', 'display_name': 'Ballyclare, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT39 9BB, United Kingdom', 'boundingbox': ['54.7125296', '54.7925296', '-6.0410911', '-5.9610911']}, {'place_id': 298652655, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4478890, 'lat': '54.7504699', 'lon': '-6.015001274656586', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballyclare', 'display_name': 'Ballyclare, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.7360767', '54.7649120', '-6.0334692', '-5.9876617']}, {'place_id': 299041038, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9430698, 'lat': '54.75375565', 'lon': '-5.987373943863444', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Ballyclare', 'display_name': 'Ballyclare, Ulster, Northern Ireland / Tuaisceart Éireann, BT39 9AG, United Kingdom', 'boundingbox': ['54.7489340', '54.7585029', '-5.9988015', '-5.9753097']}]
# https://nominatim.openstreetmap.org/search?q=Comber%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732697, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762565, 'lat': '54.5498342', 'lon': '-5.7454313', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000009999999994, 'addresstype': 'town', 'name': 'Comber', 'display_name': 'Comber, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT23 5DU, United Kingdom', 'boundingbox': ['54.5098342', '54.5898342', '-5.7854313', '-5.7054313']}]
# https://nominatim.openstreetmap.org/search?q=Magherafelt%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 730763, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762677, 'lat': '54.7544757', 'lon': '-6.6078073', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.40882733084479794, 'addresstype': 'town', 'name': 'Magherafelt', 'display_name': 'Magherafelt, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, BT45 6EE, United Kingdom', 'boundingbox': ['54.7144757', '54.7944757', '-6.6478073', '-6.5678073']}]
# https://nominatim.openstreetmap.org/search?q=Portstewart%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733486, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763043, 'lat': '55.1829096', 'lon': '-6.7187008', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3933266335064898, 'addresstype': 'town', 'name': 'Portstewart', 'display_name': 'Portstewart, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, BT55 7AG, United Kingdom', 'boundingbox': ['55.1429096', '55.2229096', '-6.7587008', '-6.6787008']}]
# https://nominatim.openstreetmap.org/search?q=Carryduff%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 740326, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762401, 'lat': '54.5184788', 'lon': '-5.8874586', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000009999999994, 'addresstype': 'town', 'name': 'Carryduff', 'display_name': 'Carryduff, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT8 8DN, United Kingdom', 'boundingbox': ['54.4784788', '54.5584788', '-5.9274586', '-5.8474586']}, {'place_id': 298273276, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4660727, 'lat': '54.51938335', 'lon': '-5.888198822116697', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Carryduff', 'display_name': 'Carryduff, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.5088440', '54.5299489', '-5.9025821', '-5.8747414']}]
# https://nominatim.openstreetmap.org/search?q=Warrenpoint%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 739734, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763161, 'lat': '54.0999923', 'lon': '-6.2512827', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4097928712086047, 'addresstype': 'town', 'name': 'Warrenpoint', 'display_name': 'Warrenpoint, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, BT34 3HS, United Kingdom', 'boundingbox': ['54.0599923', '54.1399923', '-6.2912827', '-6.2112827']}]
# https://nominatim.openstreetmap.org/search?q=Donaghadee%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 740996, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762604, 'lat': '54.6425446', 'lon': '-5.5375794', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000999999999994, 'addresstype': 'town', 'name': 'Donaghadee', 'display_name': 'Donaghadee, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT21 0AH, United Kingdom', 'boundingbox': ['54.6025446', '54.6825446', '-5.5775794', '-5.4975794']}]
# https://nominatim.openstreetmap.org/search?q=Portrush%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 741330, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762976, 'lat': '55.2060325', 'lon': '-6.6540486', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4269015619958603, 'addresstype': 'town', 'name': 'Portrush', 'display_name': 'Portrush, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT56 8BN, United Kingdom', 'boundingbox': ['55.1660325', '55.2460325', '-6.6940486', '-6.6140486']}, {'place_id': 298334053, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4475070, 'lat': '55.20471465', 'lon': '-6.651892780534951', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Portrush', 'display_name': 'Portrush, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['55.1963220', '55.2130839', '-6.6631604', '-6.6409224']}]
# https://nominatim.openstreetmap.org/search?q=Kilkeel%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 730486, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762451, 'lat': '54.0626664', 'lon': '-6.0059949', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.40784642314718983, 'addresstype': 'town', 'name': 'Kilkeel', 'display_name': 'Kilkeel, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, BT34 4BH, United Kingdom', 'boundingbox': ['54.0226664', '54.1026664', '-6.0459949', '-5.9659949']}, {'place_id': 298539647, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4550663, 'lat': '54.06659155', 'lon': '-5.995039933547005', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Kilkeel', 'display_name': 'Kilkeel, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.0579727', '54.0751640', '-6.0116218', '-5.9774297']}]
# https://nominatim.openstreetmap.org/search?q=Ballynahinch%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 736354, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763088, 'lat': '54.4026038', 'lon': '-5.8960151', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000999999999994, 'addresstype': 'town', 'name': 'Ballynahinch', 'display_name': 'Ballynahinch, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT24 8DN, United Kingdom', 'boundingbox': ['54.3626038', '54.4426038', '-5.9360151', '-5.8560151']}, {'place_id': 298443916, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5342154, 'lat': '54.36329045', 'lon': '-6.531415584950996', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballynahinch', 'display_name': 'Ballynahinch, Richhill, County Armagh, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3529926', '54.3736780', '-6.5386236', '-6.5166638']}, {'place_id': 298484609, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4661785, 'lat': '54.40546095', 'lon': '-5.888769015567764', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballynahinch', 'display_name': 'Ballynahinch, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3930306', '54.4179052', '-5.9051331', '-5.8759195']}]
# https://nominatim.openstreetmap.org/search?q=Dromore%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 742559, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763207, 'lat': '54.4152683', 'lon': '-6.1495064', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4001323183339332, 'addresstype': 'town', 'name': 'Dromore', 'display_name': 'Dromore, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT25 1BD, United Kingdom', 'boundingbox': ['54.3752683', '54.4552683', '-6.1895064', '-6.1095064']}, {'place_id': 731880, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762836, 'lat': '54.5128552', 'lon': '-7.4576175', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.3494483654395652, 'addresstype': 'village', 'name': 'Dromore', 'display_name': 'Dromore, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT78 3GA, United Kingdom', 'boundingbox': ['54.4928552', '54.5328552', '-7.4776175', '-7.4376175']}, {'place_id': 298523255, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4670232, 'lat': '54.111336300000005', 'lon': '-6.265051281213665', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Dromore', 'display_name': 'Dromore, Warrenpoint, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.1016647', '54.1208611', '-6.2752750', '-6.2516527']}, {'place_id': 298246419, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4431634, 'lat': '54.9488747', 'lon': '-6.360407435777147', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Dromore', 'display_name': 'Dromore, Glarryford, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.9366997', '54.9609739', '-6.3736719', '-6.3515487']}, {'place_id': 298355015, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4617794, 'lat': '55.074480300000005', 'lon': '-6.664641929891994', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Dromore', 'display_name': 'Dromore, County Londonderry, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['55.0687262', '55.0800461', '-6.6762132', '-6.6532480']}, {'place_id': 298562733, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5415578, 'lat': '54.37434435', 'lon': '-6.881300067984551', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Dromore', 'display_name': 'Dromore, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3657949', '54.3830590', '-6.8965170', '-6.8737065']}, {'place_id': 298373720, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4817372, 'lat': '54.78334245', 'lon': '-6.666582065303487', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Dromore', 'display_name': 'Dromore, Ulster, Northern Ireland / Tuaisceart Éireann, BT45 5JZ, United Kingdom', 'boundingbox': ['54.7766236', '54.7898537', '-6.6784704', '-6.6555545']}, {'place_id': 298273549, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4661305, 'lat': '54.515768550000004', 'lon': '-7.462622190635132', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999 ...
# https://nominatim.openstreetmap.org/search?q=Ballycastle%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733843, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267763167, 'lat': '55.2006882', 'lon': '-6.250282', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000009999999994, 'addresstype': 'town', 'name': 'Ballycastle', 'display_name': 'Ballycastle, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT54 6AN, United Kingdom', 'boundingbox': ['55.1606882', '55.2406882', '-6.2902820', '-6.2102820']}, {'place_id': 298269273, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4599985, 'lat': '54.567953450000005', 'lon': '-5.599153712831072', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Ballycastle', 'display_name': 'Ballycastle, Bangor, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.5632098', '54.5727486', '-5.6183542', '-5.5852845']}, {'place_id': 298289189, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4849345, 'lat': '55.087717299999994', 'lon': '-6.947588426945801', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Ballycastle', 'display_name': 'Ballycastle, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['55.0818963', '55.0937154', '-6.9557179', '-6.9263202']}]
# https://nominatim.openstreetmap.org/search?q=Coalisland%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728252, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762965, 'lat': '54.5394657', 'lon': '-6.7004879', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.38799234835675056, 'addresstype': 'town', 'name': 'Coalisland', 'display_name': 'Coalisland, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT71 4NB, United Kingdom', 'boundingbox': ['54.4994657', '54.5794657', '-6.7404879', '-6.6604879']}]
# https://nominatim.openstreetmap.org/search?q=Randalstown%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 739818, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762797, 'lat': '54.7498918', 'lon': '-6.3197638', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.30000009999999994, 'addresstype': 'town', 'name': 'Randalstown', 'display_name': 'Randalstown, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT41 3AD, United Kingdom', 'boundingbox': ['54.7098918', '54.7898918', '-6.3597638', '-6.2797638']}, {'place_id': 298233196, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4201806, 'lat': '54.7464909', 'lon': '-6.327074690840089', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Randalstown', 'display_name': 'Randalstown, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.7414218', '54.7514477', '-6.3310597', '-6.3175070']}]
# https://nominatim.openstreetmap.org/search?q=Crumlin%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728355, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762935, 'lat': '54.6206167', 'lon': '-6.2149351', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'village', 'name': 'Crumlin', 'display_name': 'Crumlin, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT29 4XW, United Kingdom', 'boundingbox': ['54.6006167', '54.6406167', '-6.2349351', '-6.1949351']}]
# https://nominatim.openstreetmap.org/search?q=Greenisland%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 731988, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762523, 'lat': '54.7000898', 'lon': '-5.8724792', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'village', 'name': 'Greenisland', 'display_name': 'Greenisland, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT38 8UN, United Kingdom', 'boundingbox': ['54.6800898', '54.7200898', '-5.8924792', '-5.8524792']}]
# https://nominatim.openstreetmap.org/search?q=Moira%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 140209816, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 148898309, 'lat': '54.4791204', 'lon': '-6.229523089249599', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.39163507211497156, 'addresstype': 'town', 'name': 'Moira', 'display_name': 'Moira, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4722633', '54.4853601', '-6.2424013', '-6.2130517']}]
# https://nominatim.openstreetmap.org/search?q=Maghera%20Northern%20Ireland%2C%20UK&format=json
# ...
# https://nominatim.openstreetmap.org/search?q=Glenariff%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 738290, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762391, 'lat': '55.05', 'lon': '-6.066667', 'class': 'place', 'type': 'locality', 'place_rank': 25, 'importance': 0.12500009999999995, 'addresstype': 'locality', 'name': 'Glenariff', 'display_name': 'Glenariff, Waterfoot, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 0RB, United Kingdom', 'boundingbox': ['55.0400000', '55.0600000', '-6.0766670', '-6.0566670']}, {'place_id': 298597414, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7049841, 'lat': '55.00909045', 'lon': '-6.127254122768983', 'class': 'landuse', 'type': 'forest', 'place_rank': 22, 'importance': 0.37285958840993527, 'addresstype': 'forest', 'name': 'Glenariff Forest', 'display_name': 'Glenariff Forest, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.9984865', '55.0395134', '-6.1614884', '-6.0942438']}, {'place_id': 246934121, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 708799797, 'lat': '55.0179323', 'lon': '-6.1161308', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'river', 'name': 'Glenariff River', 'display_name': 'Glenariff River, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 0QZ, United Kingdom', 'boundingbox': ['55.0168291', '55.0198041', '-6.1287334', '-6.1030086']}, {'place_id': 181847436, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 316368366, 'lat': '55.0560955', 'lon': '-6.0611352', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'river', 'name': 'Glenariff River', 'display_name': 'Glenariff River, Waterfoot, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 0RB, United Kingdom', 'boundingbox': ['55.0535719', '55.0591450', '-6.0626185', '-6.0591819']}, {'place_id': 181459297, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 316459729, 'lat': '55.04487', 'lon': '-6.0685437', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'river', 'name': 'Glenariff River', 'display_name': 'Glenariff River, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 0RB, United Kingdom', 'boundingbox': ['55.0432483', '55.0465367', '-6.0699978', '-6.0670190']}, {'place_id': 298322875, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4264562, 'lat': '55.007380999999995', 'lon': '-6.086763550600331', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Upper Glenariff Mountain West', 'display_name': 'Upper Glenariff Mountain West, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.9986239', '55.0161892', '-6.0955765', '-6.0776697']}, {'place_id': 298240600, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4259680, 'lat': '55.0308981', 'lon': '-6.039362467936121', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Glenariff Mountain Lower', 'display_name': 'Glenariff Mountain Lower, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['55.0187166', '55.0423973', '-6.0525984', '-6.0245580']}, {'place_id': 298482156, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4261324, 'lat': '55.0169863', 'lon': '-6.0662822054861', 'class': 'boundary', 'ty ...
# https://nominatim.openstreetmap.org/search?q=Kircubbin%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 730458, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762420, 'lat': '54.4870904', 'lon': '-5.53201', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.36412932717098795, 'addresstype': 'village', 'name': 'Kircubbin', 'display_name': 'Kircubbin, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT22 2SQ, United Kingdom', 'boundingbox': ['54.4670904', '54.5070904', '-5.5520100', '-5.5120100']}, {'place_id': 298261834, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4576855, 'lat': '54.4908632', 'lon': '-5.524642334880845', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Kircubbin', 'display_name': 'Kircubbin, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4827910', '54.4989861', '-5.5425660', '-5.4988117']}]
# https://nominatim.openstreetmap.org/search?q=Moy%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 734348, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762488, 'lat': '54.4467386', 'lon': '-6.6911155', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.35815456248895494, 'addresstype': 'village', 'name': 'Moy', 'display_name': 'Moy, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT71 7SG, United Kingdom', 'boundingbox': ['54.4267386', '54.4667386', '-6.7111155', '-6.6711155']}, {'place_id': 298328767, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5457716, 'lat': '54.447367299999996', 'lon': '-6.694400703855527', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Moy', 'display_name': 'Moy, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4422852', '54.4525117', '-6.7065502', '-6.6817319']}]
# https://nominatim.openstreetmap.org/search?q=Portglenone%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 731458, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762601, 'lat': '54.8733857', 'lon': '-6.4751493', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.3919557965128309, 'addresstype': 'village', 'name': 'Portglenone', 'display_name': 'Portglenone, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 8AD, United Kingdom', 'boundingbox': ['54.8533857', '54.8933857', '-6.4951493', '-6.4551493']}]
# https://nominatim.openstreetmap.org/search?q=Cushendall%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 730887, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762535, 'lat': '55.080819', 'lon': '-6.0640644', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.39436075842802887, 'addresstype': 'village', 'name': 'Cushendall', 'display_name': 'Cushendall, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 0SQ, United Kingdom', 'boundingbox': ['55.0608190', '55.1008190', '-6.0840644', '-6.0440644']}, {'place_id': 298242760, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4272576, 'lat': '55.084232650000004', 'lon': '-6.07208282450314', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Cushendall', 'display_name': 'Cushendall, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['55.0790656', '55.0895230', '-6.0780713', '-6.0606156']}]
# https://nominatim.openstreetmap.org/search?q=Magheralin%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732222, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762827, 'lat': '54.4672237', 'lon': '-6.2611343', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.27500009999999997, 'addresstype': 'village', 'name': 'Magheralin', 'display_name': 'Magheralin, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT67 0QZ, United Kingdom', 'boundingbox': ['54.4472237', '54.4872237', '-6.2811343', '-6.2411343']}, {'place_id': 298517649, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6452104, 'lat': '54.451611099999994', 'lon': '-6.242056124673627', 'class': 'boundary', 'type': 'civil_parish', 'place_rank': 25, 'importance': 0.12500999999999995, 'addresstype': 'civil_parish', 'name': 'Magheralin', 'display_name': 'Magheralin, Moira, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.4169866', '54.4863287', '-6.3181487', '-6.1811509']}]
# https://nominatim.openstreetmap.org/search?q=Annahilt%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 738583, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762910, 'lat': '54.4377964', 'lon': '-6.0022416', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.37666439582012307, 'addresstype': 'village', 'name': 'Annahilt', 'display_name': 'Annahilt, County Down, Ulster, Northern Ireland / Tuaisceart Éireann, BT26 6BP, United Kingdom', 'boundingbox': ['54.4177964', '54.4577964', '-6.0222416', '-5.9822416']}]
# https://nominatim.openstreetmap.org/search?q=Doagh%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 3696362, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 474426563, 'lat': '54.7377917', 'lon': '-6.0429206', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.38277418428996507, 'addresstype': 'village', 'name': 'Doagh', 'display_name': 'Doagh, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT39 0QT, United Kingdom', 'boundingbox': ['54.7177917', '54.7577917', '-6.0629206', '-6.0229206']}, {'place_id': 298251829, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4478864, 'lat': '54.73947215', 'lon': '-6.036495325039478', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Doagh', 'display_name': 'Doagh, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.7275604', '54.7515417', '-6.0476737', '-6.0253093']}]
# https://nominatim.openstreetmap.org/search?q=Fivemiletown%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 733355, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762454, 'lat': '54.3784847', 'lon': '-7.3153578', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.35778439681543517, 'addresstype': 'village', 'name': 'Fivemiletown', 'display_name': 'Fivemiletown, County Tyrone, Ulster, Northern Ireland / Tuaisceart Éireann, BT75 0SB, United Kingdom', 'boundingbox': ['54.3584847', '54.3984847', '-7.3353578', '-7.2953578']}, {'place_id': 298685399, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5490392, 'lat': '54.37752015', 'lon': '-7.317370171794622', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Fivemiletown', 'display_name': 'Fivemiletown, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.3707958', '54.3844150', '-7.3265543', '-7.3089078']}]
# https://nominatim.openstreetmap.org/search?q=Dunloy%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 732124, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762740, 'lat': '55.0111673', 'lon': '-6.4111633', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.27501, 'addresstype': 'village', 'name': 'Dunloy', 'display_name': 'Dunloy, County Antrim, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 9EF, United Kingdom', 'boundingbox': ['54.9911673', '55.0311673', '-6.4311633', '-6.3911633']}, {'place_id': 298420163, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4285902, 'lat': '55.013113700000005', 'lon': '-6.400281393854392', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000009999999995, 'addresstype': 'locality', 'name': 'Dunloy', 'display_name': 'Dunloy, Ulster, Northern Ireland / Tuaisceart Éireann, BT44 9EF, United Kingdom', 'boundingbox': ['55.0027927', '55.0234537', '-6.4399350', '-6.3768092']}]
# https://nominatim.openstreetmap.org/search?q=Dundrum%20Northern%20Ireland%2C%20UK&format=json
# [{'place_id': 728075, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 267762593, 'lat': '54.2581955', 'lon': '-5.8426084', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.38363447103046244, 'addresstype': 'village', 'name': 'Dundrum', 'display_name': 'Dundrum, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, BT33 0LU, United Kingdom', 'boundingbox': ['54.2381955', '54.2781955', '-5.8626084', '-5.8226084']}, {'place_id': 298391869, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5294214, 'lat': '54.2541904', 'lon': '-6.66421371613132', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Dundrum', 'display_name': 'Dundrum, Armagh, County Armagh, Ulster, Northern Ireland / Tuaisceart Éireann, BT60 2NG, United Kingdom', 'boundingbox': ['54.2432452', '54.2651810', '-6.6738285', '-6.6541353']}, {'place_id': 298556317, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4638548, 'lat': '54.25754365', 'lon': '-5.849119563128347', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.25000999999999995, 'addresstype': 'locality', 'name': 'Dundrum', 'display_name': 'Dundrum, Newry, Mourne and Down District Council, Ulster, Northern Ireland / Tuaisceart Éireann, United Kingdom', 'boundingbox': ['54.2495579', '54.2653860', '-5.8590540', '-5.8368302']}]

# %%
places_df['lat'] = places_df['coords'].apply(lambda x: x[0])
places_df['lng'] = places_df['coords'].apply(lambda x: x[1])

# %%
places_df[['City', 'Population', 'lat', 'lng']].to_csv("/Users/finn/Documents/GitHub/RADataHub/Economic Inactivity/ni_cities.csv", index=False)

# %% [markdown]
# # Belfast Place Names

# %%
#load the geojson file
wards_df = gpd.read_file("/Users/finn/Documents/Data_Dump/ni_dea.geojson")
wards_df["lon"] = wards_df["geometry"].centroid.x
wards_df["lat"] = wards_df["geometry"].centroid.y
wards_df.rename(columns={'FINALR_DEA': 'name'}, inplace=True)
# Out:
# /var/folders/by/095_7x8j04x77vcq4_rvm1_m0000gn/T/ipykernel_13887/379356394.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   wards_df["lon"] = wards_df["geometry"].centroid.x
# /var/folders/by/095_7x8j04x77vcq4_rvm1_m0000gn/T/ipykernel_13887/379356394.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   wards_df["lat"] = wards_df["geometry"].centroid.y

# %%
belfast_wards = ['N10000301', 'N10000302', 'N10000303', 'N10000304', 'N10000305', 'N10000306', 'N10000307', 'N10000308', 'N10000309', 'N10000310']

#wards_df[wards_df.WARDNAME.apply(lambda x: len([w for w in belfast_wards if w in x])>0)]
wards_df = wards_df[wards_df.ONS_CODE.isin(belfast_wards)]

wards_df = wards_df[['name', 'ONS_CODE', 'lat', 'lon']]

# %%
wards_df.to_csv("/Users/finn/Documents/GitHub/RADataHub/Economic Inactivity/belfast_wards.csv", index=False)

# %%
wards_df[wards_df.ONS_CODE.isin(belfast_wards)]
# Out:
#               name   ONS_CODE        lat       lon
# 8         BALMORAL  N10000301  54.554062 -5.960178
# 16  BLACK MOUNTAIN  N10000302  54.590505 -6.006519
# 17         BOTANIC  N10000303  54.581114 -5.938166
# 21          CASTLE  N10000304  54.633818 -5.925555
# 28          COLLIN  N10000305  54.560418 -6.022616
# 31           COURT  N10000306  54.608990 -5.978362
# 56   LISNASHARRAGH  N10000307  54.575236 -5.891728
# 64         OLDPARK  N10000308  54.629515 -5.976764
# 66        ORMISTON  N10000309  54.597079 -5.845458
# 76         TITANIC  N10000310  54.610446 -5.886680

# %%
wards_df[wards_df.WARDNAME.str.contains('Belvoir', case=False)]
# Out:
#     OBJECTID WARDNAME   WardCode  SHAPE_Length    SHAPE_Area  \
# 88        89  BELVOIR  N08000311  14491.873628  5.466012e+06
#
#                                              geometry       lon        lat
# 88  POLYGON ((-5.92388 54.56849, -5.92396 54.56850... -5.937328  54.551763

# %%
wards_df.query("'BA' in WARDNAME")
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, WARDNAME, WardCode, SHAPE_Length, SHAPE_Area, geometry, lon, lat]
# Index: []

# %%
list(dict(df.Series.value_counts()).keys())
# Out:
# ['Economically active: Employee (including full-time students)',
#  'Economically active: Self-employed (including full-time students)',
#  'Economically active: Unemployed (including full-time students)',
#  'Economically inactive: Retired',
#  'Economically inactive: Student',
#  'Economically inactive: Looking after home or family',
#  'Economically inactive: Long-term sick or disabled',
#  'Economically inactive: Other',
#  'No code required']
