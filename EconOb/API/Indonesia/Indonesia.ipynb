# %%
import pandas as pd
import numpy as np
import requests
import json 
import time
import os
from itertools import islice
from itertools import product
import itertools
import re

key = "18699dc38df444605d15278bd4ddac0f" 
key = '5a91eee05bb200a412fdddf3f53778a8'

# %% [markdown]
# # Fetching Indonesian Statistics
#
# The Indonesian Statistical Agency is <a href="https://www.bps.go.id"> Badan Pusat Statistik </a>. They have a key-gatekept api at <a href="https://webapi.bps.go.id/developer/"> webapi.bps.go.id/developer/ </a>

# %% [markdown]
# ### Finding what data is available

# %% [markdown]
# Requesting tables requires a domain code. We care most about Indonesia as a whole. These can be fetched by making a call to: https://webapi.bps.go.id/v1/api/domain/type/all

# %%
domain_list_url = f'https://webapi.bps.go.id/v1/api/domain/type/all/key/{key}/'
req = requests.get(domain_list_url)

# %% [markdown]
# this returns us some json where the domains are located in 'data'

# %%
domains_json = json.loads(req.content)
for domain in domains_json['data'][1]:
    print(f" \033[1m {domain['domain_name']}\033[0m (id: {domain['domain_id']}, url: {domain['domain_url']})) ")
# Out:
#   Pusat (id: 0000, url: http://www.bps.go.id))
#   Aceh (id: 1100, url: https://aceh.bps.go.id))
#   Simeulue (id: 1101, url: https://simeuluekab.bps.go.id))
#   Aceh Singkil (id: 1102, url: https://acehsingkilkab.bps.go.id))
#   Aceh Selatan (id: 1103, url: https://acehselatankab.bps.go.id))
#   Aceh Tenggara (id: 1104, url: https://acehtenggarakab.bps.go.id))
#   Aceh Timur (id: 1105, url: https://acehtimurkab.bps.go.id))
#   Aceh Tengah (id: 1106, url: https://acehtengahkab.bps.go.id))
#   Aceh Barat (id: 1107, url: https://acehbaratkab.bps.go.id))
#   Aceh Besar (id: 1108, url: https://acehbesarkab.bps.go.id))
#   Pidie (id: 1109, url: https://pidiekab.bps.go.id))
#   Bireuen (id: 1110, url: https://bireuenkab.bps.go.id))
#   Aceh Utara (id: 1111, url: https://acehutarakab.bps.go.id))
#   Aceh Barat Daya (id: 1112, url: https://acehbaratdayakab.bps.go.id))
#   Gayo Lues (id: 1113, url: https://gayolueskab.bps.go.id))
#   Aceh Tamiang (id: 1114, url: https://acehtamiangkab.bps.go.id))
#   Nagan Raya (id: 1115, url: https://naganrayakab.bps.go.id))
#   Aceh Jaya (id: 1116, url: https://acehjayakab.bps.go.id))
#   Bener Meriah (id: 1117, url: https://benermeriahkab.bps.go.id))
#   Pidie Jaya (id: 1118, url: https://pidiejayakab.bps.go.id))
#   Banda Aceh (id: 1171, url: https://bandaacehkota.bps.go.id))
#   Sabang (id: 1172, url: https://sabangkota.bps.go.id))
#   Langsa (id: 1173, url: https://langsakota.bps.go.id))
#   Lhokseumawe (id: 1174, url: https://lhokseumawekota.bps.go.id))
#   Subulussalam (id: 1175, url: https://subulussalamkota.bps.go.id))
#   Sumatera Utara (id: 1200, url: https://sumut.bps.go.id))
#   Nias (id: 1201, url: https://niaskab.bps.go.id))
#   Mandailing Natal (id: 1202, url: https://mandailingnatalkab.bps.go.id))
#   Tapanuli Selatan (id: 1203, url: https://tapanuliselatankab.bps.go.id))
#   Tapanuli Tengah (id: 1204, url: https://tapanulitengahkab.bps.go.id))
#   Tapanuli Utara (id: 1205, url: https://tapanuliutarakab.bps.go.id))
#   Toba (id: 1206, url: https://tobakab.bps.go.id))
#   Labuhan Batu (id: 1207, url: https://labuhanbatukab.bps.go.id))
#   Asahan (id: 1208, url: https://asahankab.bps.go.id))
#   Simalungun (id: 1209, url: https://simalungunkab.bps.go.id))
#   Dairi (id: 1210, url: https://dairikab.bps.go.id))
#   Karo (id: 1211, url: https://karokab.bps.go.id))
#   Deli Serdang (id: 1212, url: https://deliserdangkab.bps.go.id))
#   Langkat (id: 1213, url: https://langkatkab.bps.go.id))
#   Nias Selatan (id: 1214, url: https://niasselatankab.bps.go.id))
#   Humbang Hasundutan (id: 1215, url: https://humbanghasundutankab.bps.go.id))
#   Pakpak Bharat (id: 1216, url: https://pakpakbharatkab.bps.go.id))
#   Samosir (id: 1217, url: https://samosirkab.bps.go.id))
#   Serdang Bedagai (id: 1218, url: https://serdangbedagaikab.bps.go.id))
#   Batu Bara (id: 1219, url: https://batubarakab.bps.go.id))
#   Padang Lawas Utara (id: 1220, url: https://palutakab.bps.go.id))
#   Padang Lawas (id: 1221, url: https://padanglawaskab.bps.go.id))
#   Labuhan Batu Selatan (id: 1222, url: https://labuhanbatuselatankab.bps.go.id))
#   Labuhan Batu Utara (id: 1223, url: https://labuhanbatuutarakab.bps.go.id))
#   Nias Utara (id: 1224, url: https://niasutarakab.bps.go.id))
#   Nias Barat (id: 1225, url: https://niasbaratkab.bps.go.id))
#   Sibolga (id: 1271, url: https://sibolgakota.bps.go.id))
#   Tanjung Balai (id: 1272, url: https://tanjungbalaikota.bps.go.id))
#   Pematang Siantar (id: 1273, url: https://siantarkota.bps.go.id))
#   Tebing Tinggi (id: 1274, url: https://tebingtinggikota.bps.go.id))
#   Medan (id: 1275, url: https://medankota.bps.go.id))
#   Binjai (id: 1276, url: https://binjaikota.bps.go.id))
#   Padangsidimpuan (id: 1277, url: https://padangsidimpuankota.bps.go.id))
#   Gunungsitoli (id: 1278, url: https://gunungsitolikota.bps.go.id))
#   Sumatera Barat (id: 1300, url: https://sumbar.bps.go.id))
#   Kepulauan Mentawai (id: 1301, url: https://mentawaikab.bps.go.id))
#   Pesisir Selatan (id: 1302, url: https://pesselkab.bps.go.id))
#   Solok (id: 1303, url: https://solokkab.bps.go.id))
#   Sijunjung (id: 1304, url: https://sijunjungkab.bps.go.id))
#   Tanah Datar (id: 1305, url: https://tanahdatarkab.bps.go.id))
#   Padang Pariaman (id: 1306, url: https://padangpariamankab.bps.go.id))
#   Agam (id: 1307, url: https://agamkab.bps.go.id))
#   Lima Puluh Kota (id: 1308, url: https://limapuluhkotakab.bps.go.id))
#   Pasaman (id: 1309, url: https://pasamankab.bps.go.id))
#   Solok Selatan (id: 1310, url: https://solokselatankab.bps.go.id))
#   Dharmasraya (id: 1311, url: https://dharmasrayakab.bps.go.id))
#   Pasaman Barat (id: 1312, url: https://pasamanbaratkab.bps.go.id))
#   Padang (id: 1371, url: https://padangkota.bps.go.id))
#   Solok (id: 1372, url: https://solokkota.bps.go.id))
#   Sawah Lunto (id: 1373, url: https://sawahluntokota.bps.go.id))
#   Padang Panjang (id: 1374, url: https://padangpanjangkota.bps.go.id))
#   Bukittinggi (id: 1375, url: https://bukittinggikota.bps.go.id))
#   Payakumbuh (id: 1376, url: https://payakumbuhkota.bps.go.id))
#   Pariaman (id: 1377, url: https://pariamankota.bps.go.id))
#   Riau (id: 1400, url: https://riau.bps.go.id))
#   Kuantan Singingi (id: 1401, url: https://kuansingkab.bps.go.id))
#   Indragiri Hulu (id: 1402, url: https://inhukab.bps.go.id))
#   Indragiri Hilir (id: 1403, url: https://inhilkab.bps.go.id))
#   Pelalawan (id: 1404, url: https://pelalawankab.bps.go.id))
#   S I A K (id: 1405, url: https://siakkab.bps.go.id))
#   Kampar (id: 1406, url: https://kamparkab.bps.go.id))
#   Rokan Hulu (id: 1407, url: https://rohulkab.bps.go.id))
#   Bengkalis (id: 1408, url: https://bengkaliskab.bps.go.id))
#   Rokan Hilir (id: 1409, url: https://rohilkab.bps.go.id))
#   Kepulauan Meranti (id: 1410, url: https://merantikab.bps.go.id))
#   Pekanbaru (id: 1471, url: https://pekanbarukota.bps.go.id))
#   D U M A I (id: 1473, url: https://dumaikota.bps.go.id))
#   Jambi (id: 1500, url: https://jambi.bps.go.id))
#   Kerinci (id: 1501, url: https://kerincikab.bps.go.id))
#   Merangin (id: 1502, url: https://meranginkab.bps.go.id))
#   Sarolangun (id: 1503, url: https://sarolangunkab.bps.go.id))
#   Batang Hari (id: 1504, url: https://batangharikab.bps.go.id))
#   Muaro Jambi (id: 1505, url: https://muarojambikab.bps.go.id))
#   Tanjung Jabung Timur (id: 1506, url: https://tanjabtimkab.bps.go.id))
#   Tanjung Jabung Barat (id: 1507, url: https://tanjabbarkab.bps.go.id))
#   Tebo (id: 1508, url: https://tebokab.bps.go.id))
#   Bungo (id: 1509, url: https://bungokab.bps.go.id))
#   Jambi (id: 1571, url: https://jambikota.bps.go.id))
#   Sungai Penuh (id: 1572, url: https://sungaipenuhkota.bps.go.id))
#   Sumatera Selatan (id: 1600, url: https://sumsel.bps.go.id))
#   Ogan Komering Ulu (id: 1601, url: https://okukab.bps.go.id))
#   Ogan Komering Ilir (id: 1602, url: https://okikab.bps.go.id))
#   Muara Enim (id: 1603, url: https://muaraenimkab.bps.go.id))
#   Lahat (id: 1604, url: https://lahatkab.bps.go.id))
#   Musi Rawas (id: 1605, url: https://musirawaskab.bps.go.id))
#   Musi Banyuasin (id: 1606, url: https://musibanyuasinkab.bps.go.id))
#   Banyu Asin (id: 1607, url: https://banyuasinkab.bps.go.id))
#   Ogan Komering Ulu Selatan (id: 1608, url: https://okuselatankab.bps.go.id))
#   Ogan Komering Ulu Timur (id: 1609, url: https://okutimurkab.bps.go.id))
#   Ogan Ilir (id: 1610, url: https://oganilirkab.bps.go.id))
#   Empat Lawang (id: 1611, url: https://empatlawangkab.bps.go.id))
#   Penukal Abab Lematang Ilir (id: 1612, url: https://palikab.bps.go.id))
#   Musi Rawas Utara (id: 1613, url: https://muratarakab.bps.go.id))
#   Palembang (id: 1671, url: https://palembangkota.bps.go.id))
#   Prabumulih (id: 1672, url: https://prabumulihkota.bps.go.id))
#   Pagar Alam (id: 1673, url: https://pagaralamkota.bps.go.id))
#   Lubuklinggau (id: 1674, url: https://lubuklinggaukota.bps.go.id))
#   Bengkulu (id: 1700, url: https://bengkulu.bps.go.id))
#   Bengkulu Selatan (id: 1701, url: https://bengkuluselatankab.bps.go.id))
#   Rejang Lebong (id: 1702, url: https://rejanglebongkab.bps.go.id))
#   Bengkulu Utara (id: 1703, url: https://bengkuluutarakab.bps.go.id))
#   Kaur (id: 1704, url: https://kaurkab.bps.go.id))
#   Seluma (id: 1705, url: https://selumakab.bps.go.id))
#   Mukomuko (id: 1706, url: https://mukomukokab.bps.go.id))
#   Lebong (id: 1707, url: https://lebongkab.bps.go.id))
#   Kepahiang (id: 1708, url: https://kepahiangkab.bps.go.id))
#   Bengkulu Tengah (id: 1709, url: https://bengkulutengahkab.bps.go.id))
#   Bengkulu (id: 1771, url: https://bengkulukota.bps.go.id))
#   Lampung (id: 1800, url: https://lampung.bps.go.id))
#   Lampung Barat (id: 1801, url: https://lampungbaratkab.bps.go.id))
#   Tanggamus (id: 1802, url: https://tanggamuskab.bps.go.id))
#   Lampung Selatan (id: 1803, url: https://lampungselatankab.bps.go.id))
#   Lampung Timur (id: 1804, url: https://lampungtimurkab.bps.go.id))
#   Lampung Tengah (id: 1805, url: https://lampungtengahkab.bps.go.id))
#   Lampung Utara (id: 1806, url: https://lampungutarakab.bps.go.id))
#   Way Kanan (id: 1807, url: https://waykanankab.bps.go.id))
#   Tulangbawang (id: 1808, url: https://tulangbawangkab.bps.go.id))
#   Pesawaran (id: 1809, url: https://pesawarankab.bps.go.id))
#   Pringsewu (id: 1810, url: https://pringsewukab.bps.go.id))
#   Mesuji (id: 1811, url: https://mesujikab.bps.go.id))
#   Tulang Bawang Barat (id: 1812, url: https://tulangbawangbaratkab.bps.go.id))
#   Pesisir Barat (id: 1813, url: https://pesisirbaratkab.bps.go.id))
#   Bandar Lampung (id: 1871, url: https://bandarlampungkota.bps.go.id))
#   Metro (id: 1872, url: https://metrokota.bps.go.id))
#   Kep. Bangka Belitung (id: 1900, url: https://babel.bps.go.id))
#   Bangka (id: 1901, url: https://bangkakab.bps.go.id))
#   Belitung (id: 1902, url: https://belitungkab.bps.go.id))
#   Bangka Barat (id: 1903, url: https://bangkabaratkab.bps.go.id))
#   Bangka Tengah (id: 1904, url: https://bangkatengahkab.bps.go.id))
#   Bangka Selatan (id: 1905, url: https://bangkaselatankab.bps.go.id))
#   Belitung Timur (id: 1906, url: https://belitungtimurkab.bps.go.id))
#   Pangkal Pinang (id: 1971, url: https://pangkalpinangkota.bps.go.id))
#   Kep. Riau (id: 2100, url: https://kepri.bps.go.id))
#   Karimun (id: 2101, url: https://karimunkab.bps.go.id))
#   Bintan (id: 2102, url: https://bintankab.bps.go.id))
#   Natuna (id: 2103, url: https://natunakab.bps.go.id))
#   Lingga (id: 2104, url: https://linggakab.bps.go.id))
#   Kepulauan Anambas (id: 2105, url: https://anambaskab.bps.go.id))
#   B A T A M (id: 2171, url: https://batamkota.bps.go.id))
#   Tanjung Pinang (id: 2172, url: https://tanjungpinangkota.bps.go.id))
#   Dki Jakarta (id: 3100, url: https://jakarta.bps.go.id))
#   Kepulauan Seribu (id: 3101, url: https://kepulauanseribukab.bps.go.id))
#   Jakarta Selatan (id: 3171, url: https://jakselkota.bps.go.id))
#   Jakarta Timur (id: 3172, url: https://jaktimkota.bps.go.id))
#   Jakarta Pusat (id: 3173, url: https://jakpuskota.bps.go.id))
#   Jakarta Barat (id: 3174, url: https://jakbarkota.bps.go.id))
#   Jakarta Utara (id: 3175, url: https://jakutkota.bps.go.id))
#   Jawa Barat (id: 3200, url: https://jabar.bps.go.id))
#   Bogor (id: 3201, url: https://bogorkab.bps.go.id))
#   Sukabumi (id: 3202, url: https://sukabumikab.bps.go.id))
#   Cianjur (id: 3203, url: https://cianjurkab.bps.go.id))
#   Bandung (id: 3204, url: https://bandungkab.bps.go.id))
#   Garut (id: 3205, url: https://garutkab.bps.go.id))
#   Tasikmalaya (id: 3206, url: https://tasikmalayakab.bps.go.id))
#   Ciamis (id: 3207, url: https://ciamiskab.bps.go.id))
#   Kuningan (id: 3208, url: https://kuningankab.bps.go.id))
#   Cirebon (id: 3209, url: https://cirebonkab.bps.go.id))
#   Majalengka (id: 3210, url: https://majalengkakab.bps.go.id))
#   Sumedang (id: 3211, url: https://sumedangkab.bps.go.id))
#   Indramayu (id: 3212, url: https://indramayukab.bps.go.id))
#   Subang (id: 3213, url: https://subangkab.bps.go.id))
#   Purwakarta (id: 3214, url: https://purwakartakab.bps.go.id))
#   Karawang (id: 3215, url: https://karawangkab.bps.go.id))
#   Bekasi (id: 3216, url: https://bekasikab.bps.go.id))
#   Bandung Barat (id: 3217, url: https://bandungbaratkab.bps.go.id))
#   Pangandaran (id: 3218, url: https://pangandarankab.bps.go.id))
#   Bogor (id: 3271, url: https://bogorkota.bps.go.id))
#   Sukabumi (id: 3272, url: https://sukabumikota.bps.go.id))
#   Bandung (id: 3273, url: https://bandungkota.bps.go.id))
#   Cirebon (id: 3274, url: https://cirebonkota.bps.go.id))
#   Bekasi (id: 3275, url: https://bekasikota.bps.go.id))
#   Depok (id: 3276, url: https://depokkota.bps.go.id))
#   Cimahi (id: 3277, url: https://cimahikota.bps.go.id))
#   Tasikmalaya (id: 3278, url: https://tasikmalayakota.bps.go.id))
#   Banjar (id: 3279, url: https://banjarkota.bps.go.id))
#   Jawa Tengah (id: 3300, url: https://jateng.bps.go.id))
#   Cilacap (id: 3301, url: https://cilacapkab.bps.go.id))
#   Banyumas (id: 3302, url: https://banyumaskab.bps.go.id))
#   Purbalingga (id: 3303, url: https://purbalinggakab.bps.go.id))
#   Banjarnegara (id: 3304, url: https://banjarnegarakab.bps.go.id))
#   Kebumen (id: 3305, url: https://kebumenkab.bps.go.id))
#   Purworejo (id: 3306, url: https://purworejokab.bps.go.id))
#   Wonosobo (id: 3307, url: https://wonosobokab.bps.go.id))
#   Magelang (id: 3308, url: https://magelangkab.bps.go.id))
#   Boyolali (id: 3309, url: https://boyolalikab.bps.go.id))
#   Klaten (id: 3310, url: https://klatenkab.bps.go.id))
#   Sukoharjo (id: 3311, url: https://sukoharjokab.bps.go.id))
#   Wonogiri (id: 3312, url: https://wonogirikab.bps.go.id))
#   Karanganyar (id: 3313, url: https://karanganyarkab.bps.go.id))
#   Sragen (id: 3314, url: https://sragenkab.bps.go.id))
#   Grobogan (id: 3315, url: https://grobogankab.bps.go.id))
#   Blora (id: 3316, url: https://blorakab.bps.go.id))
#   Rembang (id: 3317, url: https://rembangkab.bps.go.id))
#   Pati (id: 3318, url: https://patikab.bps.go.id))
#   Kudus (id: 3319, url: https://kuduskab.bps.go.id))
#   Jepara (id: 3320, url: https://jeparakab.bps.go.id))
#   Demak (id: 3321, url: https://demakkab.bps.go.id))
#   Semarang (id: 3322, url: https://semarangkab.bps.go.id))
#   Temanggung (id: 3323, url: https://temanggungkab.bps.go.id))
#   Kendal (id: 3324, url: https://kendalkab.bps.go.id))
#   Batang (id: 3325, url: https://batangkab.bps.go.id))
#   Pekalongan (id: 3326, url: https://pekalongankab.bps.go.id))
#   Pemalang (id: 3327, url: https://pemalangkab.bps.go.id))
#   Tegal (id: 3328, url: https://tegalkab.bps.go.id))
#   Brebes (id: 3329, url: https://brebeskab.bps.go.id))
#   Magelang (id: 3371, url: https://magelangkota.bps.go.id))
#   Surakarta (id: 3372, url: https://surakartakota.bps.go.id))
#   Salatiga (id: 3373, url: https://salatigakota.bps.go.id))
#   Semarang (id: 3374, url: https://semarangkota.bps.go.id))
#   Pekalongan (id: 3375, url: https://pekalongankota.bps.go.id))
#   Tegal (id: 3376, url: https://tegalkota.bps.go.id))
#   Di Yogyakarta (id: 3400, url: https://yogyakarta.bps.go.id))
#   Kulon Progo (id: 3401, url: https://kulonprogokab.bps.go.id))
#   Bantul (id: 3402, url: https://bantulkab.bps.go.id))
#   Gunung Kidul (id: 3403, url: https://gunungkidulkab.bps.go.id))
#   Sleman (id: 3404, url: https://slemankab.bps.go.id))
#   Yogyakarta (id: 3471, url: https://jogjakota.bps.go.id))
#   Jawa Timur (id: 3500, url: https://jatim.bps.go.id))
#   Pacitan (id: 3501, url: https://pacitankab.bps.go.id))
#   Ponorogo (id: 3502, url: https://ponorogokab.bps.go.id))
#   Trenggalek (id: 3503, url: https://trenggalekkab.bps.go.id))
#   Tulungagung (id: 3504, url: https://tulungagungkab.bps.go.id))
#   Blitar (id: 3505, url: https://blitarkab.bps.go.id))
#   Kediri (id: 3506, url: https://kedirikab.bps.go.id))
#   Malang (id: 3507, url: https://malangkab.bps.go.id))
#   Lumajang (id: 3508, url: https://lumajangkab.bps.go.id))
#   Jember (id: 3509, url: https://jemberkab.bps.go.id))
#   Banyuwangi (id: 3510, url: https://banyuwangikab.bps.go.id))
#   Bondowoso (id: 3511, url: https://bondowosokab.bps.go.id))
#   Situbondo (id: 3512, url: https://situbondokab.bps.go.id))
#   Probolinggo (id: 3513, url: https://probolinggokab.bps.go.id))
#   Pasuruan (id: 3514, url: https://pasuruankab.bps.go.id))
#   Sidoarjo (id: 3515, url: https://sidoarjokab.bps.go.id))
#   Mojokerto (id: 3516, url: https://mojokertokab.bps.go.id))
#   Jombang (id: 3517, url: https://jombangkab.bps.go.id))
#   Nganjuk (id: 3518, url: https://nganjukkab.bps.go.id))
#   Madiun (id: 3519, url: https://madiunkab.bps.go.id))
#   Magetan (id: 3520, url: https://magetankab.bps.go.id))
#   Ngawi (id: 3521, url: https://ngawikab.bps.go.id))
#   Bojonegoro (id: 3522, url: https://bojonegorokab.bps.go.id))
#   Tuban (id: 3523, url: https://tubankab.bps.go.id))
#   Lamongan (id: 3524, url: https://lamongankab.bps.go.id))
#   Gresik (id: 3525, url: https://gresikkab.bps.go.id))
#   Bangkalan (id: 3526, url: https://bangkalankab.bps.go.id))
#   Sampang (id: 3527, url: https://sampangkab.bps.go.id))
#   Pamekasan (id: 3528, url: https://pamekasankab.bps.go.id))
#   Sumenep (id: 3529, url: https://sumenepkab.bps.go.id))
#   Kediri (id: 3571, url: https://kedirikota.bps.go.id))
#   Blitar (id: 3572, url: https://blitarkota.bps.go.id))
#   Malang (id: 3573, url: https://malangkota.bps.go.id))
#   Probolinggo (id: 3574, url: https://probolinggokota.bps.go.id))
#   Pasuruan (id: 3575, url: https://pasuruankota.bps.go.id))
#   Mojokerto (id: 3576, url: https://mojokertokota.bps.go.id))
#   Madiun (id: 3577, url: https://madiunkota.bps.go.id))
#   Surabaya (id: 3578, url: https://surabayakota.bps.go.id))
#   Batu (id: 3579, url: https://batukota.bps.go.id))
#   Banten (id: 3600, url: https://banten.bps.go.id))
#   Pandeglang (id: 3601, url: https://pandeglangkab.bps.go.id))
#   Lebak (id: 3602, url: https://lebakkab.bps.go.id))
#   Tangerang (id: 3603, url: https://tangerangkab.bps.go.id))
#   Serang (id: 3604, url: https://serangkab.bps.go.id))
#   Tangerang (id: 3671, url: https://tangerangkota.bps.go.id))
#   Cilegon (id: 3672, url: https://cilegonkota.bps.go.id))
#   Serang (id: 3673, url: https://serangkota.bps.go.id))
#   Tangerang Selatan (id: 3674, url: https://tangselkota.bps.go.id))
#   Bali (id: 5100, url: https://bali.bps.go.id))
#   Jembrana (id: 5101, url: https://jembranakab.bps.go.id))
#   Tabanan (id: 5102, url: https://tabanankab.bps.go.id))
#   Badung (id: 5103, url: https://badungkab.bps.go.id))
#   Gianyar (id: 5104, url: https://gianyarkab.bps.go.id))
#   Klungkung (id: 5105, url: https://klungkungkab.bps.go.id))
#   Bangli (id: 5106, url: https://banglikab.bps.go.id))
#   Karang Asem (id: 5107, url: https://karangasemkab.bps.go.id))
#   Buleleng (id: 5108, url: https://bulelengkab.bps.go.id))
#   Denpasar (id: 5171, url: https://denpasarkota.bps.go.id))
#   Nusa Tenggara Barat (id: 5200, url: https://ntb.bps.go.id))
#   Lombok Barat (id: 5201, url: https://lombokbaratkab.bps.go.id))
#   Lombok Tengah (id: 5202, url: https://lomboktengahkab.bps.go.id))
#   Lombok Timur (id: 5203, url: https://lomboktimurkab.bps.go.id))
#   Sumbawa (id: 5204, url: https://sumbawakab.bps.go.id))
#   Dompu (id: 5205, url: https://dompukab.bps.go.id))
#   Bima (id: 5206, url: https://bimakab.bps.go.id))
#   Sumbawa Barat (id: 5207, url: https://sumbawabaratkab.bps.go.id))
#   Lombok Utara (id: 5208, url: https://lombokutarakab.bps.go.id))
#   Mataram (id: 5271, url: https://mataramkota.bps.go.id))
#   Bima (id: 5272, url: https://bimakota.bps.go.id))
#   Nusa Tenggara Timur (id: 5300, url: https://ntt.bps.go.id))
#   Sumba Barat (id: 5301, url: https://sumbabaratkab.bps.go.id))
#   Sumba Timur (id: 5302, url: https://sumbatimurkab.bps.go.id))
#   Kupang (id: 5303, url: https://kupangkab.bps.go.id))
#   Timor Tengah Selatan (id: 5304, url: https://timortengahselatankab.bps.go.id))
#   Timor Tengah Utara (id: 5305, url: https://timortengahutarakab.bps.go.id))
#   Belu (id: 5306, url: https://belukab.bps.go.id))
#   Alor (id: 5307, url: https://alorkab.bps.go.id))
#   Lembata (id: 5308, url: https://lembatakab.bps.go.id))
#   Flores Timur (id: 5309, url: https://florestimurkab.bps.go.id))
#   Sikka (id: 5310, url: https://sikkakab.bps.go.id))
#   Ende (id: 5311, url: https://endekab.bps.go.id))
#   Ngada (id: 5312, url: https://ngadakab.bps.go.id))
#   Manggarai (id: 5313, url: https://manggaraikab.bps.go.id))
#   Rote Ndao (id: 5314, url: https://rotendaokab.bps.go.id))
#   Manggarai Barat (id: 5315, url: https://manggaraibaratkab.bps.go.id))
#   Sumba Tengah (id: 5316, url: https://sumbatengahkab.bps.go.id))
#   Sumba Barat Daya (id: 5317, url: https://sumbabaratdayakab.bps.go.id))
#   Nagekeo (id: 5318, url: https://nagekeokab.bps.go.id))
#   Manggarai Timur (id: 5319, url: https://manggaraitimurkab.bps.go.id))
#   Sabu Raijua (id: 5320, url: https://saburaijuakab.bps.go.id))
#   Malaka (id: 5321, url: https://malakakab.bps.go.id))
#   Kupang (id: 5371, url: https://kupangkota.bps.go.id))
#   Kalimantan Barat (id: 6100, url: https://kalbar.bps.go.id))
#   Sambas (id: 6101, url: https://sambaskab.bps.go.id))
#   Bengkayang (id: 6102, url: https://bengkayangkab.bps.go.id))
#   Landak (id: 6103, url: https://landakkab.bps.go.id))
#   Mempawah (id: 6104, url: https://mempawahkab.bps.go.id))
#   Sanggau (id: 6105, url: https://sanggaukab.bps.go.id))
#   Ketapang (id: 6106, url: https://ketapangkab.bps.go.id))
#   Sintang (id: 6107, url: https://sintangkab.bps.go.id))
#   Kapuas Hulu (id: 6108, url: https://kapuashulukab.bps.go.id))
#   Sekadau (id: 6109, url: https://sekadaukab.bps.go.id))
#   Melawi (id: 6110, url: https://melawikab.bps.go.id))
#   Kayong Utara (id: 6111, url: https://kayongutarakab.bps.go.id))
#   Kubu Raya (id: 6112, url: https://kuburayakab.bps.go.id))
#   Pontianak (id: 6171, url: https://pontianakkota.bps.go.id))
#   Singkawang (id: 6172, url: https://singkawangkota.bps.go.id))
#   Kalimantan Tengah (id: 6200, url: https://kalteng.bps.go.id))
#   Kotawaringin Barat (id: 6201, url: https://kobarkab.bps.go.id))
#   Kotawaringin Timur (id: 6202, url: https://kotimkab.bps.go.id))
#   Kapuas (id: 6203, url: https://kapuaskab.bps.go.id))
#   Barito Selatan (id: 6204, url: https://barselkab.bps.go.id))
#   Barito Utara (id: 6205, url: https://barutkab.bps.go.id))
#   Sukamara (id: 6206, url: https://sukamarakab.bps.go.id))
#   Lamandau (id: 6207, url: https://lamandaukab.bps.go.id))
#   Seruyan (id: 6208, url: https://seruyankab.bps.go.id))
#   Katingan (id: 6209, url: https://katingankab.bps.go.id))
#   Pulang Pisau (id: 6210, url: https://pulpiskab.bps.go.id))
#   Gunung Mas (id: 6211, url: https://gumaskab.bps.go.id))
#   Barito Timur (id: 6212, url: https://bartimkab.bps.go.id))
#   Murung Raya (id: 6213, url: https://murakab.bps.go.id))
#   Palangka Raya (id: 6271, url: https://palangkakota.bps.go.id))
#   Kalimantan Selatan (id: 6300, url: https://kalsel.bps.go.id))
#   Tanah Laut (id: 6301, url: https://tanahlautkab.bps.go.id))
#   Kota Baru (id: 6302, url: https://kotabarukab.bps.go.id))
#   Banjar (id: 6303, url: https://banjarkab.bps.go.id))
#   Barito Kuala (id: 6304, url: https://baritokualakab.bps.go.id))
#   Tapin (id: 6305, url: https://tapinkab.bps.go.id))
#   Hulu Sungai Selatan (id: 6306, url: https://hulusungaiselatankab.bps.go.id))
#   Hulu Sungai Tengah (id: 6307, url: https://hulusungaitengahkab.bps.go.id))
#   Hulu Sungai Utara (id: 6308, url: https://hulusungaiutarakab.bps.go.id))
#   Tabalong (id: 6309, url: https://tabalongkab.bps.go.id))
#   Tanah Bumbu (id: 6310, url: https://tanahbumbukab.bps.go.id))
#   Balangan (id: 6311, url: https://balangankab.bps.go.id))
#   Banjarmasin (id: 6371, url: https://banjarmasinkota.bps.go.id))
#   Banjar Baru (id: 6372, url: https://banjarbarukota.bps.go.id))
#   Kalimantan Timur (id: 6400, url: https://kaltim.bps.go.id))
#   Paser (id: 6401, url: https://paserkab.bps.go.id))
#   Kutai Barat (id: 6402, url: https://kubarkab.bps.go.id))
#   Kutai Kartanegara (id: 6403, url: https://kukarkab.bps.go.id))
#   Kutai Timur (id: 6404, url: https://kutimkab.bps.go.id))
#   Berau (id: 6405, url: https://beraukab.bps.go.id))
#   Penajam Paser Utara (id: 6409, url: https://ppukab.bps.go.id))
#   Mahakam Hulu (id: 6411, url: https://mahulukab.bps.go.id))
#   Balikpapan (id: 6471, url: https://balikpapankota.bps.go.id))
#   Samarinda (id: 6472, url: https://samarindakota.bps.go.id))
#   Bontang (id: 6474, url: https://bontangkota.bps.go.id))
#   Kalimantan Utara (id: 6500, url: https://kaltara.bps.go.id))
#   Malinau (id: 6501, url: https://malinaukab.bps.go.id))
#   Bulungan (id: 6502, url: https://bulungankab.bps.go.id))
#   Tana Tidung (id: 6503, url: https://tanatidungkab.bps.go.id))
#   Nunukan (id: 6504, url: https://nunukankab.bps.go.id))
#   Tarakan (id: 6571, url: https://tarakankota.bps.go.id))
#   Sulawesi Utara (id: 7100, url: https://sulut.bps.go.id))
#   Bolaang Mongondow (id: 7101, url: https://bolmongkab.bps.go.id))
#   Minahasa (id: 7102, url: https://minahasakab.bps.go.id))
#   Kepulauan Sangihe (id: 7103, url: https://sangihekab.bps.go.id))
#   Kepulauan Talaud (id: 7104, url: https://talaudkab.bps.go.id))
#   Minahasa Selatan (id: 7105, url: https://minselkab.bps.go.id))
#   Minahasa Utara (id: 7106, url: https://minutkab.bps.go.id))
#   Bolaang Mongondow Utara (id: 7107, url: https://bolmutkab.bps.go.id))
#   Siau Tagulandang Biaro (id: 7108, url: https://sitarokab.bps.go.id))
#   Minahasa Tenggara (id: 7109, url: https://mitrakab.bps.go.id))
#   Bolaang Mongondow Selatan (id: 7110, url: https://bolselkab.bps.go.id))
#   Bolaang Mongondow Timur (id: 7111, url: https://boltimkab.bps.go.id))
#   Manado (id: 7171, url: https://manadokota.bps.go.id))
#   Bitung (id: 7172, url: https://bitungkota.bps.go.id))
#   Tomohon (id: 7173, url: https://tomohonkota.bps.go.id))
#   Kotamobagu (id: 7174, url: https://kotamobagukota.bps.go.id))
#   Sulawesi Tengah (id: 7200, url: https://sulteng.bps.go.id))
#   Banggai Kepulauan (id: 7201, url: https://bangkepkab.bps.go.id))
#   Banggai (id: 7202, url: https://banggaikab.bps.go.id))
#   Morowali (id: 7203, url: https://morowalikab.bps.go.id))
#   Poso (id: 7204, url: https://posokab.bps.go.id))
#   Donggala (id: 7205, url: https://donggalakab.bps.go.id))
#   Toli-Toli (id: 7206, url: https://tolitolikab.bps.go.id))
#   Buol (id: 7207, url: https://buolkab.bps.go.id))
#   Parigi Moutong (id: 7208, url: https://parigimoutongkab.bps.go.id))
#   Tojo Una-Una (id: 7209, url: https://tojounakab.bps.go.id))
#   Sigi (id: 7210, url: https://sigikab.bps.go.id))
#   Banggai Laut (id: 7211, url: https://banggailautkab.bps.go.id))
#   Morowali Utara (id: 7212, url: https://morowaliutarakab.bps.go.id))
#   Palu (id: 7271, url: https://palukota.bps.go.id))
#   Sulawesi Selatan (id: 7300, url: https://sulsel.bps.go.id))
#   Kepulauan Selayar (id: 7301, url: https://selayarkab.bps.go.id))
#   Bulukumba (id: 7302, url: https://bulukumbakab.bps.go.id))
#   Bantaeng (id: 7303, url: https://bantaengkab.bps.go.id))
#   Jeneponto (id: 7304, url: https://jenepontokab.bps.go.id))
#   Takalar (id: 7305, url: https://takalarkab.bps.go.id))
#   Gowa (id: 7306, url: https://gowakab.bps.go.id))
#   Sinjai (id: 7307, url: https://sinjaikab.bps.go.id))
#   Maros (id: 7308, url: https://maroskab.bps.go.id))
#   Pangkajene Dan Kepulauan (id: 7309, url: https://pangkepkab.bps.go.id))
#   Barru (id: 7310, url: https://barrukab.bps.go.id))
#   Bone (id: 7311, url: https://bonekab.bps.go.id))
#   Soppeng (id: 7312, url: https://soppengkab.bps.go.id))
#   Wajo (id: 7313, url: https://wajokab.bps.go.id))
#   Sidenreng Rappang (id: 7314, url: https://sidrapkab.bps.go.id))
#   Pinrang (id: 7315, url: https://pinrangkab.bps.go.id))
#   Enrekang (id: 7316, url: https://enrekangkab.bps.go.id))
#   Luwu (id: 7317, url: https://luwukab.bps.go.id))
#   Tana Toraja (id: 7318, url: https://tatorkab.bps.go.id))
#   Luwu Utara (id: 7322, url: https://luwuutarakab.bps.go.id))
#   Luwu Timur (id: 7325, url: https://luwutimurkab.bps.go.id))
#   Toraja Utara (id: 7326, url: https://torutkab.bps.go.id))
#   Makassar (id: 7371, url: https://makassarkota.bps.go.id))
#   Parepare (id: 7372, url: https://pareparekota.bps.go.id))
#   Palopo (id: 7373, url: https://palopokota.bps.go.id))
#   Sulawesi Tenggara (id: 7400, url: https://sultra.bps.go.id))
#   Buton (id: 7401, url: https://butonkab.bps.go.id))
#   Muna (id: 7402, url: https://munakab.bps.go.id))
#   Konawe (id: 7403, url: https://konawekab.bps.go.id))
#   Kolaka (id: 7404, url: https://kolakakab.bps.go.id))
#   Konawe Selatan (id: 7405, url: https://konselkab.bps.go.id))
#   Bombana (id: 7406, url: https://bombanakab.bps.go.id))
#   Wakatobi (id: 7407, url: https://wakatobikab.bps.go.id))
#   Kolaka Utara (id: 7408, url: https://kolutkab.bps.go.id))
#   Buton Utara (id: 7409, url: https://buturkab.bps.go.id))
#   Konawe Utara (id: 7410, url: https://konutkab.bps.go.id))
#   Kolaka Timur (id: 7411, url: https://koltimkab.bps.go.id))
#   Konawe Kepulauan (id: 7412, url: https://konkepkab.bps.go.id))
#   Muna Barat (id: 7413, url: https://munbarkab.bps.go.id))
#   Buton Tengah (id: 7414, url: https://butengkab.bps.go.id))
#   Buton Selatan (id: 7415, url: https://buselkab.bps.go.id))
#   Kendari (id: 7471, url: https://kendarikota.bps.go.id))
#   Baubau (id: 7472, url: https://baubaukota.bps.go.id))
#   Gorontalo (id: 7500, url: https://gorontalo.bps.go.id))
#   Boalemo (id: 7501, url: https://boalemokab.bps.go.id))
#   Gorontalo (id: 7502, url: https://gorontalokab.bps.go.id))
#   Pohuwato (id: 7503, url: https://pohuwatokab.bps.go.id))
#   Bone Bolango (id: 7504, url: https://bonebolangokab.bps.go.id))
#   Gorontalo Utara (id: 7505, url: https://gorontaloutarakab.bps.go.id))
#   Gorontalo (id: 7571, url: https://gorontalokota.bps.go.id))
#   Sulawesi Barat (id: 7600, url: https://sulbar.bps.go.id))
#   Majene (id: 7601, url: https://majenekab.bps.go.id))
#   Polewali Mandar (id: 7602, url: https://polewalimandarkab.bps.go.id))
#   Mamasa (id: 7603, url: https://mamasakab.bps.go.id))
#   Mamuju (id: 7604, url: https://mamujukab.bps.go.id))
#   Mamuju Utara (id: 7605, url: https://mamujuutarakab.bps.go.id))
#   Mamuju Tengah (id: 7606, url: https://mamujutengahkab.bps.go.id))
#   Maluku (id: 8100, url: https://maluku.bps.go.id))
#   Maluku Tenggara Barat (id: 8101, url: https://mtbkab.bps.go.id))
#   Maluku Tenggara (id: 8102, url: https://malukutenggarakab.bps.go.id))
#   Maluku Tengah (id: 8103, url: https://malukutengahkab.bps.go.id))
#   Buru (id: 8104, url: https://burukab.bps.go.id))
#   Kepulauan Aru (id: 8105, url: https://keparukab.bps.go.id))
#   Seram Bagian Barat (id: 8106, url: https://sbbkab.bps.go.id))
#   Seram Bagian Timur (id: 8107, url: https://sbtkab.bps.go.id))
#   Maluku Barat Daya (id: 8108, url: https://malukubaratdayakab.bps.go.id))
#   Buru Selatan (id: 8109, url: https://burselkab.bps.go.id))
#   Ambon (id: 8171, url: https://ambonkota.bps.go.id))
#   Tual (id: 8172, url: https://tualkota.bps.go.id))
#   Maluku Utara (id: 8200, url: https://malut.bps.go.id))
#   Halmahera Barat (id: 8201, url: https://halbarkab.bps.go.id))
#   Halmahera Tengah (id: 8202, url: https://haltengkab.bps.go.id))
#   Kepulauan Sula (id: 8203, url: https://kepsulkab.bps.go.id))
#   Halmahera Selatan (id: 8204, url: https://halmaheraselatankab.bps.go.id))
#   Halmahera Utara (id: 8205, url: https://halutkab.bps.go.id))
#   Halmahera Timur (id: 8206, url: https://haltimkab.bps.go.id))
#   Pulau Morotai (id: 8207, url: https://morotaikab.bps.go.id))
#   Pulau Taliabu (id: 8208, url: https://taliabukab.bps.go.id))
#   Ternate (id: 8271, url: https://ternatekota.bps.go.id))
#   Tidore Kepulauan (id: 8272, url: https://tikepkota.bps.go.id))
#   Papua Barat (id: 9100, url: https://papuabarat.bps.go.id))
#   Fakfak (id: 9101, url: https://fakfakkab.bps.go.id))
#   Kaimana (id: 9102, url: https://kaimanakab.bps.go.id))
#   Teluk Wondama (id: 9103, url: https://telukwondamakab.bps.go.id))
#   Teluk Bintuni (id: 9104, url: https://telukbintunikab.bps.go.id))
#   Manokwari (id: 9105, url: https://manokwarikab.bps.go.id))
#   Sorong Selatan (id: 9106, url: https://sorongselatankab.bps.go.id))
#   Sorong (id: 9107, url: https://sorongkab.bps.go.id))
#   Raja Ampat (id: 9108, url: https://rajaampatkab.bps.go.id))
#   Tambrauw (id: 9109, url: https://tambrauwkab.bps.go.id))
#   Maybrat (id: 9110, url: https://maybratkab.bps.go.id))
#   Manokwari Selatan (id: 9111, url: https://manokwariselatankab.bps.go.id))
#   Pegunungan Arfak (id: 9112, url: https://pegununganarfakkab.bps.go.id))
#   Sorong (id: 9171, url: https://sorongkota.bps.go.id))
#   Papua (id: 9400, url: https://papua.bps.go.id))
#   Merauke (id: 9401, url: https://meraukekab.bps.go.id))
#   Jayawijaya (id: 9402, url: https://jayawijayakab.bps.go.id))
#   Jayapura (id: 9403, url: https://jayapurakab.bps.go.id))
#   Nabire (id: 9404, url: https://nabirekab.bps.go.id))
#   Kepulauan Yapen (id: 9408, url: https://kepulauanyapenkab.bps.go.id))
#   Biak Numfor (id: 9409, url: https://biaknumforkab.bps.go.id))
#   Paniai (id: 9410, url: https://paniaikab.bps.go.id))
#   Puncak Jaya (id: 9411, url: https://puncakjayakab.bps.go.id))
#   Mimika (id: 9412, url: https://mimikakab.bps.go.id))
#   Boven Digoel (id: 9413, url: https://bovendigoelkab.bps.go.id))
#   Mappi (id: 9414, url: https://mappikab.bps.go.id))
#   Asmat (id: 9415, url: https://asmatkab.bps.go.id))
#   Yahukimo (id: 9416, url: https://yahukimokab.bps.go.id))
#   Pegunungan Bintang (id: 9417, url: https://pegununganbintangkab.bps.go.id))
#   Tolikara (id: 9418, url: https://tolikarakab.bps.go.id))
#   Sarmi (id: 9419, url: https://sarmikab.bps.go.id))
#   Keerom (id: 9420, url: https://keeromkab.bps.go.id))
#   Waropen (id: 9426, url: https://waropenkab.bps.go.id))
#   Supiori (id: 9427, url: https://supiorikab.bps.go.id))
#   Mamberamo Raya (id: 9428, url: https://mamberamorayakab.bps.go.id))
#   Nduga (id: 9429, url: https://ndugakab.bps.go.id))
#   Lanny Jaya (id: 9430, url: https://lannyjayakab.bps.go.id))
#   Mamberamo Tengah (id: 9431, url: https://mamberamotengahkab.bps.go.id))
#   Yalimo (id: 9432, url: https://yalimokab.bps.go.id))
#   Puncak (id: 9433, url: https://puncakkab.bps.go.id))
#   Dogiyai (id: 9434, url: https://dogiyaikab.bps.go.id))
#   Intan Jaya (id: 9435, url: https://intanjayakab.bps.go.id))
#   Deiyai (id: 9436, url: https://deiyaikab.bps.go.id))
#   Jayapura (id: 9471, url: https://jayapurakota.bps.go.id))

# %% [markdown]
# It looks like Pusat (Malay: center) is the one we want: it's code is 0 suggesting it is the root, and its url is the stat's agencies homepage.

# %% [markdown]
# ### Finding what Data is available
#
# BPS divides their data into dynamic tables and static tables. Let's first focus on dynamic tables:
#
# Requesting from https://webapi.bps.go.id/v1/api/list/model/var will provide us with a list of all variables available in the dynamic tables for the root domain.

# %%
req_url = f"https://webapi.bps.go.id/v1/api/list/model/var/lang/eng/domain/0000/key/{key}/"
req = requests.get(req_url)
req_json = json.loads(req.content)
req_json['data'][0]
# Out:
# {'page': 1, 'pages': 131, 'per_page': 10, 'count': 10, 'total': 1305}

# %% [markdown]
# There are a lot! We'll need to make a new call for each page:

# %%
if os.path.exists('indonesia_0000_subject_responses.json'): # Load from file if it exists
    with open('indonesia_0000_subject_responses.json', 'r') as f:
        responses = json.load(f)
else:
    responses =  [json.loads(requests.get(f"https://webapi.bps.go.id/v1/api/list/model/var/lang/eng/domain/0000/page/1/key/{key}/").content)['data']]
    page = 1
    while page < responses[0][0]['pages']:
        page += 1
        #wait a bit
        time.sleep(0.25)
        req = requests.get(f"https://webapi.bps.go.id/v1/api/list/model/var/lang/eng/domain/0000/page/{page}/key/{key}/")
        response = json.loads(req.content)['data']
        print(f"Page {page} Fetched with status code {req.status_code}")
        responses.append(response)

# %% [markdown]
# let's cache this to a json to avoid making 131 calls next time and store in a df for easy access:

# %%
if not os.path.exists('indonesia_0000_subject_responses.json'): # Save to file if it doesn't exist
    with open('indonesia_0000_subject_responses.json', 'w') as f:
        json.dump(responses, f)
df = pd.concat([pd.DataFrame(res[1]) for res in responses])
df.to_csv("all_indonesian_series.csv", index=False)

# %% [markdown]
# trying a static table:

# %%
req_url = f"https://webapi.bps.go.id/v1/api/list/model/var/lang/eng/domain/0000/key/{key}/"
req = requests.get(req_url)
req_json = json.loads(req.content)
req_json['data'][0]

# %% [markdown]
# ### Fetching the data
#
# Let's try first with inflation (code 0)

# %%
var_num = 1521 # 1521  1 is for inflation
vervar = 9999
domain = "0000"
req_url = f"https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/{domain}/var/{var_num}/key/{key}/"
req = requests.get(req_url)
res = json.loads(req.content)
print(res.keys())
print(f"turvar {res['turvar']}")
print(f"vervar {res['vervar']}")
# Out:
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])
# turvar [{'val': 191, 'label': 'Urban+Rural'}]
# vervar [{'val': 9999, 'label': 'INDONESIA'}, {'val': 1100, 'label': 'ACEH'}, {'val': 1200, 'label': 'SUMATERA UTARA'}, {'val': 1300, 'label': 'SUMATERA BARAT'}, {'val': 1400, 'label': 'RIAU'}, {'val': 1500, 'label': 'JAMBI'}, {'val': 1600, 'label': 'SUMATERA SELATAN'}, {'val': 1700, 'label': 'BENGKULU'}, {'val': 1800, 'label': 'LAMPUNG'}, {'val': 1900, 'label': 'KEP. BANGKA BELITUNG'}, {'val': 2100, 'label': 'KEP. RIAU'}, {'val': 3100, 'label': 'DKI JAKARTA'}, {'val': 3200, 'label': 'JAWA BARAT'}, {'val': 3300, 'label': 'JAWA TENGAH'}, {'val': 3400, 'label': 'DI YOGYAKARTA'}, {'val': 3500, 'label': 'JAWA TIMUR'}, {'val': 3600, 'label': 'BANTEN'}, {'val': 5100, 'label': 'BALI'}, {'val': 5200, 'label': 'NUSA TENGGARA BARAT'}, {'val': 5300, 'label': 'NUSA TENGGARA TIMUR'}, {'val': 6100, 'label': 'KALIMANTAN BARAT'}, {'val': 6200, 'label': 'KALIMANTAN TENGAH'}, {'val': 6300, 'label': 'KALIMANTAN SELATAN'}, {'val': 6400, 'label': 'KALIMANTAN TIMUR'}, {'val': 6500, 'label': 'KALIMANTAN UTARA'}, {'val': 7100, 'label': 'SULAWESI UTARA'}, {'val': 7200, 'label': 'SULAWESI TENGAH'}, {'val': 7300, 'label': 'SULAWESI SELATAN'}, {'val': 7400, 'label': 'SULAWESI TENGGARA'}, {'val': 7500, 'label': 'GORONTALO'}, {'val': 7600, 'label': 'SULAWESI BARAT'}, {'val': 8100, 'label': 'MALUKU'}, {'val': 8200, 'label': 'MALUKU UTARA'}, {'val': 9100, 'label': 'PAPUA BARAT'}, {'val': 9400, 'label': 'PAPUA'}]

# %% [markdown]
# Looking at the returned datacontent, we can see that a dict is returned with keys identifying inflation values:

# %%
dict(islice(res['datacontent'].items(), 0, 5))
# Out:
# {'999910791': 2.58,
#  '999910792': 2.34,
#  '999910793': 0.55,
#  '999910794': 3.02,
#  '999910795': 3.05}

# %% [markdown]
# Unfortunately, in the data we get back, the keys are not dates, they're they're identifiers e.g. 999910791
# Where:
#
# - The first digits are the vervar (verticle variable?): region in this case; 9999 is Indonesia
# - The next digit(s) are the variable: 1 is inflation
# - The next are the year: 079 is 1979
# - The last digit is the subyear measure (in this case, 1-12 are Jan-Dec, 13 is annual): 1 is January

# %% [markdown]
# ### From Value Key to Dataframe:

# %% [markdown]
# Going from value key to date is a bit of a pain. Fields are not of a consistent length, and aren't padded with 0s. This means we can't just slice the string. Interpretting the string character by character is a nonstarter - there can be ambiguity as to whether the next character is a continuation of a field or start of a new field. An alternative approach is to generate all the keys we expect to see and then match them to the datacontent keys. This is what we'll do.

# %%
def get_df_backwards(res):
    """
    (request response content) -> (pandas dataframe)
    An attempt at parsing the keys by reading them backwards character by character and moving to the next key when the current key doesn't match any of the labels
    """
    turtahun_labels = {str(turtahun['val']):turtahun['label'] for turtahun in res['turtahun']}
    tahun_labels = {str(tahun['val']):tahun['label'] for tahun in res['tahun']}
    turvar_labels = {str(turvar['val']):turvar['label'] for turvar in res['turvar']}
    var_labels = {str(var['val']):var['label'] for var in res['var']}
    vervar_labels = {str(vervar['val']):vervar['label'] for vervar in res['vervar']}

    turtahuns = [] # Subyear Periods
    tahuns = [] # Years
    turvars = [] # Subvariables
    vars = [] # Variables
    vervars = [] # Subvariables

    for key in res['datacontent'].keys():
        try :
            full_key = key
            print("")
            print(f"key {key}")
            print(f"value {res['datacontent'][key]}")

            # We need to loop backwards through each key - why? Because fields aren't 0 padded and going forwards has edge cases where next character could be either vervar or var (e.g. 11 could be vervar 11 or leading in to 1 1521)
            turtahun_start = len(key)-1
            while(len( [turtahun for turtahun in turtahun_labels if turtahun.endswith(key[turtahun_start-1:])  ] ) > 0): # Whilst adding the previous character to the key still matches a turtahun add that character to the key
                turtahun_start -= 1
            turtahuns.append(turtahun_labels[key[turtahun_start:]])
            print(f"turtaun: key {key} turtahun {key[turtahun_start:]} label {turtahun_labels[key[turtahun_start:]]}")
            key = key[:turtahun_start]

            # Now do the same for tahun (years) 
            tahun_start = len(key)-1
            while(len( [tahun for tahun in tahun_labels if tahun.endswith(key[tahun_start-1:])  ] ) > 0): # Whilst adding the previous character to the key still matches a turtahun add that character to the key
                tahun_start -= 1
            tahuns.append(tahun_labels[key[tahun_start:]])
            print(f"tahun: key {key} tahun {key[tahun_start:]} label {tahun_labels[key[tahun_start:]]}")
            key = key[:tahun_start]

            # and for turvar (subvariables)
            turvar_start = len(key)-1
            while(len( [turvar for turvar in turvar_labels if turvar.endswith(key[turvar_start-1:])  ] ) > 0): # Whilst adding the previous character to the key still matches a turtahun add that character to the key
                turvar_start -= 1
            turvars.append(turvar_labels[key[turvar_start:]])
            print(f"turvar: key {key} turvar {key[turvar_start:]} label {turvar_labels[key[turvar_start:]]}")
            key = key[:turvar_start]

            # and for var (variables)
            var_start = len(key)-1
            while(len( [var for var in var_labels if var.endswith(key[var_start-1:])  ] ) > 0): # Whilst adding the previous character to the key still matches a turtahun add that character to the key
                var_start -= 1
            print(f"var: key {key} var {key[var_start:]} label {var_labels[key[var_start:]]}")
            vars.append(var_labels[key[var_start:]])
            key = key[:var_start]

            # and for vervar (subvariables)
            vervar_start = len(key)-1
            while (len( [vervar for vervar in vervar_labels if vervar.endswith(key[vervar_start-1:])] ) > 0) and vervar_start > 0: # Whilst adding the previous character to the key still matches a turtahun add that character to the key
                vervar_start -= 1

            vervars.append(vervar_labels[key[vervar_start:]])
            print(f"vervar: key {key} vervar {key[vervar_start:]} label {vervar_labels[key[vervar_start:]]}")
            key = key[:vervar_start]

            if len(key) > 0:
                raise Exception(f"Key not empty {key}")
        except Exception as e:
            # print red and bold
            print('\033[1;31m Error {e} \033[0m')
        
    df = pd.DataFrame({"year" : tahuns, "subyear" : turtahuns, "subvariable" : turvars, "variable" : vars, "vertical_variable" : vervars})
    return df

def get_df(res):
    """
    (request response content) -> (pandas dataframe)
    Parses bps response into a pandas dataframe by matching the keys to the labels
    """
    vervar_labels = {str(vervar['val']):vervar['label'] for vervar in res['vervar']}
    var_labels = {str(var['val']):var['label'] for var in res['var']}
    turvar_labels = {str(turvar['val']):turvar['label'] for turvar in res['turvar']}
    tahun_labels = {str(tahun['val']):tahun['label'] for tahun in res['tahun']}
    turtahun_labels = {str(turtahun['val']):turtahun['label'] for turtahun in res['turtahun']}

    possible_keys = {} # dict of key:{"year", "subyear", "subvariable", "variable", "vertical_variable"} # Cache all possible keys to link datacontent to
    for fields in itertools.product(vervar_labels, var_labels, turvar_labels, tahun_labels, turtahun_labels):
        key = "".join(fields)
        possible_keys[key] = {"year" : tahun_labels[fields[3]], "subyear" : turtahun_labels[fields[4]], "subvariable" : turvar_labels[fields[2]], "variable" : var_labels[fields[1]], "vertical_variable" : vervar_labels[fields[0]]}

    # Link the datacontent to the possible keys
    data = [dict(possible_keys[key], **{"value":value}) for key, value in res['datacontent'].items()]
    df = pd.DataFrame(data)
    return df

# %%
var_num = 2130 # 1521  1 is for inflation
vervar = 9999
domain = "0000"
req_url = f"https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/{domain}/var/{var_num}/key/{key}/"
print(f"req_url {req_url}")
req = requests.get(req_url)
res = json.loads(req.content)
print(res.keys())
print(f"turvar {res['turvar']}")
print(f"vervar {res['vervar']}")
""" print("")
print(f"tahun {res['tahun']}")
print(f"turtahun {res['turtahun']}") """

get_df(res)
# Out:
# req_url https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/2130/key/5a91eee05bb200a412fdddf3f53778a8/
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])
# turvar [{'val': 0, 'label': 'Tidak Ada'}]
# vervar [{'val': 100, 'label': '1. Household Consumption Expenditures'}, {'val': 110, 'label': 'a. Food and Beverages, Other Than Restaurants'}, {'val': 120, 'label': 'b. Clothing, Footwear and Maintenance Services'}, {'val': 130, 'label': 'c. Household Housing and Equipment'}, {'val': 140, 'label': 'd. Health and Education'}, {'val': 150, 'label': 'e. Transportation and Communication'}, {'val': 160, 'label': 'f. Restaurants and Hotels'}, {'val': 170, 'label': 'g. Others'}, {'val': 200, 'label': '2. Consumption Expenditures of Non-Profit Institutions that serve Households'}, {'val': 300, 'label': '3. Government Consumption Expenditures'}, {'val': 310, 'label': 'a. Collective Consumption'}, {'val': 320, 'label': 'b. Individual consumption'}, {'val': 400, 'label': '4. Establishment of Gross Domestic Fixed Capital'}, {'val': 410, 'label': 'a. Building'}, {'val': 420, 'label': 'b. Machinery and Equipment'}, {'val': 430, 'label': 'c. Vehicle'}, {'val': 440, 'label': 'd. Other Equipment'}, {'val': 450, 'label': 'e. Cultivated Biological Resources (CBR)'}, {'val': 460, 'label': 'f. Intellectual Property Products'}, {'val': 600, 'label': '6. Export of goods and services'}, {'val': 610, 'label': 'a. Goods'}, {'val': 611, 'label': 'a.1. Non-oil and gas goods'}, {'val': 612, 'label': 'a.b. Oil and gas goods'}, {'val': 620, 'label': 'b. Services'}, {'val': 700, 'label': '7. Reduced Import of Goods and Services'}, {'val': 710, 'label': 'a. Goods'}, {'val': 711, 'label': 'a.1. Non-oil and gas goods'}, {'val': 712, 'label': 'a.b. Oil and gas goods'}, {'val': 720, 'label': 'b. Services'}, {'val': 800, 'label': '8. GROSS DOMESTIC PRODUCTS'}]
#       year      subyear subvariable  \
# 0     2011    Quarter 1   Tidak Ada
# 1     2011   Quarter II   Tidak Ada
# 2     2011  Quarter III   Tidak Ada
# 3     2011   Quarter IV   Tidak Ada
# 4     2012    Quarter 1   Tidak Ada
# ...    ...          ...         ...
# 1675  2022   Quarter II   Tidak Ada
# 1676  2022  Quarter III   Tidak Ada
# 1677  2022   Quarter IV   Tidak Ada
# 1678  2022     Annually   Tidak Ada
# 1679  2023    Quarter 1   Tidak Ada
#
#                                                variable  \
# 0     [2010 Version] 8. Source of Growth C to C Quar...
# 1     [2010 Version] 8. Source of Growth C to C Quar...
# 2     [2010 Version] 8. Source of Growth C to C Quar...
# 3     [2010 Version] 8. Source of Growth C to C Quar...
# 4     [2010 Version] 8. Source of Growth C to C Quar...
# ...                                                 ...
# 1675  [2010 Version] 8. Source of Growth C to C Quar...
# 1676  [2010 Version] 8. Source of Growth C to C Quar...
# 1677  [2010 Version] 8. Source of Growth C to C Quar...
# 1678  [2010 Version] 8. Source of Growth C to C Quar...
# 1679  [2010 Version] 8. Source of Growth C to C Quar...
#
#                           vertical_variable  value
# 0     1. Household Consumption Expenditures   2.32
# 1     1. Household Consumption Expenditures   2.42
# 2     1. Household Consumption Expenditures   2.68
# 3     1. Household Consumption Expenditures   2.79
# 4     1. Household Consumption Expenditures   3.06
# ...                                     ...    ...
# 1675             8. GROSS DOMESTIC PRODUCTS   5.25
# 1676             8. GROSS DOMESTIC PRODUCTS   5.41
# 1677             8. GROSS DOMESTIC PRODUCTS   5.31
# 1678             8. GROSS DOMESTIC PRODUCTS   5.31
# 1679             8. GROSS DOMESTIC PRODUCTS   5.03
#
# [1680 rows x 6 columns]

# %%
res["turtahun"]
# Out:
# [{'val': 31, 'label': 'Quarter 1'},
#  {'val': 32, 'label': 'Quarter II'},
#  {'val': 33, 'label': 'Quarter III'},
#  {'val': 34, 'label': 'Quarter IV'},
#  {'val': 35, 'label': 'Annually'}]

# %% [markdown]
# ### Parsing Dates
# Records right now are identified by year and subyear. We want to convert this to a date. Before proceeding, we'll download and cache requests for relevant series (identified in Relevant_Parameters.csv).

# %%
params_df = pd.read_csv("Relevant_Parameters.csv", dtype=str)
params_df.dropna(inplace=True, subset=["Topic"])

# %%
def request_series(row):
    """
    (pandas dataframe row) -> (requests response content)
    """
    # if request content exists in Cached_Requests/ use that
    # else request content from bps and save to Cached_Requests/
    if os.path.exists(f"Cached_Requests/{row['Topic']}.json"):
        with open(f"Cached_Requests/{row['Topic']}.json", "r") as f:
            return(json.load(f))
    else:
        # Request content from bps
        req_url = f"https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/{row['Var']}/key/{key}/vervar/{row['Vervar']}/"
        if not pd.isna(row['Turvar']):
            req_url += f"turvar/{row['Turvar']}/"
        req = requests.get(req_url)
        time.sleep(5)
        res = json.loads(req.content)
        # Save request content to Cached_Requests/ if request was successful
        if "datacontent" in res.keys():
            with open(f"Cached_Requests/{row['Topic']}.json", "w") as f:
                json.dump(res, f)
        return res
data_requests = params_df.apply(request_series, axis=1)

# %% [markdown]
# Let's look at all the labels we have in Turtahun (subyear):

# %%
turtahun_lists = [res['turtahun'] for res in data_requests]
# Flatten this list of lists
turtahuns = [turtahun['label'] for turtahun_list in turtahun_lists for turtahun in turtahun_list]
print(set(turtahuns))
# Out:
# {'January', 'Quarter II', 'September', 'May', 'April', 'February', 'Annual', 'November', 'Semester 2 (September)', 'December', 'Semester 1 (March)', 'Quarter III', 'Yearly', 'March', 'Annually', 'Quarter 1', 'August', 'July', 'October', 'June', 'Quarter IV'}

# %% [markdown]
# There's nothing too surprising here - Just the months, quarters and a few semesters. Instead of any fancy parsing, we'll just use a dictionary to map these to their respective months.

# %%
def turtahun_month_day(turtahun):
    """
    (str) -> (str, str)
    Returns the month and day of the turtahun
    """
    turtahun_lookups = { "January": "01-01", "February": "02-01", "March": "03-01", "April": "04-01", "May": "05-01", "June": "06-01", "July": "07-01", "August": "08-01", "September": "09-01", "October": "10-01", "November": "11-01", "December": "12-01", "Quarter I": "01-01", "Quarter II": "04-01", "Quarter III": "07-01", "Quarter IV": "10-01", "Semester 1 (March)" : "03-01", "Semester 2 (September)" : "09-01", "Annual": "01-01", "Annually" : "01-01", "Yearly" : "01-01"}
    if turtahun in turtahun_lookups.keys():
        return turtahun_lookups[turtahun]
    else:
        #print in red and bold
        print('\033[1;31m {turtahun} not in turtahun_lookups, defaulting to 01-01 \033[0m')

# %% [markdown]
# now we can have a JS compliant date string:

# %%
df["date"] = df["year"]+"-"+df["subyear"].apply(turtahun_month_day)

# %% [markdown]
# ### Reducing Down to 3 Functions
# To automate this, let's have it in one function and avoid pandas. Steps:
# 1. Function to fetch data from api
# 2. Function to parse data

# %%
def turtahun_month_day(turtahun):
    """
    (str) -> (str, str)
    Returns the month and day of the turtahun
    """
    turtahun_lookups = { "January": "01-01", "February": "02-01", "March": "03-01", "April": "04-01", "May": "05-01", "June": "06-01", "July": "07-01", "August": "08-01", "September": "09-01", "October": "10-01", "November": "11-01", "December": "12-01", "Quarter I": "01-01", "Quarter 1": "01-01", "Quarter 2": "04-01", "Quarter II": "04-01", "Quarter III": "07-01", "Quarter 3": "07-01", "Quarter IV": "10-01","Quarter 4": "10-01","Semester 1 (March)" : "03-01", "Semester 2 (September)" : "09-01", "Annual": "01-01", "Annually" : "01-01", "Yearly" : "01-01"}
    if turtahun in turtahun_lookups:
        return turtahun_lookups[turtahun]
    else:
        #print in red and bold
        print(f'\033[1;31m {turtahun} not in turtahun_lookups, defaulting to 01-01 \033[0m')
        return "01-01"

def dict_from_req(res):
    """
    (requests response) -> (json: list of dicts of form {"date":str, "value":str}})
    Receives a requests response of a bps api request and json containing the datacontent
    """
    vervar_labels = {str(vervar['val']):vervar['label'] for vervar in res['vervar']}
    var_labels = {str(var['val']):var['label'] for var in res['var']}
    turvar_labels = {str(turvar['val']):turvar['label'] for turvar in res['turvar']}
    tahun_labels = {str(tahun['val']):tahun['label'] for tahun in res['tahun']}
    turtahun_labels = {str(turtahun['val']):turtahun['label'] for turtahun in res['turtahun']}

    possible_keys = {} # dict of key:{"year", "subyear", "subvariable", "variable", "vertical_variable"} # Cache all possible keys to link datacontent to
    for fields in itertools.product(vervar_labels, var_labels, turvar_labels, tahun_labels, turtahun_labels):
        key = "".join(fields)
        possible_keys[key] = {"year" : tahun_labels[fields[3]], "subyear" : turtahun_labels[fields[4]], "subvariable" : turvar_labels[fields[2]], "variable" : var_labels[fields[1]], "vertical_variable" : vervar_labels[fields[0]]}
    data = [dict(possible_keys[key], **{"value":value}) for key, value in res['datacontent'].items()]

    for d in data:
        #print(f"d['year'] = {d['year']}, d['subyear'] = {d['subyear']}")
        #print(f" type(d['year']) = {type(d['year'])}, type(d['subyear']) = {type(d['subyear'])}, type(turtahun_month_day(d['subyear'])) = {type(turtahun_month_day(d['subyear']))}")
        d["date"] = d["year"]+"-"+turtahun_month_day(d["subyear"])

    return {"name":res['var'][0]['label'],
             "unit": res['var'][0]['unit'],
             "data":data }


def request_bps_series_from_csv(series_path="Relevant_Parameters.csv", write_path="bps_data/"):
    """
    (path of csv containing series to get) -> (none)
    Requests data from bps and saves it to write_path
    """
    params_df = pd.read_csv("Relevant_Parameters.csv", dtype=str)
    params_df.dropna(inplace=True, subset=["Topic"])

    for index, row in params_df.iterrows():
        req_url = f"https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/{row['Var']}/key/{key}/vervar/{row['Vervar']}/"
        if not pd.isna(row['Turvar']):
            req_url += f"turvar/{row['Turvar']}/"
        req = requests.get(req_url)
        time.sleep(1)
        res = json.loads(req.content)
        if "datacontent" in res.keys():
            with open(f"{write_path}{row['Topic']}.json", "w") as f:
                json.dump(dict_from_req(res), f)
            print(f"Finished {row['Topic']} with status code {req.status_code}")
        else:
            print(f"Failed {row['Topic']} with status code {req.status_code}")

# %%
import pandas as pd

params_df = pd.read_csv("Relevant_Parameters.csv", dtype=str)
params_df.dropna(inplace=True, subset=["Topic"])



for index, row in params_df.iterrows():
    req_url = f"https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/{row['Var']}/key/{key}/vervar/{row['Vervar']}/"
    if not pd.isna(row['Turvar']):
        req_url += f"turvar/{row['Turvar']}/"
    print(req_url)
# Out:
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/1/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/2130/key/5a91eee05bb200a412fdddf3f53778a8/vervar/800/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/543/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/1953/key/5a91eee05bb200a412fdddf3f53778a8/vervar/1/turvar/1664/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/1953/key/5a91eee05bb200a412fdddf3f53778a8/vervar/2/turvar/1664/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/196/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/497/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/720/key/5a91eee05bb200a412fdddf3f53778a8/vervar/35/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/704/key/5a91eee05bb200a412fdddf3f53778a8/vervar/11/turvar/834/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/1975/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/1521/key/5a91eee05bb200a412fdddf3f53778a8/vervar/18/
# https://webapi.bps.go.id/v1/api/list/model/data/lang/eng/domain/0000/var/98/key/5a91eee05bb200a412fdddf3f53778a8/vervar/9999/turvar/191/

# %%
request_bps_series_from_csv()
# Out:
# Finished Inflation  with status code 200
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
#  Quarter 1 not in turtahun_lookups, defaulting to 01-01
# Finished Growth  with status code 200
# Finished Unemployment rate  with status code 200
# Finished Employment rate with status code 200
# Finished Employed with status code 200
# Finished Exports with status code 200
# Finished Imports with status code 200
# Finished Productivity with status code 200
# Finished Inactivity with status code 200
# Finished Population with status code 200
# Finished Monthly Wage with status code 200
# Finished Inequality with status code 200

# %%
turtahun_month_day("Quarter I")
# Out:
# '01-01'

# %%
data_requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y252sZmlsZQ%3D%3D?line=0'>1</a> data_requests
#
# NameError: name 'data_requests' is not defined

# %%
params_df.iloc[0].Turvar == nan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y254sZmlsZQ%3D%3D?line=0'>1</a> (params_df.iloc[0].Turvar.isnan())
#
# AttributeError: 'float' object has no attribute 'isnan'

# %%
key = "115210115189"

# %%
len("115210115189")
# Out:
# 12

# %%
turtahun_start = len(key)-1
turtahun_start
# Out:
# 11

# %%
key[turtahun_start-1]
# Out:
# '8'

# %%
while(len( [turtahun for turtahun in turtahun_labels if turtahun.endswith(key[turtahun_start-1])  ] ) > 0): # Whilst adding the previous character to the key still matches a turtahun add that character to the key
    turtahun_start -= 1
turtahuns.append(turtahun_labels[key[turtahun_start:]])
key = key[:turtahun_start]

# %%
res['turtahun']
# Out:
# [{'val': 189, 'label': 'February'}, {'val': 190, 'label': 'August'}]

# %%
"hello"[len("hello"):]
# Out:
# ''

# %%
[key for key in res['datacontent'].keys() if key.startswith("11") ]
# Out:
# ['115210115189',
#  '115210115190',
#  '115210116189',
#  '115210116190',
#  '115210117189',
#  '115210117190',
#  '115210118189',
#  '115210118190',
#  '115210119189',
#  '115210119190',
#  '115210120189',
#  '115210120190',
#  '115210121189',
#  '115210121190',
#  '115210122189',
#  '115210122190',
#  '115210123189',
#  '1115210115189',
#  '1115210115190',
#  '1115210116189',
#  '1115210116190',
#  '1115210117189',
#  '1115210117190',
#  '1115210118189',
#  '1115210118190',
#  '1115210119189',
#  '1115210119190',
#  '1115210120189',
#  '1115210120190',
#  '1115210121189',
#  '1115210121190',
#  '1115210122189',
#  '1115210122190',
#  '1115210123189']

# %%
def data_from_bps(res):
    """"
    req: requests content
    Returns: pandas dataframe of the data
    """

    vervar_len = max([len(str(vervar['val'])) for vervar in res['vervar']]) # max length of vervar
    vervar_labels = {str(vervar['val']): vervar['label'] for vervar in res['vervar']} # associate vervar with labels
    vertical_variables = []

    turvar_len = max([len(str(turvar['val'])) for turvar in res['turvar']])
    turvar_labels = {str(turvar['val']): turvar['label'] for turvar in res['turvar']} # associate turvar with labels
    turvar_labels['Tidak Ada'] = ''
    subvariables = []

    var_len = len(str(res['var'][0]['val']))
    var_labels = {str(var['val']): var['label'] for var in res['var']} # associate var with labels
    variables = []

    #tahun_len = max([len(str(tahun['val'])) for tahun in res['tahun']]) 
    tahun_labels = {str(tahun['val']): tahun['label'] for tahun in res['tahun']} # associate tahun with labels - they don't zfill at all - they just add a 0 regardless of length!!
    years = []

    turtahun_len = max([len(str(turtahun['val'])) for turtahun in res['turtahun']])
    turtahun_labels = {str(turtahun['val']): turtahun['label'] for turtahun in res['turtahun']} # associate tahun with labels - they do zfill
    subyears = []

    keys = []
    values = []

    print(f"res['vervar']: {res['vervar']}")
    print(f"res['var']: {res['var']}")
    print("")

    for key in res['datacontent'].keys():

        keys.append(key)
        full_key = key


        values.append(
            res['datacontent'][key]
        )

        # First extract the vervar and var - these aren't 0 separated
        """     print(f"key: {key}")
        print(f"full_key: {full_key}")
        print(f"vervar_len: {vervar_len}") 
        """

        # This isn't working - turns out they don't actually zfill
        # TODO: grab next characters until it couldn't be a vervar

        vervar_len = 1
        while len([vervar for vervar in res['vervar'] if str(vervar['val']).startswith(key[0:vervar_len+1])]) > 0:
            vervar_len += 1

        vertical_variables.append(
            vervar_labels[
                key[0:vervar_len]
            ]
        )
        key = key[vervar_len:]

        var_len = 1
        print(f"full_key: {full_key}")
        print(f"key: {key}")
        print(f"key starts with {key[0:var_len]}")
        print(f"variables starting with {key[0:var_len]}: {[var for var in res['var'] if str(var['val']).startswith(key[0:var_len+1])]}")
        while len([var for var in res['var'] if str(var['val']).startswith(key[0:var_len+1])]) > 0:
            var_len += 1

        print(f"res['var']: {res['var']}")
        print(f"var_len: {var_len}")
        print(f"var: {key[0:var_len]}")
        print(f"var_labels: {var_labels}")


        variables.append(
            var_labels[
                key[0:var_len]
            ]
        )
        key = key[var_len:]

        # Then extract turvar
        subvariables.append(
            turvar_labels[
                key[0:turvar_len]
            ]
        )
        key = key[turvar_len:]

        # Work out how many digits tahun will have
        # look at the first character and find maximum length of tahuns that start with that character
        tahun_len = max([ len(str(tahun['val'])) for tahun in res['tahun'] if str(tahun['val']).startswith(key[0])])
        """ print(f"key: {key}")
        print(f"full_key: {full_key}")
        print(f"tahun_len: {tahun_len}")
        print(f"tahun starts with {key[0]}")
        print(f"keys starting with {key[0]} are {[ str(tahun['val']) for tahun in res['tahun'] if str(tahun['val']).startswith(key[0])]}") """
        years.append(
            tahun_labels[
                key[0:tahun_len]
            ]
        )
        key = key[tahun_len:]

        # Which only leaves the subyear
        subyears.append(
            turtahun_labels[
                key
            ]
        )
        # When there are varying lengths of turhan, they are separated by a 0
         
    return pd.DataFrame({
        "vertical_variable": vertical_variables,
        "variable": variables,
        "subvariable": subvariables,
        "year": years,
        "subyear": subyears,
        "key": keys,
        "value": values
    })

df = data_from_bps(res)
df
# Out:
# res['vervar']: [{'val': 1, 'label': 'A'}, {'val': 2, 'label': 'B'}, {'val': 3, 'label': 'C'}, {'val': 4, 'label': 'D'}, {'val': 5, 'label': 'E'}, {'val': 6, 'label': 'F'}, {'val': 7, 'label': 'G'}, {'val': 8, 'label': 'H'}, {'val': 9, 'label': 'I'}, {'val': 10, 'label': 'J'}, {'val': 11, 'label': 'K'}, {'val': 12, 'label': 'L'}, {'val': 13, 'label': 'M, N'}, {'val': 14, 'label': 'O'}, {'val': 15, 'label': 'P'}, {'val': 16, 'label': 'Q'}, {'val': 17, 'label': 'R, S, T, U'}, {'val': 18, 'label': 'Average'}]
# res['var']: [{'val': 1521, 'label': 'Average of Net Wage/Salary', 'unit': 'Rupiahs', 'subj': 'Labour Wages', 'def': '', 'decimal': '0', 'note': 'Source from The  Labor  Force  Situation  in Indonesia February and August 2023.\n Net  Wage/Salary  per month is  wage/salary received  by  the  employee  during  previous  month  from  the  main  job,which consists of basic wages and allowances, in terms of money or goods paid by the employer.\nA. Agriculture, Forestry, and Fishing   \t\t\t\nB. Mining and Quarrying\t\t\t\nC. Manufacturing   \t\t\t\nD. Electricity, Gas Steam and Air Contioning Supply\t\t\nE. Water Supply, sewerage, waste Management and remendiation Activities   \t\t\t\nF. Construction\t\t\t\nG. Wholesale and Retail Trade; Repair of Motor Vehicles and Motorcycles\t\t\t\nH. Transportation and Storage\t\t\t\nI. Accomodation and Services Activities\t\t\t\nJ. Information and Communication\t\t\t\nK. Financial and Insurance Activities\t\t\t\nL. Real Estate\t\t\t\nM,N. Prpfesional Activities and administration &amp;amp; Support Activities\t\t\t\nO. Public Administration and Defence; Compulsory Social Security\t\t\t\nP. Education\t\t\t\nQ. Human Health Services and Social Work Activities\t\t\t\nR,S,T,U. Other Service Activities\t\n'}]
#
# full_key: 115210115189
# key: 5210115189
# key starts with 5
# variables starting with 5: []
# res['var']: [{'val': 1521, 'label': 'Average of Net Wage/Salary', 'unit': 'Rupiahs', 'subj': 'Labour Wages', 'def': '', 'decimal': '0', 'note': 'Source from The  Labor  Force  Situation  in Indonesia February and August 2023.\n Net  Wage/Salary  per month is  wage/salary received  by  the  employee  during  previous  month  from  the  main  job,which consists of basic wages and allowances, in terms of money or goods paid by the employer.\nA. Agriculture, Forestry, and Fishing   \t\t\t\nB. Mining and Quarrying\t\t\t\nC. Manufacturing   \t\t\t\nD. Electricity, Gas Steam and Air Contioning Supply\t\t\nE. Water Supply, sewerage, waste Management and remendiation Activities   \t\t\t\nF. Construction\t\t\t\nG. Wholesale and Retail Trade; Repair of Motor Vehicles and Motorcycles\t\t\t\nH. Transportation and Storage\t\t\t\nI. Accomodation and Services Activities\t\t\t\nJ. Information and Communication\t\t\t\nK. Financial and Insurance Activities\t\t\t\nL. Real Estate\t\t\t\nM,N. Prpfesional Activities and administration &amp;amp; Support Activities\t\t\t\nO. Public Administration and Defence; Compulsory Social Security\t\t\t\nP. Education\t\t\t\nQ. Human Health Services and Social Work Activities\t\t\t\nR,S,T,U. Other Service Activities\t\n'}]
# var_len: 1
# var: 5
# var_labels: {'1521': 'Average of Net Wage/Salary'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 37 in <cell line: 127>()
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=114'>115</a>         # When there are varying lengths of turhan, they are separated by a 0
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=116'>117</a>     return pd.DataFrame({
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=117'>118</a>         "vertical_variable": vertical_variables,
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=118'>119</a>         "variable": variables,
#    (...)
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=123'>124</a>         "value": values
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=124'>125</a>     })
# --> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=126'>127</a> df = data_from_bps(res)
#     <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=127'>128</a> df
#
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 37 in data_from_bps(res)
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=74'>75</a> print(f"var: {key[0:var_len]}")
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=75'>76</a> print(f"var_labels: {var_labels}")
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=78'>79</a> variables.append(
# ---> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=79'>80</a>     var_labels[
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=80'>81</a>         key[0:var_len]
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=81'>82</a>     ]
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=82'>83</a> )
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=83'>84</a> key = key[var_len:]
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y124sZmlsZQ%3D%3D?line=85'>86</a> # Then extract turvar
#
# KeyError: '5'

# %%
df.query("key == '119531664111189'")
# Out:
#   vertical_variable                                           variable  \
# 0    Percentage (%)  Number and Percentage of Employment and Unempl...
#
#   subvariable  year   subyear              key  value
# 0  Employment  2011  February  119531664111189  93.04

# %%
res['turtahun']
# Out:
# [{'val': 189, 'label': 'February'}, {'val': 190, 'label': 'August'}]

# %%
res['turvar']
# Out:
# [{'val': 0, 'label': 'Tidak Ada'}]

# %%
[ [key, value] for key, value in res['datacontent'].items() if key == "119531664111189"]
# Out:
# [['119531664111189', 93.04]]

# %%
res['turtahun']
# Out:
# [{'val': 189, 'label': 'February'}, {'val': 190, 'label': 'August'}]

# %%
res
# Out:
# {'status': 'OK',
#  'data-availability': 'available',
#  'var': [{'val': 1,
#    'label': 'Inflation (Umum)',
#    'unit': '',
#    'subj': 'Consumer Prices Indices',
#    'def': '',
#    'decimal': '',
#    'note': '&lt;p&gt;1. Before April 1979, the base year is September 1966 (September 1966 = 100)&lt;br /&gt;\n2.Since April 1979, the Term &quot;Consumer Price Index&quot; has been used ( the term that has been used before is &quot;Cost Living Index&quot;). The base year is April 1977-Maret 1978. CPI using a consumption pattern obtained from 1977/1978 Cost Living Survey in 17 Provincial Capital cities.) (April 1977-Maret 1978=100).&lt;br /&gt;\n3. Since April 1990-1997, CPI has been based on a consumption pattern obtained from Cost Living Survey in 27 Provincial Capital cities and using 1988/1989 base year) (1988/1989=100)&lt;br /&gt;\n4. Since December 1997, CPI has been based on a consumption pattern obtained from 1996 Cost of Living Survey in 44 cities(1996=100)&lt;br /&gt;\n5. Since January 2004, CPI has been based on a consumption pattern obtained from 2002 Cost of Living Survey in 45 cities(2002=100)&lt;br /&gt;\n6. Since June 2008, CPI has been based on a consumption pattern obtained from 2007 Cost of Living Survey in 66 cities(2007=100)&lt;br /&gt;\n7. Since 2014, CPI has been based on a consumption pattern obtained from 2012 Cost of Living Survey in 82 cities (2012=100)&lt;br /&gt;&lt;/p&gt;'}],
#  'turvar': [{'val': 0, 'label': 'Tidak Ada'}],
#  'labelvervar': 'Inflation City',
#  'vervar': [{'val': 9999, 'label': 'INDONESIA'},
#   {'val': 1107, 'label': 'KOTA MEULABOH'},
#   {'val': 1171, 'label': 'KOTA BANDA ACEH'},
#   {'val': 1174, 'label': 'KOTA LHOKSEUMAWE'},
#   {'val': 1271, 'label': 'KOTA SIBOLGA'},
#   {'val': 1273, 'label': 'KOTA PEMATANG SIANTAR'},
#   {'val': 1275, 'label': 'KOTA MEDAN'},
#   {'val': 1277, 'label': 'KOTA PADANGSIDIMPUAN'},
#   {'val': 1371, 'label': 'KOTA PADANG'},
#   {'val': 1375, 'label': 'KOTA BUKITTINGGI'},
#   {'val': 1403, 'label': 'TEMBILAHAN'},
#   {'val': 1471, 'label': 'KOTA PEKANBARU'},
#   {'val': 1473, 'label': 'KOTA DUMAI'},
#   {'val': 1509, 'label': 'BUNGO'},
#   {'val': 1571, 'label': 'KOTA JAMBI'},
#   {'val': 1671, 'label': 'KOTA PALEMBANG'},
#   {'val': 1674, 'label': 'KOTA LUBUKLINGGAU'},
#   {'val': 1771, 'label': 'KOTA BENGKULU'},
#   {'val': 1871, 'label': 'KOTA BANDAR LAMPUNG'},
#   {'val': 1872, 'label': 'KOTA METRO'},
#   {'val': 1902, 'label': 'TANJUNG PANDAN'},
#   {'val': 1971, 'label': 'KOTA PANGKAL PINANG'},
#   {'val': 2171, 'label': 'KOTA BATAM'},
#   {'val': 2172, 'label': 'KOTA TANJUNG PINANG'},
#   {'val': 3100, 'label': 'DKI JAKARTA'},
#   {'val': 3271, 'label': 'KOTA BOGOR'},
#   {'val': 3272, 'label': 'KOTA SUKABUMI'},
#   {'val': 3273, 'label': 'KOTA BANDUNG'},
#   {'val': 3274, 'label': 'KOTA CIREBON'},
#   {'val': 3275, 'label': 'KOTA BEKASI'},
#   {'val': 3276, 'label': 'KOTA DEPOK'},
#   {'val': 3278, 'label': 'KOTA TASIKMALAYA'},
#   {'val': 3301, 'label': 'CILACAP'},
#   {'val': 3302, 'label': 'PURWOKERTO'},
#   {'val': 3319, 'label': 'KUDUS'},
#   {'val': 3372, 'label': 'KOTA SURAKARTA'},
#   {'val': 3374, 'label': 'KOTA SEMARANG'},
#   {'val': 3376, 'label': 'KOTA TEGAL'},
#   {'val': 3471, 'label': 'KOTA YOGYAKARTA'},
#   {'val': 3509, 'label': 'JEMBER'},
#   {'val': 3510, 'label': 'BANYUWANGI'},
#   {'val': 3529, 'label': 'SUMENEP'},
#   {'val': 3571, 'label': 'KOTA KEDIRI'},
#   {'val': 3573, 'label': 'KOTA MALANG'},
#   {'val': 3574, 'label': 'KOTA PROBOLINGGO'},
#   {'val': 3577, 'label': 'KOTA MADIUN'},
#   {'val': 3578, 'label': 'KOTA SURABAYA'},
#   {'val': 3671, 'label': 'KOTA TANGERANG'},
#   {'val': 3672, 'label': 'KOTA CILEGON'},
#   {'val': 3673, 'label': 'KOTA SERANG'},
#   {'val': 5108, 'label': 'SINGARAJA'},
#   {'val': 5171, 'label': 'KOTA DENPASAR'},
#   {'val': 5271, 'label': 'KOTA MATARAM'},
#   {'val': 5272, 'label': 'KOTA BIMA'},
#   {'val': 5310, 'label': 'MAUMERE'},
#   {'val': 5371, 'label': 'KOTA KUPANG'},
#   {'val': 5400, 'label': 'DILI'},
#   {'val': 6171, 'label': 'KOTA PONTIANAK'},
#   {'val': 6172, 'label': 'KOTA SINGKAWANG'},
#   {'val': 6202, 'label': 'SAMPIT'},
#   {'val': 6271, 'label': 'KOTA PALANGKA RAYA'},
#   {'val': 6309, 'label': 'TANJUNG'},
#   {'val': 6371, 'label': 'KOTA BANJARMASIN'},
#   {'val': 6471, 'label': 'KOTA BALIKPAPAN'},
#   {'val': 6472, 'label': 'KOTA SAMARINDA'},
#   {'val': 6473, 'label': 'KOTA TARAKAN'},
#   {'val': 7171, 'label': 'KOTA MANADO'},
#   {'val': 7271, 'label': 'KOTA PALU'},
#   {'val': 7302, 'label': 'BULUKUMBA'},
#   {'val': 7311, 'label': 'WATAMPONE'},
#   {'val': 7371, 'label': 'KOTA MAKASSAR'},
#   {'val': 7372, 'label': 'KOTA PARE-PARE'},
#   {'val': 7373, 'label': 'KOTA PALOPO'},
#   {'val': 7471, 'label': 'KOTA KENDARI'},
#   {'val': 7472, 'label': 'KOTA BAU-BAU'},
#   {'val': 7571, 'label': 'KOTA GORONTALO'},
#   {'val': 7604, 'label': 'MAMUJU'},
#   {'val': 8171, 'label': 'KOTA AMBON'},
#   {'val': 8172, 'label': 'KOTA TUAL'},
#   {'val': 8271, 'label': 'KOTA TERNATE'},
#   {'val': 9105, 'label': 'MANOKWARI'},
#   {'val': 9171, 'label': 'KOTA SORONG'},
#   {'val': 9401, 'label': 'MERAUKE'},
#   {'val': 9471, 'label': 'KOTA JAYAPURA'}],
#  'tahun': [{'val': 79, 'label': '1979'},
#   {'val': 80, 'label': '1980'},
#   {'val': 81, 'label': '1981'},
#   {'val': 82, 'label': '1982'},
#   {'val': 83, 'label': '1983'},
#   {'val': 84, 'label': '1984'},
#   {'val': 85, 'label': '1985'},
#   {'val': 86, 'label': '1986'},
#   {'val': 87, 'label': '1987'},
#   {'val': 88, 'label': '1988'},
#   {'val': 89, 'label': '1989'},
#   {'val': 90, 'label': '1990'},
#   {'val': 91, 'label': '1991'},
#   {'val': 92, 'label': '1992'},
#   {'val': 93, 'label': '1993'},
#   {'val': 94, 'label': '1994'},
#   {'val': 95, 'label': '1995'},
#   {'val': 96, 'label': '1996'},
#   {'val': 97, 'label': '1997'},
#   {'val': 98, 'label': '1998'},
#   {'val': 99, 'label': '1999'},
#   {'val': 100, 'label': '2000'},
#   {'val': 101, 'label': '2001'},
#   {'val': 102, 'label': '2002'},
#   {'val': 103, 'label': '2003'},
#   {'val': 104, 'label': '2004'},
#   {'val': 105, 'label': '2005'},
#   {'val': 106, 'label': '2006'},
#   {'val': 107, 'label': '2007'},
#   {'val': 108, 'label': '2008'},
#   {'val': 109, 'label': '2009'},
#   {'val': 110, 'label': '2010'},
#   {'val': 111, 'label': '2011'},
#   {'val': 112, 'label': '2012'},
#   {'val': 113, 'label': '2013'},
#   {'val': 114, 'label': '2014'},
#   {'val': 115, 'label': '2015'},
#   {'val': 116, 'label': '2016'},
#   {'val': 117, 'label': '2017'},
#   {'val': 118, 'label': '2018'},
#   {'val': 119, 'label': '2019'}],
#  'turtahun': [{'val': 1, 'label': 'January'},
#   {'val': 2, 'label': 'February'},
#   {'val': 3, 'label': 'March'},
#   {'val': 4, 'label': 'April'},
#   {'val': 5, 'label': 'May'},
#   {'val': 6, 'label': 'June'},
#   {'val': 7, 'label': 'July'},
#   {'val': 8, 'label': 'August'},
#   {'val': 9, 'label': 'September'},
#   {'val': 10, 'label': 'October'},
#   {'val': 11, 'label': 'November'},
#   {'val': 12, 'label': 'December'},
#   {'val': 13, 'label': 'Annually'}],
#  'metadata': {'activity': None, 'variable': None},
#  'datacontent': {'999910791': 2.58,
#   '999910792': 2.34,
#   '999910793': 0.55,
#   '999910794': 3.02,
#   '999910795': 3.05,
#   '999910796': 2.32,
#   '999910797': 2.5,
#   '999910798': 2.34,
#   '999910799': 0.74,
#   '9999107910': 0.89,
#   '9999107911': 0.57,
#   '9999107912': 0.87,
#   '9999107913': 21.77,
#   '999910801': 1.19,
#   '999910802': 1.42,
#   '999910803': 0.22,
#   '999910804': 1.04,
#   '999910805': 3.79,
#   '999910806': 1.49,
#   '999910807': 1.1,
#   '999910808': 1.19,
#   '999910809': 0.36,
#   '9999108010': 1.69,
#   '9999108011': 2.22,
#   '9999108012': 0.26,
#   '9999108013': 15.97,
#   '999910811': 1.31,
#   '999910812': 0.7,
#   '999910813': 0.7,
#   '999910814': 0.93,
#   '999910815': 0.15,
#   '999910816': 0.42,
#   '999910817': 1.2,
#   '999910818': 0.51,
#   '999910819': -0.19,
#   '9999108110': 1.17,
#   '9999108111': -0.32,
#   '9999108112': 0.51,
#   '9999108113': 7.09,
#   '999910821': 4.7,
#   '999910822': 0.54,
#   '999910823': 0.18,
#   '999910824': -0.06,
#   '999910825': 0.18,
#   '999910826': 0.33,
#   '999910827': 1.11,
#   '999910828': -0.46,
#   '999910829': 0.88,
#   '9999108210': 1.24,
#   '9999108211': 0.44,
#   '9999108212': 0.61,
#   '9999108213': 9.69,
#   '999910831': 4.59,
#   '999910832': 0.14,
#   '999910833': -0.6,
#   '999910834': 2.43,
#   '999910835': 0.87,
#   '999910836': 1.58,
#   '999910837': 0.78,
#   '999910838': -0.02,
#   '999910839': 0.82,
#   '9999108310': -0.01,
#   '9999108311': 0.28,
#   '9999108312': 0.6,
#   '9999108313': 11.46,
#   '999910841': 3.42,
#   '999910842': 1.66,
#   '999910843': 0.22,
#   '999910844': 1.31,
#   '999910845': 0.65,
#   '999910846': 0.28,
#   '999910847': 0.37,
#   '999910848': -0.15,
#   '999910849': -0.1,
#   '9999108410': 0.03,
#   '9999108411': 0.03,
#   '9999108412': 1.04,
#   '9999108413': 8.76,
#   '999910851': 0.46,
#   '999910852': -0.5,
#   '999910853': 0.55,
#   '999910854': 2.5,
#   '999910855': 0.36,
#   '999910856': 0.89,
#   '999910857': -0.12,
#   '999910858': -0.07,
#   '999910859': -0.15,
#   '9999108510': 0.08,
#   '9999108511': 0.26,
#   '9999109411': 0.45,
#   '9999109412': 0.52,
#   '9999109413': 9.24,
#   '999910951': 1.16,
#   '999910952': 1.31,
#   '999910953': 0.57,
#   '999910954': 1.69,
#   '999910955': 0.49,
#   '999910956': 0.16,
#   '999910957': 0.71,
#   '999910958': 0.16,
#   '999910959': 0.38,
#   '9999109510': 0.64,
#   '9999109511': 0.42,
#   '9999109512': 0.79,
#   '9999109513': 8.64,
#   '999910961': 2.16,
#   '999910962': 1.71,
#   '999910963': -0.61,
#   '999910964': 0.78,
#   '999910965': 0.06,
#   '999910966': -0.07,
#   '999910967': 0.68,
#   '999910968': 0.27,
#   '999910969': -0.04,
#   '9999109610': 0.41,
#   '9999109611': 0.57,
#   '9999109612': 0.55,
#   '9999109613': 6.47,
#   '999910971': 1.03,
#   '999910972': 1.05,
#   '999910973': -0.12,
#   '999910974': 0.56,
#   '999910975': 0.19,
#   '999910976': -0.17,
#   '999910977': 0.66,
#   '999910978': 0.88,
#   '999910979': 1.29,
#   '9999109710': 1.99,
#   '9999109711': 1.65,
#   '9999109712': 2.04,
#   '9999109713': 11.05,
#   '999910981': 6.88,
#   '999910982': 12.76,
#   '999910983': 5.18,
#   '999910984': 4.7,
#   '999910985': 5.24,
#   '999910986': 4.64,
#   '999910987': 8.56,
#   '999910988': 4.48,
#   '999910989': 3.75,
#   '9999109810': -0.27,
#   '9999109811': 0.48,
#   '9999109812': 1.42,
#   '9999109813': 77.63,
#   '999910991': 2.97,
#   '999910992': 1.26,
#   '999910993': -0.18,
#   '999910994': -0.68,
#   '999910995': -0.28,
#   '999910996': -0.34,
#   '999910997': -1.05,
#   '999910998': -0.93,
#   '999910999': -0.68,
#   '9999109910': 0.06,
#   '9999109911': 0.25,
#   '9999109912': 1.73,
#   '9999109913': 2.01,
#   '9999101001': 1.32,
#   '9999101002': 0.07,
#   '9999101003': -0.45,
#   '9999101004': 0.56,
#   '9999101005': 0.84,
#   '9999101006': 0.5,
#   '9999101007': 1.28,
#   '9999101008': 0.51,
#   '9999101009': -0.06,
#   '99991010010': 1.16,
#   '99991010011': 1.32,
#   '99991010012': 1.94,
#   '99991010013': 9.35,
#   '9999101011': 0.33,
#   '9999101012': 0.87,
#   '9999101013': 0.89,
#   '9999101014': 0.46,
#   '9999101015': 1.13,
#   '9999101016': 1.67,
#   '9999101017': 2.12,
#   '9999101018': -0.21,
#   '9999101019': 0.64,
#   '99991010110': 0.68,
#   '99991010111': 1.71,
#   '99991010112': 1.62,
#   '99991010113': 12.55,
#   '9999101021': 1.99,
#   '9999101022': 1.5,
#   '9999101023': -0.02,
#   '9999101024': -0.24,
#   '9999101025': 0.8,
#   '9999101026': 0.36,
#   '9999101027': 0.82,
#   '9999101028': 0.29,
#   '9999101029': 0.53,
#   '99991010210': 0.54,
#   '99991010211': 1.85,
#   '99991010212': 1.2,
#   '99991010213': 10.03,
#   '9999101031': 0.8,
#   '9999101032': 0.2,
#   '9999101033': -0.23,
#   '9999101034': 0.15,
#   '9999101035': 0.21,
#   '9999101036': 0.09,
#   '9999101037': 0.03,
#   '9999101038': 0.84,
#   '9999101039': 0.36,
#   '99991010310': 0.55,
#   '99991010311': 1.01,
#   '99991010312': 0.94,
#   '99991010313': 5.06,
#   '9999101041': 0.57,
#   '9999101042': -0.02,
#   '9999101043': 0.36,
#   '9999101044': 0.97,
#   '9999101045': 0.88,
#   '9999101046': 0.48,
#   '9999101047': 0.39,
#   '9999101048': 0.09,
#   '9999101049': 0.02,
#   '99991010410': 0.56,
#   '99991010411': 0.89,
#   '99991010412': 1.04,
#   '99991010413': 6.4,
#   '9999101051': 1.43,
#   '9999101052': -0.17,
#   '9999101053': 1.91,
#   '9999101054': 0.34,
#   '9999101055': 0.21,
#   '9999101056': 0.5,
#   '9999101057': 0.78,
#   '9999101058': 0.55,
#   '9999101059': 0.69,
#   '99991010510': 8.7,
#   '99991010511': 1.31,
#   '99991010512': -0.04,
#   '99991010513': 17.11,
#   '9999101061': 1.36,
#   '9999101062': 0.58,
#   '9999101063': 0.03,
#   '9999101064': 0.05,
#   '9999101065': 0.37,
#   '9999101066': 0.45,
#   '9999101067': 0.45,
#   '9999101068': 0.33,
#   '9999101069': 0.38,
#   '99991010610': 0.86,
#   '99991010611': 0.34,
#   '99991010612': 1.21,
#   '99991010613': 6.6,
#   '9999101071': 1.04,
#   '9999101072': 0.62,
#   '9999101073': 0.24,
#   '9999101074': -0.16,
#   '9999101075': 0.1,
#   '9999101076': 0.23,
#   '9999101077': 0.72,
#   '9999101078': 0.75,
#   '9999101079': 0.8,
#   '99991010710': 0.79,
#   '99991010711': 0.18,
#   '99991010712': 1.1,
#   '99991010713': 6.59,
#   '9999101081': 1.77,
#   '9999101082': 0.65,
#   '9999101083': 0.95,
#   '9999101084': 0.57,
#   '9999101085': 1.41,
#   '9999101086': 2.46,
#   '9999101087': 1.37,
#   '9999101088': 0.51,
#   '9999101089': 0.97,
#   '99991010810': 0.45,
#   '99991010811': 0.12,
#   '99991010812': -0.04,
#   '99991010813': 11.06,
#   '9999101091': -0.07,
#   '9999101092': 0.21,
#   '9999101093': 0.22,
#   '9999101094': -0.31,
#   '9999101095': 0.04,
#   '9999101096': 0.11,
#   '9999101097': 0.45,
#   '9999101098': 0.56,
#   '9999101099': 1.05,
#   '99991010910': 0.19,
#   '99991010911': -0.03,
#   '99991010912': 0.33,
#   '99991010913': 2.78,
#   '9999101101': 0.84,
#   '9999101102': -0.08,
#   '9999101103': -0.14,
#   '9999101104': 0.15,
#   '9999101105': 0.29,
#   '9999101106': 0.97,
#   '9999101107': 1.57,
#   '9999101108': 0.76,
#   '9999101109': 0.44,
#   '99991011010': 0.06,
#   '99991011011': 0.6,
#   '99991011012': 0.92,
#   '99991011013': 6.96,
#   '9999101111': 0.89,
#   '9999101112': 0.13,
#   '9999101113': -0.32,
#   '9999101114': -0.31,
#   '9999101115': 0.12,
#   '9999101116': 0.55,
#   '9999101117': 0.67,
#   '9999101118': 0.93,
#   '9999101119': 0.27,
#   '99991011110': -0.12,
#   '99991011111': 0.34,
#   '99991011112': 0.57,
#   '99991011113': 3.79,
#   '9999101121': 0.76,
#   '9999101122': 0.05,
#   '9999101123': 0.07,
#   '9999101124': 0.21,
#   '9999101125': 0.07,
#   '9999101126': 0.62,
#   '9999101127': 0.7,
#   '9999101128': 0.95,
#   '9999101129': 0.01,
#   '99991011210': 0.16,
#   '99991011211': 0.07,
#   '99991011212': 0.54,
#   '99991011213': 4.3,
#   '9999101131': 1.03,
#   '9999101132': 0.75,
#   '9999101133': 0.63,
#   '9999101134': -0.1,
#   '9999101135': -0.03,
#   '9999101136': 1.03,
#   '9999101137': 3.29,
#   '9999101138': 1.12,
#   '9999101139': -0.35,
#   '99991011310': 0.09,
#   '99991011311': 0.12,
#   '99991011312': 0.55,
#   '99991011313': 8.38,
#   '9999101141': 1.07,
#   '9999101142': 0.26,
#   '9999101143': 0.08,
#   '9999101144': -0.02,
#   '9999101145': 0.16,
#   '9999101146': 0.43,
#   '9999101147': 0.93,
#   '9999101148': 0.47,
#   '9999101149': 0.27,
#   '99991011410': 0.47,
#   '99991011411': 1.5,
#   '99991011412': 2.46,
#   '99991011413': 8.36,
#   '9999101151': -0.24,
#   '9999101152': -0.36,
#   '9999101153': 0.17,
#   '9999101154': 0.36,
#   '9999101155': 0.5,
#   '9999101156': 0.54,
#   '9999101157': 0.93,
#   '9999101158': 0.39,
#   '9999101159': -0.05,
#   '99991011510': -0.08,
#   '99991011511': 0.21,
#   '99991011512': 0.96,
#   '99991011513': 3.35,
#   '9999101161': 0.51,
#   '9999101162': -0.09,
#   '9999101163': 0.19,
#   '9999101164': -0.45,
#   '9999101165': 0.24,
#   '9999101166': 0.66,
#   '9999101167': 0.69,
#   '9999101168': -0.02,
#   '9999101169': 0.22,
#   '99991011610': 0.14,
#   '99991011611': 0.47,
#   '99991011612': 0.42,
#   '99991011613': 3.02,
#   '9999101171': 0.97,
#   '9999101172': 0.23,
#   '9999101173': -0.02,
#   '9999101174': 0.09,
#   '9999101175': 0.39,
#   '9999101176': 0.69,
#   '9999101177': 0.22,
#   '9999101178': -0.07,
#   '9999101179': 0.13,
#   '99991011710': 0.01,
#   '99991011711': 0.2,
#   '99991011712': 0.71,
#   '99991011713': 3.61,
#   '9999101181': 0.62,
#   '9999101182': 0.17,
#   '9999101183': 0.2,
#   '9999101184': 0.1,
#   '9999101185': 0.21,
#   '9999101186': 0.59,
#   '9999101187': 0.28,
#   '9999101188': -0.05,
#   '9999101189': -0.18,
#   '99991011810': 0.28,
#   '99991011811': 0.27,
#   '99991011812': 0.62,
#   '99991011813': 3.13,
#   '9999101191': 0.32,
#   '9999101192': -0.08,
#   '9999101193': 0.11,
#   '9999101194': 0.44,
#   '9999101195': 0.68,
#   '9999101196': 0.55,
#   '9999101197': 0.31,
#   '9999101198': 0.12,
#   '9999101199': -0.27,
#   '99991011910': 0.02,
#   '99991011911': 0.14,
#   '99991011912': 0.34,
#   '99991011913': 2.72,
#   '1107101141': 2.67,
#   '1107101142': -1.28,
#   '1107101143': -0.73,
#   '1107101144': -0.06,
#   '1107101145': 0.42,
#   '1107101146': 0.2,
#   '1107101147': 2.41,
#   '1107101148': 0.68,
#   '1107101149': 0.58,
#   '11071011410': 0.82,
#   '11071011411': 1.08,
#   '11071011412': 1.17,
#   '11071011413': 8.2,
#   '1107101151': -0.12,
#   '1107101152': -0.97,
#   '1107101153': -0.64,
#   '1107101154': 0.08,
#   '1107101155': 0.67,
#   '1107101156': 0.57,
#   '1107101157': 0.84,
#   '1107101158': -0.63,
#   '1107101159': -0.02,
#   '11071011510': 0.05,
#   '11071011511': 0.28,
#   '11071011512': 0.49,
#   '11071011513': 0.58,
#   '1107101161': 0.46,
#   '1107101162': 0.37,
#   '1107101163': -0.07,
#   '1107101164': -0.14,
#   '1107101165': 0.39,
#   '1107101166': 0.16,
#   '1107101167': 0.41,
#   '1107101168': 0.52,
#   '1107101169': 0.83,
#   '11071011610': 0.32,
#   '11071011611': 0.15,
#   '11071011612': 0.31,
#   '11071011613': 3.77,
#   '1107101171': 1.34,
#   '1107101172': 0.41,
#   '1107101173': -0.06,
#   '1107101174': -0.52,
#   '1107101175': 0.06,
#   '1107101176': 0.48,
#   '1107101177': 0.01,
#   '1107101178': 0.24,
#   '1107101179': 0.37,
#   '11071011710': 0.28,
#   '11071011711': 0.88,
#   '11071011712': 1.18,
#   '11071011713': 4.76,
#   '1107101181': -0.14,
#   '1107101182': -0.25,
#   '1107101183': 0.21,
#   '1107101184': -0.52,
#   '1107101185': 0.57,
#   '1107101186': 0.2,
#   '1107101187': 0.71,
#   '1107101188': 0.23,
#   '1107101189': -0.41,
#   '11071011810': -0.17,
#   '11071011811': 0.08,
#   '11071011812': 0.48,
#   '11071011813': 0.96,
#   '1107101191': 0.91,
#   '1107101192': -0.71,
#   '1107101193': 0.39,
#   '1107101194': 0.18,
#   '1107101195': 1.33,
#   '1107101196': 1.3,
#   '1107101197': 0.21,
#   '1107101198': 0.2,
#   '1107101199': 0.91,
#   '11071011910': 0.18,
#   '11071011911': -0.5,
#   '11071011912': -0.19,
#   '11071011913': 4.28,
#   '117110891': -0.06,
#   '117110892': 1.03,
#   '117110893': 0.18,
#   '117110894': 1.22,
#   '117110895': 0.35,
#   '117110896': 0.79,
#   '117110897': 1.21,
#   '117110898': 1.93,
#   '117110899': 0.25,
#   '1171108910': 0.07,
#   '1171108911': 0.13,
#   '1171108912': 0.51,
#   '1171108913': 8.25,
#   '117110901': -1.24,
#   '117110902': -0.72,
#   '117110903': 0.14,
#   '117110904': 1.19,
#   '117110905': 0.11,
#   '117110906': 2.88,
#   '117110907': 3.42,
#   '117110908': -0.64,
#   '117110909': 0.05,
#   '1171109010': 1.02,
#   '1171109011': 1.3,
#   '1171109012': 1.34,
#   '1171109013': 8.85,
#   '117110911': 0.31,
#   '117110912': 0.07,
#   '117110913': -0.55,
#   '117110914': -0.4,
#   '117110915': 0.22,
#   '117110916': 0.6,
#   '117110917': 2.75,
#   '117110918': 0.5,
#   '117110919': 0.77,
#   '1171109110': -0.02,
#   '1171109111': 0.95,
#   '1171109112': 1.67,
#   '1171109113': 6.87,
#   '117110921': -1.48,
#   '117110922': 1.12,
#   '117110923': 0.85,
#   '117110924': -0.28,
#   '117110925': -0.31,
#   '117110926': 0.75,
#   '117110927': 0.3,
#   '117110928': 0.48,
#   '117110929': -0.07,
#   '1171109210': 0.26,
#   '1171109211': -0.04,
#   '1171109212': 0.66,
#   '1171109213': 2.24,
#   '117110931': 1.96,
#   '117110932': 2.44,
#   '117110933': 0.9,
#   '117110934': 0.91,
#   '117110935': 0.34,
#   '117110936': 1.1,
#   '117110937': 1.84,
#   '117110938': -0.51,
#   '117110939': 0.18,
#   '1171109310': 0.72,
#   '1171109311': -0.63,
#   '1171109312': 0.58,
#   '1171109313': 9.83,
#   '117110941': 0.26,
#   '117110942': 0.45,
#   '117110943': 2.48,
#   '117110944': -0.24,
#   '117110945': 0.49,
#   '117110946': 1.33,
#   '117110947': 0.93,
#   '117110948': 0.45,
#   '117110949': 0.36,
#   '1171109410': 0.15,
#   '1171109411': 1.59,
#   '1171109412': 0.72,
#   '1171109413': 8.97,
#   '117110951': 1.03,
#   '117110952': -0.38,
#   '117110953': 1.83,
#   '117110954': 1.32,
#   '117110955': 1.17,
#   '117110956': 0.78,
#   '117110957': 1.04,
#   '117110958': 0.14,
#   '117110959': 0.2,
#   '1171109510': 0.29,
#   '1171109511': 1.07,
#   '1171109512': 0.67,
#   '1171109513': 9.16,
#   '117110961': 0.67,
#   '117110962': 0.91,
#   '117110963': 0.12,
#   '117110964': 1.63,
#   '117110965': -0.14,
#   '117110966': 0.1,
#   '117110967': 1.14,
#   '117110968': -0.03,
#   '117110969': -0.3,
#   '1171109610': 2.2,
#   '1171109611': 0.07,
#   '1171109612': 0.29,
#   '1171109613': 6.66,
#   '117110971': -0.31,
#   '117110972': -0.31,
#   '117110973': 2.42,
#   '117110974': -0.96,
#   '117110975': 0.07,
#   '117110976': -0.31,
#   '117110977': 0.48,
#   '117110978': 1.53,
#   '117110979': 0.55,
#   '1171109710': 0.97,
#   '1171109711': 3.24,
#   '1171109712': 1.64,
#   '1171109713': 9.9,
#   '117110981': 4.46,
#   '117110982': 11.15,
#   '117110983': 5.07,
#   '117110984': 3.05,
#   '117110985': 8.03,
#   '117110986': 7.36,
#   '117110987': 7.12,
#   '117110988': 4.78,
#   '117110989': 4.9,
#   '1171109810': 0.11,
#   '1171109811': 1.14,
#   '1171109812': 3,
#   '1171109813': 79.01,
#   '117110991': 3.41,
#   '117110992': 1.99,
#   '117110993': 0.34,
#   '117110994': -1.02,
#   '117110995': -0.94,
#   '117110996': 0.38,
#   '117110997': -1.08,
#   '117110998': 1.01,
#   '117110999': -3.25,
#   '1171109910': 2,
#   '1171109911': 1.36,
#   '1171109912': 2.3,
#   '1171109913': 5.57,
#   '1171101001': 3.31,
#   '1171101002': 0.32,
#   '1171101003': 0.06,
#   '1171101004': -1.37,
#   '1171101005': -0.21,
#   '1171101006': -0.45,
#   '1171101007': 1.4,
#   '1171101008': 1.53,
#   '1171101009': 0.22,
#   '1171101178': 0.42,
#   '1171101179': 0.62,
#   '11711011710': 0.17,
#   '11711011711': 0.3,
#   '11711011712': 1.06,
#   '11711011713': 4.86,
#   '1171101181': -0.33,
#   '1171101182': -0.21,
#   '1171101183': -0.08,
#   '1171101184': -0.1,
#   '1171101185': 0.72,
#   '1171101186': 0.84,
#   '1171101187': 0.08,
#   '1171101188': 0.5,
#   '1171101189': -0.75,
#   '11711011810': 0.32,
#   '11711011811': 0.92,
#   '11711011812': 0.02,
#   ...}}

# %%
res['']

# %%
res['tahun']
# Out:
# [{'val': 79, 'label': '1979'},
#  {'val': 80, 'label': '1980'},
#  {'val': 81, 'label': '1981'},
#  {'val': 82, 'label': '1982'},
#  {'val': 83, 'label': '1983'},
#  {'val': 84, 'label': '1984'},
#  {'val': 85, 'label': '1985'},
#  {'val': 86, 'label': '1986'},
#  {'val': 87, 'label': '1987'},
#  {'val': 88, 'label': '1988'},
#  {'val': 89, 'label': '1989'},
#  {'val': 90, 'label': '1990'},
#  {'val': 91, 'label': '1991'},
#  {'val': 92, 'label': '1992'},
#  {'val': 93, 'label': '1993'},
#  {'val': 94, 'label': '1994'},
#  {'val': 95, 'label': '1995'},
#  {'val': 96, 'label': '1996'},
#  {'val': 97, 'label': '1997'},
#  {'val': 98, 'label': '1998'},
#  {'val': 99, 'label': '1999'},
#  {'val': 100, 'label': '2000'},
#  {'val': 101, 'label': '2001'},
#  {'val': 102, 'label': '2002'},
#  {'val': 103, 'label': '2003'},
#  {'val': 104, 'label': '2004'},
#  {'val': 105, 'label': '2005'},
#  {'val': 106, 'label': '2006'},
#  {'val': 107, 'label': '2007'},
#  {'val': 108, 'label': '2008'},
#  {'val': 109, 'label': '2009'},
#  {'val': 110, 'label': '2010'},
#  {'val': 111, 'label': '2011'},
#  {'val': 112, 'label': '2012'},
#  {'val': 113, 'label': '2013'},
#  {'val': 114, 'label': '2014'},
#  {'val': 115, 'label': '2015'},
#  {'val': 116, 'label': '2016'},
#  {'val': 117, 'label': '2017'},
#  {'val': 118, 'label': '2018'},
#  {'val': 119, 'label': '2019'}]

# %%
res['tahun']
# Out:
# [{'val': 79, 'label': '1979'},
#  {'val': 80, 'label': '1980'},
#  {'val': 81, 'label': '1981'},
#  {'val': 82, 'label': '1982'},
#  {'val': 83, 'label': '1983'},
#  {'val': 84, 'label': '1984'},
#  {'val': 85, 'label': '1985'},
#  {'val': 86, 'label': '1986'},
#  {'val': 87, 'label': '1987'},
#  {'val': 88, 'label': '1988'},
#  {'val': 89, 'label': '1989'},
#  {'val': 90, 'label': '1990'},
#  {'val': 91, 'label': '1991'},
#  {'val': 92, 'label': '1992'},
#  {'val': 93, 'label': '1993'},
#  {'val': 94, 'label': '1994'},
#  {'val': 95, 'label': '1995'},
#  {'val': 96, 'label': '1996'},
#  {'val': 97, 'label': '1997'},
#  {'val': 98, 'label': '1998'},
#  {'val': 99, 'label': '1999'},
#  {'val': 100, 'label': '2000'},
#  {'val': 101, 'label': '2001'},
#  {'val': 102, 'label': '2002'},
'999910954', '999910955', '999910956', '999910957', '999910958', '999910959', '9999109510', '9999109511', '9999109512', '9999109513', '999910961', '999910962', '999910963', '999910964', '999910965', '999910966', '999910967', '999910968', '999910969', '9999109610', '9999109611', '9999109612', '9999109613', '999910971', '999910972', '999910973', '999910974', '999910975', '999910976', '999910977', '999910978', '999910979', '9999109710', '9999109711', '9999109712', '9999109713', '999910981', '999910982', '999910983', '999910984', '999910985', '999910986', '999910987', '999910988', '999910989', '9999109810', '9999109811', '9999109812', '9999109813', '999910991', '999910992', '999910993', '999910994', '999910995', '999910996', '999910997', '999910998', '999910999', '9999109910', '9999109911', '9999109912', '9999109913', '9999101001', '9999101002', '9999101003', '9999101004', '9999101005', '9999101006', '9999101007', '9999101008', '9999101009', '99991010010', '99991010011', '99991010012', '99991010013', '9999101011', '9999101012', '9999101013', '9999101014', '9999101015', '9999101016', '9999101017', '9999101018', '9999101019', '99991010110', '99991010111', '99991010112', ...

# %%
[f'{key[:6]} {key[6:]}' for key in res['datacontent'].keys() if key[0:4] == '9999' and (key[6:8]=="99" or key[6:9]=="100") and '999910' in key]
# Out:
# ['999910 991',
#  '999910 992',
#  '999910 993',
#  '999910 994',
#  '999910 995',
#  '999910 996',
#  '999910 997',
#  '999910 998',
#  '999910 999',
#  '999910 9910',
#  '999910 9911',
#  '999910 9912',
#  '999910 9913',
#  '999910 1001',
#  '999910 1002',
#  '999910 1003',
#  '999910 1004',
#  '999910 1005',
#  '999910 1006',
#  '999910 1007',
#  '999910 1008',
#  '999910 1009',
#  '999910 10010',
#  '999910 10011',
#  '999910 10012',
#  '999910 10013']

# %%
json.dump(res, open("indonesia_0000_543.json", "w"))

# %%
res['var']
# Out:
# [{'val': 543,
#   'label': 'Unemployment Rate by Province',
#   'unit': 'Percent',
#   'subj': 'Employment',
#   'def': '',
#   'decimal': '2',
#   'note': '&lt;pre class=&quot;tw-data-text tw-text-large XcVN5d tw-ta&quot; style=&quot;text-align:left;&quot; dir=&quot;ltr&quot;&gt;&lt;span lang=&quot;en&quot; xml:lang=&quot;en&quot;&gt;The 2011-2013 data uses the Backcast of the Component Projection Weigher\nThe 2018-2020 data uses Backcast from the 2015 SUPAS-based Weigher\n1986-1998, calculations without data for the Province of Timor Timor\nIn 1995, Sakernas was not implemented\nIn 2000, without Maluku\nSource: National Labor Force Survey (Sakernas)&lt;/span&gt;&lt;/pre&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;&lt;br /&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&lt;/p&gt;'}]

# %%
list(res['datacontent'].keys() )
# Out:
# ['999910791',
#  '999910792',
#  '999910793',
#  '999910794',
#  '999910795',
#  '999910796',
#  '999910797',
#  '999910798',
#  '999910799',
#  '9999107910',
#  '9999107911',
#  '9999107912',
#  '9999107913',
#  '999910801',
#  '999910802',
#  '999910803',
#  '999910804',
#  '999910805',
#  '999910806',
#  '999910807',
#  '999910808',
#  '999910809',
#  '9999108010',
#  '9999108011',
#  '9999108012',
#  '9999108013',
#  '999910811',
#  '999910812',
#  '999910813',
#  '999910814',
#  '999910815',
#  '999910816',
#  '999910817',
#  '999910818',
#  '999910819',
#  '1171101127',
#  '1171101128',
#  '1171101129',
#  '11711011210',
#  '11711011211',
#  '11711011212',
#  '11711011213',
#  '1171101131',
#  '1171101132',
#  '1171101133',
#  '1171101134',
#  '1171101135',
#  '1171101136',
#  '1171101137',
#  '1171101138',
#  '1171101139',
#  '11711011310',
#  '11711011311',
#  '11711011312',
#  '11711011313',
#  '1171101141',
#  '1171101142',
#  '1171101143',
#  '1171101144',
#  '1171101145',
#  '1171101146',
#  '1171101147',
#  '1171101148',
#  '1171101149',
#  '11711011410',
#  '11711011411',
#  '11711011412',
#  '11711011413',
#  '1171101151',
#  '1171101152',
#  '1171101153',
#  '1171101154',
#  '1171101155',
#  '1171101156',
#  '1171101157',
#  '1171101158',
#  '1171101159',
#  '11711011510',
#  '11711011511',
#  '11711011512',
#  '11711011513',
#  '1171101161',
#  '1171101162',
#  '1171101163',
#  '1171101164',
#  '1171101165',
#  '1171101166',
#  '1171101167',
#  '1171101168',
#  '1171101169',
#  '11711011610',
#  '11711011611',
#  '11711011612',
#  '11711011613',
#  '1171101171',
#  '1171101172',
#  '1171101173',
#  '1171101174',
#  '1171101175',
#  '1171101176',
#  '1171101177',
#  '1171101178',
#  '1171101179',
#  '11711011710',
#  '11711011711',
#  '11711011712',
#  '11711011713',
#  '1171101181',
#  '1171101182',
#  '1171101183',
#  '1171101184',
#  '1171101185',
#  '1171101186',
#  '1171101187',
#  '1171101188',
#  '1171101189',
#  '11711011810',
#  '11711011811',
#  '11711011812',
#  ...]

# %%
data_from_bps(res)
# Out:
# {'086': '1986', '087': '1987', '088': '1988', '089': '1989', '090': '1990', '091': '1991', '092': '1992', '093': '1993', '094': '1994', '096': '1996', '097': '1997', '098': '1998', '099': '1999', '100': '2000', '101': '2001', '102': '2002', '103': '2003', '104': '2004', '105': '2005', '106': '2006', '107': '2007', '108': '2008', '109': '2009', '110': '2010', '111': '2011', '112': '2012', '113': '2013', '114': '2014', '115': '2015', '116': '2016', '117': '2017', '118': '2018', '119': '2019', '120': '2020', '121': '2021', '122': '2022', '123': '2023'}
# ['086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '086', '087', '088', '089', '090', '091', '092', '093', '094', '096', '097', '098', '099', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '012', '012', '012', '012', '012', '012', '012', '0 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> data_from_bps(res)
#
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 35 in data_from_bps(res)
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=19'>20</a> print(tahun_labels)
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=20'>21</a> print(tahun)
# ---> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=21'>22</a> tahun = [tahun_labels[tahun] for tahun in tahun] # replace tahun with labels
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=23'>24</a> return(tahun)
#
# /Users/finn/Documents/Stats APIs/Indonesia.ipynb Cell 35 in <listcomp>(.0)
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=19'>20</a> print(tahun_labels)
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=20'>21</a> print(tahun)
# ---> <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=21'>22</a> tahun = [tahun_labels[tahun] for tahun in tahun] # replace tahun with labels
#      <a href='vscode-notebook-cell:/Users/finn/Documents/Stats%20APIs/Indonesia.ipynb#Y145sZmlsZQ%3D%3D?line=23'>24</a> return(tahun)
#
# KeyError: '010'

# %%
len(str(res['var'][0]['val']))
# Out:
# 3

# %%
res.keys()
# Out:
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])

# %%
'12'.zfill(4)
# Out:
# '0012'

# %%
data_from_bps(res)
# Out:
# ['INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'INDONESIA',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'ACEH',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA UTARA',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'SUMATERA BARAT',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'RIAU',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'JAMBI',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'SUMATERA SELATAN',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'BENGKULU',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'LAMPUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. BANGKA BELITUNG',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'KEP. RIAU',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'DKI JAKARTA',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA BARAT',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'JAWA TENGAH',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'DI YOGYAKARTA',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'JAWA TIMUR',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BANTEN',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'BALI',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA BARAT',
#  'NUSA TENGGARA TIMUR',
#  'NUSA TENGGARA TIMUR',
#  'NUSA TENGGARA TIMUR',
#  ...]

# %%
# reshape res['vervar] from list of dicts to dict of dicts
vervar_dict = {

# %%
vervar_dict = {vervar['val']: vervar['label'] for vervar in res['vervar']}
vervar_dict
# Out:
# {9999: 'INDONESIA',
#  1100: 'ACEH',
#  1200: 'SUMATERA UTARA',
#  1300: 'SUMATERA BARAT',
#  1400: 'RIAU',
#  1500: 'JAMBI',
#  1600: 'SUMATERA SELATAN',
#  1700: 'BENGKULU',
#  1800: 'LAMPUNG',
#  1900: 'KEP. BANGKA BELITUNG',
#  2100: 'KEP. RIAU',
#  3100: 'DKI JAKARTA',
#  3200: 'JAWA BARAT',
#  3300: 'JAWA TENGAH',
#  3400: 'DI YOGYAKARTA',
#  3500: 'JAWA TIMUR',
#  3600: 'BANTEN',
#  5100: 'BALI',
#  5200: 'NUSA TENGGARA BARAT',
#  5300: 'NUSA TENGGARA TIMUR',
#  6100: 'KALIMANTAN BARAT',
#  6200: 'KALIMANTAN TENGAH',
#  6300: 'KALIMANTAN SELATAN',
#  6400: 'KALIMANTAN TIMUR',
#  6500: 'KALIMANTAN UTARA',
#  7100: 'SULAWESI UTARA',
#  7200: 'SULAWESI TENGAH',
#  7300: 'SULAWESI SELATAN',
#  7400: 'SULAWESI TENGGARA',
#  7500: 'GORONTALO',
#  7600: 'SULAWESI BARAT',
#  8100: 'MALUKU',
#  8200: 'MALUKU UTARA',
#  9100: 'PAPUA BARAT',
#  9400: 'PAPUA'}

# %%
res['datacontent'].items()
# Out:
# dict_items([('9999543086191', 2.7), ('9999543087191', 2.62), ('9999543088191', 2.85), ('9999543089191', 2.81), ('9999543090191', 2.55), ('9999543091191', 2.62), ('9999543092191', 2.74), ('9999543093191', 2.79), ('9999543094191', 4.36), ('9999543096191', 4.87), ('9999543097191', 4.69), ('9999543098191', 5.46), ('9999543099191', 6.36), ('99995430100191', 6.08), ('99995430101191', 8.1), ('99995430102191', 9.06), ('99995430103191', 9.67), ('99995430104191', 9.86), ('99995430105189', 10.26), ('99995430105190', 11.24), ('99995430106189', 10.45), ('99995430106190', 10.28), ('99995430107189', 9.75), ('99995430107190', 9.11), ('99995430108189', 8.46), ('99995430108190', 8.39), ('99995430109189', 8.14), ('99995430109190', 7.87), ('99995430110189', 7.41), ('99995430110190', 7.14), ('99995430111189', 6.96), ('99995430111190', 7.48), ('99995430112189', 6.37), ('99995430112190', 6.13), ('99995430113189', 5.88), ('99995430113190', 6.17), ('99995430114189', 5.7), ('99995430114190',
[key for key in res['datacontent'].keys() if "99995430110" in key]
# Out:
# ['99995430110189', '99995430110190']

# %%
len("9999543110")
# Out:
# 10

# %%
len("t")
# Out:
# 10

# %%
res['turtahun']
# Out:
# [{'val': 191, 'label': 'Yearly'},
#  {'val': 189, 'label': 'February'},
#  {'val': 190, 'label': 'August'}]

# %% [markdown]
# 10791

# %%
res['datacontent']['9999']

# %%
res['turtahun']
# Out:
# [{'val': 1, 'label': 'January'},
#  {'val': 2, 'label': 'February'},
#  {'val': 3, 'label': 'March'},
#  {'val': 4, 'label': 'April'},
#  {'val': 5, 'label': 'May'},
#  {'val': 6, 'label': 'June'},
#  {'val': 7, 'label': 'July'},
#  {'val': 8, 'label': 'August'},
#  {'val': 9, 'label': 'September'},
#  {'val': 10, 'label': 'October'},
#  {'val': 11, 'label': 'November'},
#  {'val': 12, 'label': 'December'},
#  {'val': 13, 'label': 'Annually'}]

# %%
res['datacontent']
# Out:
# {'999910791': 2.58,
#  '999910792': 2.34,
#  '999910793': 0.55,
#  '999910794': 3.02,
#  '999910795': 3.05,
#  '999910796': 2.32,
#  '999910797': 2.5,
#  '999910798': 2.34,
#  '999910799': 0.74,
#  '9999107910': 0.89,
#  '9999107911': 0.57,
#  '9999107912': 0.87,
#  '9999107913': 21.77,
#  '999910801': 1.19,
#  '999910802': 1.42,
#  '999910803': 0.22,
#  '999910804': 1.04,
#  '999910805': 3.79,
#  '999910806': 1.49,
#  '999910807': 1.1,
#  '999910808': 1.19,
#  '999910809': 0.36,
#  '9999108010': 1.69,
#  '9999108011': 2.22,
#  '9999108012': 0.26,
#  '9999108013': 15.97,
#  '999910811': 1.31,
#  '999910812': 0.7,
#  '999910813': 0.7,
#  '999910814': 0.93,
#  '999910815': 0.15,
#  '999910816': 0.42,
#  '999910817': 1.2,
#  '999910818': 0.51,
#  '999910819': -0.19,
#  '9999108110': 1.17,
#  '9999108111': -0.32,
#  '9999108112': 0.51,
#  '9999108113': 7.09,
#  '999910821': 4.7,
#  '999910822': 0.54,
#  '999910823': 0.18,
#  '999910824': -0.06,
#  '999910825': 0.18,
#  '999910826': 0.33,
#  '999910827': 1.11,
#  '999910828': -0.46,
#  '999910829': 0.88,
#  '9999108210': 1.24,
#  '9999108211': 0.44,
#  '9999108212': 0.61,
#  '9999108213': 9.69,
#  '999910831': 4.59,
#  '999910832': 0.14,
#  '999910833': -0.6,
#  '999910834': 2.43,
#  '999910835': 0.87,
#  '999910836': 1.58,
#  '999910837': 0.78,
#  '999910838': -0.02,
#  '999910839': 0.82,
#  '9999108310': -0.01,
#  '9999108311': 0.28,
#  '9999108312': 0.6,
#  '9999108313': 11.46,
#  '999910841': 3.42,
#  '999910842': 1.66,
#  '999910843': 0.22,
#  '999910844': 1.31,
#  '999910845': 0.65,
#  '999910846': 0.28,
#  '999910847': 0.37,
#  '999910848': -0.15,
#  '999910849': -0.1,
#  '9999108410': 0.03,
#  '9999108411': 0.03,
#  '9999108412': 1.04,
#  '9999108413': 8.76,
#  '999910851': 0.46,
#  '9999101198': 0.12,
#  '9999101199': -0.27,
#  '99991011910': 0.02,
#  '99991011911': 0.14,
#  '99991011912': 0.34,
#  '99991011913': 2.72}

# %%
res['tahun']
# Out:
# [{'val': 79, 'label': '1979'},
#  {'val': 80, 'label': '1980'},
#  {'val': 81, 'label': '1981'},
#  {'val': 82, 'label': '1982'},
#  {'val': 83, 'label': '1983'},
#  {'val': 84, 'label': '1984'},
#  {'val': 85, 'label': '1985'},
#  {'val': 86, 'label': '1986'},
#  {'val': 87, 'label': '1987'},
#  {'val': 88, 'label': '1988'},
#  {'val': 89, 'label': '1989'},
#  {'val': 90, 'label': '1990'},
#  {'val': 91, 'label': '1991'},
#  {'val': 92, 'label': '1992'},
#  {'val': 93, 'label': '1993'},
#  {'val': 94, 'label': '1994'},
#  {'val': 95, 'label': '1995'},
#  {'val': 96, 'label': '1996'},
#  {'val': 97, 'label': '1997'},
#  {'val': 98, 'label': '1998'},
#  {'val': 99, 'label': '1999'},
#  {'val': 100, 'label': '2000'},
#  {'val': 101, 'label': '2001'},
#  {'val': 102, 'label': '2002'},
#  {'val': 103, 'label': '2003'},
#  {'val': 104, 'label': '2004'},
#  {'val': 105, 'label': '2005'},
#  {'val': 106, 'label': '2006'},
#  {'val': 107, 'label': '2007'},
#  {'val': 108, 'label': '2008'},
#  {'val': 109, 'label': '2009'},
#  {'val': 110, 'label': '2010'},
#  {'val': 111, 'label': '2011'},
#  {'val': 112, 'label': '2012'},
#  {'val': 113, 'label': '2013'},
#  {'val': 114, 'label': '2014'},
#  {'val': 115, 'label': '2015'},
#  {'val': 116, 'label': '2016'},
#  {'val': 117, 'label': '2017'},
#  {'val': 118, 'label': '2018'},
#  {'val': 119, 'label': '2019'}]

# %%
res.keys()
# Out:
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])

# %%
res['var']
# Out:
# [{'val': 1,
#   'label': 'Inflation (Umum)',
#   'unit': '',
#   'subj': 'Consumer Prices Indices',
#   'def': '',
#   'decimal': '',
#   'note': '&lt;p&gt;1. Before April 1979, the base year is September 1966 (September 1966 = 100)&lt;br /&gt;\n2.Since April 1979, the Term &quot;Consumer Price Index&quot; has been used ( the term that has been used before is &quot;Cost Living Index&quot;). The base year is April 1977-Maret 1978. CPI using a consumption pattern obtained from 1977/1978 Cost Living Survey in 17 Provincial Capital cities.) (April 1977-Maret 1978=100).&lt;br /&gt;\n3. Since April 1990-1997, CPI has been based on a consumption pattern obtained from Cost Living Survey in 27 Provincial Capital cities and using 1988/1989 base year) (1988/1989=100)&lt;br /&gt;\n4. Since December 1997, CPI has been based on a consumption pattern obtained from 1996 Cost of Living Survey in 44 cities(1996=100)&lt;br /&gt;\n5. Since January 2004, CPI has been based on a consumption pattern obtained from 2002 Cost of Living Survey in 45 cities(2002=100)&lt;br /&gt;\n6. Since June 2008, CPI has been based on a consumption pattern obtained from 2007 Cost of Living Survey in 66 cities(2007=100)&lt;br /&gt;\n7. Since 2014, CPI has been based on a consumption pattern obtained from 2012 Cost of Living Survey in 82 cities (2012=100)&lt;br /&gt;&lt;/p&gt;'}]

# %%
res['tahun']
# Out:
# [{'val': 79, 'label': '1979'},
#  {'val': 80, 'label': '1980'},
#  {'val': 81, 'label': '1981'},
#  {'val': 82, 'label': '1982'},
#  {'val': 83, 'label': '1983'},
#  {'val': 84, 'label': '1984'},
#  {'val': 85, 'label': '1985'},
#  {'val': 86, 'label': '1986'},
#  {'val': 87, 'label': '1987'},
#  {'val': 88, 'label': '1988'},
#  {'val': 89, 'label': '1989'},
#  {'val': 90, 'label': '1990'},
#  {'val': 91, 'label': '1991'},
#  {'val': 92, 'label': '1992'},
#  {'val': 93, 'label': '1993'},
#  {'val': 94, 'label': '1994'},
#  {'val': 95, 'label': '1995'},
#  {'val': 96, 'label': '1996'},
#  {'val': 97, 'label': '1997'},
#  {'val': 98, 'label': '1998'},
#  {'val': 99, 'label': '1999'},
#  {'val': 100, 'label': '2000'},
#  {'val': 101, 'label': '2001'},
#  {'val': 102, 'label': '2002'},
#  {'val': 103, 'label': '2003'},
#  {'val': 104, 'label': '2004'},
#  {'val': 105, 'label': '2005'},
#  {'val': 106, 'label': '2006'},
#  {'val': 107, 'label': '2007'},
#  {'val': 108, 'label': '2008'},
#  {'val': 109, 'label': '2009'},
#  {'val': 110, 'label': '2010'},
#  {'val': 111, 'label': '2011'},
#  {'val': 112, 'label': '2012'},
#  {'val': 113, 'label': '2013'},
#  {'val': 114, 'label': '2014'},
#  {'val': 115, 'label': '2015'},
#  {'val': 116, 'label': '2016'},
#  {'val': 117, 'label': '2017'},
#  {'val': 118, 'label': '2018'},
#  {'val': 119, 'label': '2019'}]

# %%
[yr for yr in res['tahun'] if yr['val']==107]
# Out:
# [{'val': 107, 'label': '2007'}]

# %%
print(res.keys())
res["datacontent"]
# Out:
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])
# {'999910791': 2.58,
#  '999910792': 2.34,
#  '999910793': 0.55,
#  '999910794': 3.02,
#  '999910795': 3.05,
#  '999910796': 2.32,
#  '999910797': 2.5,
#  '999910798': 2.34,
#  '999910799': 0.74,
#  '9999107910': 0.89,
#  '9999107911': 0.57,
#  '9999107912': 0.87,
#  '9999107913': 21.77,
#  '999910801': 1.19,
#  '999910802': 1.42,
#  '999910803': 0.22,
#  '999910804': 1.04,
#  '999910805': 3.79,
#  '999910806': 1.49,
#  '999910807': 1.1,
#  '999910808': 1.19,
#  '999910809': 0.36,
#  '9999108010': 1.69,
#  '9999108011': 2.22,
#  '9999108012': 0.26,
#  '9999108013': 15.97,
#  '999910811': 1.31,
#  '999910812': 0.7,
#  '999910813': 0.7,
#  '999910814': 0.93,
#  '999910815': 0.15,
#  '999910816': 0.42,
#  '999910817': 1.2,
#  '999910818': 0.51,
#  '999910819': -0.19,
#  '9999108110': 1.17,
#  '9999108111': -0.32,
#  '9999108112': 0.51,
#  '9999108113': 7.09,
#  '999910821': 4.7,
#  '999910822': 0.54,
#  '999910823': 0.18,
#  '999910824': -0.06,
#  '999910825': 0.18,
#  '999910826': 0.33,
#  '999910827': 1.11,
#  '999910828': -0.46,
#  '999910829': 0.88,
#  '9999108210': 1.24,
#  '9999101175': 0.39,
#  '9999101176': 0.69,
#  '9999101177': 0.22,
#  '9999101178': -0.07,
#  '9999101179': 0.13,
#  '99991011710': 0.01,
#  '99991011711': 0.2,
#  '99991011712': 0.71,
#  '99991011713': 3.61,
#  '9999101181': 0.62,
#  '9999101182': 0.17,
#  '9999101183': 0.2,
#  '9999101184': 0.1,
#  '9999101185': 0.21,
#  '9999101186': 0.59,
#  '9999101187': 0.28,
#  '9999101188': -0.05,
#  '9999101189': -0.18,
#  '99991011810': 0.28,
#  '99991011811': 0.27,
#  '99991011812': 0.62,
#  '99991011813': 3.13,
#  '9999101191': 0.32,
#  '9999101192': -0.08,
#  '9999101193': 0.11,
#  '9999101194': 0.44,
#  '9999101195': 0.68,
#  '9999101196': 0.55,
#  '9999101197': 0.31,
#  '9999101198': 0.12,
#  '9999101199': -0.27,
#  '99991011910': 0.02,
#  '99991011911': 0.14,
#  '99991011912': 0.34,
#  '99991011913': 2.72}

# %%
first_key = list(res['datacontent'].keys())[0]
print(f"{first_key} : {res['datacontent'][first_key]}" )
# Out:
# 999910791 : 2.58

# %%
res.keys()
# Out:
# dict_keys(['status', 'data-availability', 'var', 'turvar', 'labelvervar', 'vervar', 'tahun', 'turtahun', 'metadata', 'datacontent'])

# %%
# Out:
# {'999910791': 2.58,
#  '999910792': 2.34,
#  '999910793': 0.55,
#  '999910794': 3.02,
#  '999910795': 3.05,
#  '999910796': 2.32,
#  '999910797': 2.5,
#  '999910798': 2.34,
#  '999910799': 0.74,
#  '9999107910': 0.89,
#  '9999107911': 0.57,
#  '9999107912': 0.87,
#  '9999107913': 21.77,
#  '999910801': 1.19,
#  '999910802': 1.42,
#  '999910803': 0.22,
#  '999910804': 1.04,
#  '999910805': 3.79,
#  '999910806': 1.49,
#  '999910807': 1.1,
#  '999910808': 1.19,
#  '999910809': 0.36,
#  '9999108010': 1.69,
#  '9999108011': 2.22,
#  '9999108012': 0.26,
#  '9999108013': 15.97,
#  '999910811': 1.31,
#  '999910812': 0.7,
#  '999910813': 0.7,
#  '999910814': 0.93,
#  '999910815': 0.15,
#  '999910816': 0.42,
#  '999910817': 1.2,
#  '999910818': 0.51,
#  '999910819': -0.19,
#  '9999108110': 1.17,
#  '9999108111': -0.32,
#  '9999108112': 0.51,
#  '9999108113': 7.09,
#  '999910821': 4.7,
#  '999910822': 0.54,
#  '999910823': 0.18,
#  '999910824': -0.06,
#  '999910825': 0.18,
#  '999910826': 0.33,
#  '999910827': 1.11,
#  '999910828': -0.46,
#  '999910829': 0.88,
#  '9999108210': 1.24,
#  '9999108211': 0.44,
#  '9999108212': 0.61,
#  '9999108213': 9.69,
#  '999910831': 4.59,
#  '999910832': 0.14,
#  '999910833': -0.6,
#  '999910834': 2.43,
#  '999910835': 0.87,
#  '999910836': 1.58,
#  '999910837': 0.78,
#  '999910838': -0.02,
#  '999910839': 0.82,
#  '9999108310': -0.01,
#  '9999108311': 0.28,
#  '9999108312': 0.6,
#  '9999108313': 11.46,
#  '999910841': 3.42,
#  '999910842': 1.66,
#  '9999101189': -0.18,
#  '99991011810': 0.28,
#  '99991011811': 0.27,
#  '99991011812': 0.62,
#  '99991011813': 3.13,
#  '9999101191': 0.32,
#  '9999101192': -0.08,
#  '9999101193': 0.11,
#  '9999101194': 0.44,
#  '9999101195': 0.68,
#  '9999101196': 0.55,
#  '9999101197': 0.31,
#  '9999101198': 0.12,
#  '9999101199': -0.27,
#  '99991011910': 0.02,
#  '99991011911': 0.14,
#  '99991011912': 0.34,
#  '99991011913': 2.72}

# %%
res['metadata']
# Out:
# {'activity': None, 'variable': None}

# %%
print(json.dumps(req_json, indent=4))
# Out:
# {
#     "status": "OK",
#     "data-availability": "available",
#     "var": [
#         {
#             "val": 1,
#             "label": "Inflation (Umum)",
#             "unit": "",
#             "subj": "Consumer Prices Indices",
#             "def": "",
#             "decimal": "",
#             "note": "&lt;p&gt;1. Before April 1979, the base year is September 1966 (September 1966 = 100)&lt;br /&gt;\n2.Since April 1979, the Term &quot;Consumer Price Index&quot; has been used ( the term that has been used before is &quot;Cost Living Index&quot;). The base year is April 1977-Maret 1978. CPI using a consumption pattern obtained from 1977/1978 Cost Living Survey in 17 Provincial Capital cities.) (April 1977-Maret 1978=100).&lt;br /&gt;\n3. Since April 1990-1997, CPI has been based on a consumption pattern obtained from Cost Living Survey in 27 Provincial Capital cities and using 1988/1989 base year) (1988/1989=100)&lt;br /&gt;\n4. Since December 1997, CPI has been based on a consumption pattern obtained from 1996 Cost of Living Survey in 44 cities(1996=100)&lt;br /&gt;\n5. Since January 2004, CPI has been based on a consumption pattern obtained from 2002 Cost of Living Survey in 45 cities(2002=100)&lt;br /&gt;\n6. Since June 2008, CPI has been based on a consumption pattern obtained from 2007 Cost of Living Survey in 66 cities(2007=100)&lt;br /&gt;\n7. Since 2014, CPI has been based on a consumption pattern obtained from 2012 Cost of Living Survey in 82 cities (2012=100)&lt;br /&gt;&lt;/p&gt;"
#         }
#     ],
#     "turvar": [
#         {
#             "val": 0,
#             "label": "Tidak Ada"
#         }
#     ],
#     "labelvervar": "Inflation City",
#     "vervar": [
#         {
#             "val": 9999,
#             "label": "INDONESIA"
#         },
#         {
#             "val": 1107,
#             "label": "KOTA MEULABOH"
#         },
#         {
#             "val": 1171,
#             "label": "KOTA BANDA ACEH"
#         },
#         {
#             "val": 1174,
#             "label": "KOTA LHOKSEUMAWE"
#         },
#         {
#             "val": 1271,
#             "label": "KOTA SIBOLGA"
#         },
#         {
#             "val": 1273,
#             "label": "KOTA PEMATANG SIANTAR"
#         },
#         {
#             "val": 1275,
#             "label": "KOTA MEDAN"
#         },
#         {
#             "val": 1277,
#             "label": "KOTA PADANGSIDIMPUAN"
#         },
#         {
#             "val": 1371,
#             "label": "KOTA PADANG"
#         },
#         {
#             "val": 1375,
#             "label": "KOTA BUKITTINGGI"
#         },
#         {
#             "val": 1403,
#             "label": "TEMBILAHAN"
#         },
#         {
#             "val": 1471,
#             "label": "KOTA PEKANBARU"
#         },
#         {
#             "val": 1473,
#             "label": "KOTA DUMAI"
#         },
#         {
#             "val": 1509,
#             "label": "BUNGO"
#         },
#         {
#             "val": 1571,
#             "label": "KOTA JAMBI"
#         },
#         {
#             "val": 1671,
#             "label": "KOTA PALEMBANG"
#         },
#         {
#             "val": 1674,
#             "label": "KOTA LUBUKLINGGAU"
#         },
#         {
#             "val": 1771,
#             "label": "KOTA BENGKULU"
#         },
#         {
#             "val": 1871,
#             "label": "KOTA BANDAR LAMPUNG"
#         },
#         {
#             "val": 1872,
#             "label": "KOTA METRO"
#         },
#         {
#             "val": 1902,
#             "label": "TANJUNG PANDAN"
#         },
#         {
#             "val": 1971,
#             "label": "KOTA PANGKAL PINANG"
#         },
#         {
#             "val": 2171,
#             "label": "KOTA BATAM"
#         },
#         {
#             "val": 2172,
#             "label": "KOTA TANJUNG PINANG"
#         },
#         {
#             "val": 3100,
#             "label": "DKI JAKARTA"
#         },
#         {
#             "val": 3271,
#             "label": "KOTA BOGOR"
#         },
#         {
#             "val": 3272,
#             "label": "KOTA SUKABUMI"
#         },
#         {
#             "val": 3273,
#             "label": "KOTA BANDUNG"
#         },
#         {
#             "val": 3274,
#             "label": "KOTA CIREBON"
#         },
#         {
#             "val": 3275,
#             "label": "KOTA BEKASI"
#         },
#         {
#             "val": 3276,
#             "label": "KOTA DEPOK"
#         },
#         {
#             "val": 3278,
#             "label": "KOTA TASIKMALAYA"
#         },
#         {
#             "val": 3301,
#             "label": "CILACAP"
#         },
#         {
#             "val": 3302,
#             "label": "PURWOKERTO"
#         },
#         {
#             "val": 3319,
#             "label": "KUDUS"
#         },
#         {
#             "val": 3372,
#             "label": "KOTA SURAKARTA"
#         },
#         {
#             "val": 3374,
#             "label": "KOTA SEMARANG"
#         },
#         {
#             "val": 3376,
#             "label": "KOTA TEGAL"
#         },
#         {
#             "val": 3471,
#             "label": "KOTA YOGYAKARTA"
#         },
#         {
#             "val": 3509,
#             "label": "JEMBER"
#         },
#         {
#             "val": 3510,
#             "label": "BANYUWANGI"
#         },
#         {
#             "val": 3529,
#             "label": "SUMENEP"
#         },
#         {
#             "val": 3571,
#             "label": "KOTA KEDIRI"
#         },
#         {
#             "val": 3573,
#             "label": "KOTA MALANG"
#         },
#         {
#             "val": 3574,
#             "label": "KOTA PROBOLINGGO"
#         },
#         {
#             "val": 3577,
#             "label": "KOTA MADIUN"
#         },
#         {
#             "val": 3578,
#             "label": "KOTA SURABAYA"
#         },
#         {
#             "val": 3671,
#             "label": "KOTA TANGERANG"
#         },
#         {
#             "val": 3672,
#             "label": "KOTA CILEGON"
#         },
#         {
#             "val": 3673,
#             "label": "KOTA SERANG"
#         },
#         {
#             "val": 5108,
#             "label": "SINGARAJA"
#         },
#         {
#             "val": 5171,
#             "label": "KOTA DENPASAR"
#         },
#         {
#             "val": 5271,
#             "label": "KOTA MATARAM"
#         },
#         {
#             "val": 5272,
#             "label": "KOTA BIMA"
#         },
#         {
#             "val": 5310,
#             "label": "MAUMERE"
#         },
#         {
#             "val": 5371,
#             "label": "KOTA KUPANG"
#         },
#         {
#             "val": 5400,
#             "label": "DILI"
#         },
#         {
#             "val": 6171,
#             "label": "KOTA PONTIANAK"
#         },
#         {
#             "val": 6172,
#             "label": "KOTA SINGKAWANG"
#         },
#         {
#             "val": 6202,
#             "label": "SAMPIT"
#         },
#         {
#             "val": 6271,
#             "label": "KOTA PALANGKA RAYA"
#         },
#         {
#             "val": 6309,
#             "label": "TANJUNG"
#         },
#         {
#             "val": 6371,
#             "label": "KOTA BANJARMASIN"
#         },
#         {
#             "val": 6471,
#             "label": "KOTA BALIKPAPAN"
#         },
#         {
#             "val": 6472,
#             "label": "KOTA SAMARINDA"
#         },
#         {
#             "val": 6473,
#             "label": "KOTA TARAKAN"
#         },
#         {
#             "val": 7171,
#             "label": "KOTA MANADO"
#         },
#         {
#             "val": 7271,
#             "label": "KOTA PALU"
#         },
#         {
#             "val": 7302,
#             "label": "BULUKUMBA"
#         },
#         {
#             "val": 7311,
#             "label": "WATAMPONE"
#         },
#         {
#             "val": 7371,
#             "label": "KOTA MAKASSAR"
#         },
#         {
#             "val": 7372,
#             "label": "KOTA PARE-PARE"
#         },
#         {
#             "val": 7373,
#             "label": "KOTA PALOPO"
#         },
#         {
#             "val": 7471,
#             "label": "KOTA KENDARI"
#         },
#         {
#             "val": 7472,
#             "label": "KOTA BAU-BAU"
#         },
#         {
#             "val": 7571,
#             "label": "KOTA GORONTALO"
#         },
#         {
#             "val": 7604,
#             "label": "MAMUJU"
#         },
#         {
#             "val": 8171,
#             "label": "KOTA AMBON"
#         },
#         {
#             "val": 8172,
#             "label": "KOTA TUAL"
#         },
#         {
#             "val": 8271,
#             "label": "KOTA TERNATE"
#         },
#         {
#             "val": 9105,
#             "label": "MANOKWARI"
#         },
#         {
#             "val": 9171,
#             "label": "KOTA SORONG"
#         },
#         {
#             "val": 9401,
#             "label": "MERAUKE"
#         },
#         {
#             "val": 9471,
#             "label": "KOTA JAYAPURA"
#         }
#     ],
#     "tahun": [
#         {
#             "val": 79,
#             "label": "1979"
#         },
#         {
#             "val": 80,
#             "label": "1980"
#         },
#         {
#             "val": 81,
#             "label": "1981"
#         },
#         {
#             "val": 82,
#             "label": "1982"
#         },
#         {
#             "val": 83,
#             "label": "1983"
#         },
#         {
#             "val": 84,
#             "label": "1984"
#         },
#         {
#             "val": 85,
#             "label": "1985"
#         },
#         {
#             "val": 86,
#             "label": "1986"
#         },
#         {
#             "val": 87,
#             "label": "1987"
#         },
#         {
#             "val": 88,
#             "label": "1988"
#         },
#         {
#             "val": 89,
#             "label": "1989"
#         },
#         {
#             "val": 90,
#             "label": "1990"
#         },
#         {
#             "val": 91,
#             "label": "1991"
#         },
#         {
#             "val": 92,
#             "label": "1992"
#         },
#         {
#             "val": 93,
#             "label": "1993"
#         },
#         {
#             "val": 94,
#             "label": "1994"
#         },
#         {
#             "val": 95,
#             "label": "1995"
#         },
#         {
#             "val": 96,
#             "label": "1996"
#         },
#         {
#             "val": 97,
#             "label": "1997"
#         },
#         {
#             "val": 98,
#             "label": "1998"
#         },
#         {
#             "val": 99,
#             "label": "1999"
#         },
#         {
#             "val": 100,
#             "label": "2000"
#         },
#         {
#             "val": 101,
#             "label": "2001"
#         },
#         {
#             "val": 102,
#             "label": "2002"
#         },
#         {
#             "val": 103,
#             "label": "2003"
#         },
#         {
#             "val": 104,
#             "label": "2004"
#         },
#         {
#             "val": 105,
#             "label": "2005"
#         },
#         {
#             "val": 106,
#             "label": "2006"
#         },
#         {
#             "val": 107,
#             "label": "2007"
#         },
#         {
#             "val": 108,
#             "label": "2008"
#         },
#         {
#             "val": 109,
#             "label": "2009"
#         },
#         {
#             "val": 110,
#             "label": "2010"
#         },
#         {
#             "val": 111,
#             "label": "2011"
#         },
#         {
#             "val": 112,
#             "label": "2012"
#         },
#         {
#             "val": 113,
#             "label": "2013"
#         },
#         {
#             "val": 114,
#             "label": "2014"
#         },
#         {
#             "val": 115,
#             "label": "2015"
#         },
#         {
#             "val": 116,
#             "label": "2016"
#         },
#         {
#             "val": 117,
#             "label": "2017"
#         },
#         {
#             "val": 118,
#             "label": "2018"
#         },
#         {
#             "val": 119,
#             "label": "2019"
#         }
#     ],
#     "turtahun": [
#         {
#             "val": 1,
#             "label": "January"
#         },
#         {
#             "val": 2,
#             "label": "February"
#         },
#         {
#             "val": 3,
#             "label": "March"
#         },
#         {
#             "val": 4,
#             "label": "April"
#         },
#         {
#             "val": 5,
#             "label": "May"
#         },
#         {
#             "val": 6,
#             "label": "June"
#         },
#         {
#             "val": 7,
#             "label": "July"
#         },
#         {
#             "val": 8,
#             "label": "August"
#         },
#         {
#             "val": 9,
#             "label": "September"
#         },
#         {
#             "val": 10,
#             "label": "October"
#         },
#         {
#             "val": 11,
#             "label": "November"
#         },
#         {
#             "val": 12,
#             "label": "December"
#         },
#         {
#             "val": 13,
#             "label": "Annually"
#         }
#     ],
#     "metadata": {
#         "activity": null,
#         "variable": null
#     },
#     "datacontent": {
#         "999910791": 2.58,
#         "999910792": 2.34,
#         "999910793": 0.55,
#         "999910794": 3.02,
#         "999910795": 3.05,
#         "999910796": 2.32,
#         "999910797": 2.5,
#         "999910798": 2.34,
#         "999910799": 0.74,
#         "9999107910": 0.89,
#         "9999107911": 0.57,
#         "9999107912": 0.87,
#         "9999107913": 21.77,
#         "999910801": 1.19,
#         "999910802": 1.42,
#         "999910803": 0.22,
#         "999910804": 1.04,
#         "999910805": 3.79,
#         "999910806": 1.49,
#         "999910807": 1.1,
#         "999910808": 1.19,
#         "999910809": 0.36,
#         "9999108010": 1.69,
#         "9999108011": 2.22,
#         "9999108012": 0.26,
#         "9999108013": 15.97,
#         "999910811": 1.31,
#         "999910812": 0.7,
#         "999910813": 0.7,
#         "999910814": 0.93,
#         "999910815": 0.15,
#         "999910816": 0.42,
#         "999910817": 1.2,
#         "999910818": 0.51,
#         "999910819": -0.19,
#         "9999108110": 1.17,
#         "9999108111": -0.32,
#         "9999108112": 0.51,
#         "9999108113": 7.09,
#         "999910821": 4.7,
#         "999910822": 0.54,
#         "999910823": 0.18,
#         "999910824": -0.06,
#         "999910825": 0.18,
